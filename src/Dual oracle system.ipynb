# %%
import pandas as pd
import numpy as np
import math
import pickle

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold

import platform
from os import listdir
from os.path import isfile, join
from glob import glob
from pathlib import Path
import sys
import os
import copy
import traceback



import matplotlib.pyplot as plt

import SMOTE
import feature_selector
import DE
import CFS
import birch
import metrics.abcd


from multiprocessing import Pool, cpu_count
from threading import Thread
from multiprocessing import Queue

import metrices
import measures

import sys
import traceback
import warnings
warnings.filterwarnings("ignore")

cores = cpu_count()

# %%
data_source1 = '/Users/suvodeepmajumder/Documents/AI4SE/bellwether_comminity/data/1385/converted'
if platform.system() == 'Darwin' or platform.system() == 'Linux':
    _dir = data_source1 + '/'
else:
    _dir = data_source1 + '\\'
projects = [f for f in listdir(_dir) if isfile(join(_dir, f))]

# %%
def prepare_data(path):
    df = pd.read_csv(path)
    df = df.drop(labels = ['Host','Vcs','Project','File','PL','IssueTracking'],axis=1)
    df = df.dropna()
    df = df[['TLOC', 'TNF', 'TNC', 'TND', 'LOC', 'CL', 'NStmt', 'NFunc',
       'RCC', 'MNL', 'avg_WMC', 'max_WMC', 'total_WMC', 'avg_DIT', 'max_DIT',
       'total_DIT', 'avg_RFC', 'max_RFC', 'total_RFC', 'avg_NOC', 'max_NOC',
       'total_NOC', 'avg_CBO', 'max_CBO', 'total_CBO', 'avg_DIT.1',
       'max_DIT.1', 'total_DIT.1', 'avg_NIV', 'max_NIV', 'total_NIV',
       'avg_NIM', 'max_NIM', 'total_NIM', 'avg_NOM', 'max_NOM', 'total_NOM',
       'avg_NPBM', 'max_NPBM', 'total_NPBM', 'avg_NPM', 'max_NPM', 'total_NPM',
       'avg_NPRM', 'max_NPRM', 'total_NPRM', 'avg_CC', 'max_CC', 'total_CC',
       'avg_FANIN', 'max_FANIN', 'total_FANIN', 'avg_FANOUT', 'max_FANOUT',
       'total_FANOUT', 'NRev', 'NFix', 'avg_AddedLOC', 'max_AddedLOC',
       'total_AddedLOC', 'avg_DeletedLOC', 'max_DeletedLOC',
       'total_DeletedLOC', 'avg_ModifiedLOC', 'max_ModifiedLOC',
       'total_ModifiedLOC','Buggy']]
    return df

def get_features(df):
    fs = feature_selector.featureSelector()
    df,_feature_nums,features = fs.cfs_bfs(df)
    return df,features

def apply_cfs(df):
    y = df.Buggy.values
    X = df.drop(labels = ['Buggy'],axis = 1)
    X = X.values
    selected_cols = CFS.cfs(X,y)
    cols = df.columns[[selected_cols]].tolist()
    cols.append('Buggy')
    return df[cols],cols
    
def apply_smote(df):
    cols = df.columns
    smt = SMOTE.smote(df)
    df = smt.run()
    df.columns = cols
    return df

def load_data(path,target):
    df = pd.read_csv(path)
    if path == 'data/jm1.csv':
        df = df[~df.uniq_Op.str.contains("\?")]
    y = df[target]
    X = df.drop(labels = target, axis = 1)
    X = X.apply(pd.to_numeric)
    return X,y

# Cluster Driver
def cluster_driver(df,print_tree = True):
    X = df.apply(pd.to_numeric)
    cluster = birch.birch(branching_factor=20)
    #X.set_index('Project Name',inplace=True)
    cluster.fit(X)
    cluster_tree,max_depth = cluster.get_cluster_tree()
    #cluster_tree = cluster.model_adder(cluster_tree)
    if print_tree:
        cluster.show_clutser_tree()
    return cluster,cluster_tree,max_depth

# %%
attr_dict = pd.read_pickle('data/1385/projects/selected_attr.pkl')
attr_df = pd.DataFrame.from_dict(attr_dict,orient='index')
cluster,cluster_tree,max_depth = cluster_driver(attr_df)
# Out:
# [cluster_id=0] N_children: 9 N_samples: 697
# > [cluster_id=1] N_children: 9 N_samples: 87
# > > [cluster_id=2] N_children: 0 N_samples: 2
# > > [cluster_id=3] N_children: 0 N_samples: 7
# > > [cluster_id=4] N_children: 0 N_samples: 17
# > > [cluster_id=5] N_children: 0 N_samples: 6
# > > [cluster_id=6] N_children: 0 N_samples: 18
# > > [cluster_id=7] N_children: 0 N_samples: 15
# > > [cluster_id=8] N_children: 0 N_samples: 12
# > > [cluster_id=9] N_children: 0 N_samples: 6
# > > [cluster_id=10] N_children: 0 N_samples: 4
# > [cluster_id=11] N_children: 2 N_samples: 4
# > > [cluster_id=12] N_children: 0 N_samples: 1
# > > [cluster_id=13] N_children: 0 N_samples: 3
# > [cluster_id=14] N_children: 10 N_samples: 103
# > > [cluster_id=15] N_children: 0 N_samples: 3
# > > [cluster_id=16] N_children: 0 N_samples: 4
# > > [cluster_id=17] N_children: 0 N_samples: 16
# > > [cluster_id=18] N_children: 0 N_samples: 11
# > > [cluster_id=19] N_children: 0 N_samples: 19
# > > [cluster_id=20] N_children: 0 N_samples: 3
# > > [cluster_id=21] N_children: 0 N_samples: 10
# > > [cluster_id=22] N_children: 0 N_samples: 6
# > > [cluster_id=23] N_children: 0 N_samples: 13
# > > [cluster_id=24] N_children: 0 N_samples: 18
# > [cluster_id=25] N_children: 0 N_samples: 2
# > [cluster_id=26] N_children: 0 N_samples: 4
# > [cluster_id=27] N_children: 0 N_samples: 1
# > [cluster_id=28] N_children: 6 N_samples: 64
# > > [cluster_id=29] N_children: 0 N_samples: 9
# > > [cluster_id=30] N_children: 0 N_samples: 12
# > > [cluster_id=31] N_children: 0 N_samples: 15
# > > [cluster_id=32] N_children: 0 N_samples: 16
# > > [cluster_id=33] N_children: 0 N_samples: 5
# > > [cluster_id=34] N_children: 0 N_samples: 7
# > [cluster_id=35] N_children: 19 N_samples: 222
# > > [cluster_id=36] N_children: 0 N_samples: 12
# > > [cluster_id=37] N_children: 0 N_samples: 10
# > > [cluster_id=38] N_children: 0 N_samples: 4
# > > [cluster_id=39] N_children: 0 N_samples: 19
# > > [cluster_id=40] N_children: 0 N_samples: 20
# > > [cluster_id=41] N_children: 0 N_samples: 11
# > > [cluster_id=42] N_children: 0 N_samples: 16
# > > [cluster_id=43] N_children: 0 N_samples: 8
# > > [cluster_id=44] N_children: 0 N_samples: 13
# > > [cluster_id=45] N_children: 0 N_samples: 7
# > > [cluster_id=46] N_children: 0 N_samples: 17
# > > [cluster_id=47] N_children: 0 N_samples: 19
# > > [cluster_id=48] N_children: 0 N_samples: 6
# > > [cluster_id=49] N_children: 0 N_samples: 5
# > > [cluster_id=50] N_children: 0 N_samples: 12
# > > [cluster_id=51] N_children: 0 N_samples: 13
# > > [cluster_id=52] N_children: 0 N_samples: 19
# > > [cluster_id=53] N_children: 0 N_samples: 4
# > > [cluster_id=54] N_children: 0 N_samples: 7
# > [cluster_id=55] N_children: 20 N_samples: 210
# > > [cluster_id=56] N_children: 0 N_samples: 11
# > > [cluster_id=57] N_children: 0 N_samples: 18
# > > [cluster_id=58] N_children: 0 N_samples: 3
# > > [cluster_id=59] N_children: 0 N_samples: 13
# > > [cluster_id=60] N_children: 0 N_samples: 9
# > > [cluster_id=61] N_children: 0 N_samples: 18
# > > [cluster_id=62] N_children: 0 N_samples: 15
# > > [cluster_id=63] N_children: 0 N_samples: 2
# > > [cluster_id=64] N_children: 0 N_samples: 5
# > > [cluster_id=65] N_children: 0 N_samples: 13
# > > [cluster_id=66] N_children: 0 N_samples: 6
# > > [cluster_id=67] N_children: 0 N_samples: 11
# > > [cluster_id=68] N_children: 0 N_samples: 2
# > > [cluster_id=69] N_children: 0 N_samples: 1
# > > [cluster_id=70] N_children: 0 N_samples: 11
# > > [cluster_id=71] N_children: 0 N_samples: 18
# > > [cluster_id=72] N_children: 0 N_samples: 18
# > > [cluster_id=73] N_children: 0 N_samples: 20
# > > [cluster_id=74] N_children: 0 N_samples: 7
# > > [cluster_id=75] N_children: 0 N_samples: 9

# %%
selected_projects = list(attr_df.iloc[cluster_tree[6].data_points].index)

# %%
def load_data_t(s_project):
    s_path = '/Users/suvodeepmajumder/Documents/AI4SE/bellwether_comminity/data/1385/converted/' + s_project
    df = prepare_data(s_path)
    df.reset_index(drop=True,inplace=True)
    d = {'buggy': True, 'clean': False}
    df['Buggy'] = df['Buggy'].map(d)
    df, s_cols = apply_cfs(df)
    df = apply_smote(df)
    y = df.Buggy
    X = df.drop(labels = ['Buggy'],axis = 1)
    return X,y,s_cols

def load_data_te(s_project):
    s_path = '/Users/suvodeepmajumder/Documents/AI4SE/bellwether_comminity/data/1385/converted/' + s_project
    df = prepare_data(s_path)
    df.reset_index(drop=True,inplace=True)
    d = {'buggy': True, 'clean': False}
    df['Buggy'] = df['Buggy'].map(d)
    return df

# %%
train_X, train_y,s1_cols = load_data_t('google-collections.csv')
clf1 = LogisticRegression()
clf1.fit(train_X,train_y)

train_X, train_y,s2_cols = load_data_t('piccolo2d.csv')
clf2 = LogisticRegression()
clf2.fit(train_X,train_y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
for project in selected_projects:
    print("Selcted Project==============================================")
    test_df = load_data_te(project)
    _test_df = test_df[s1_cols]
    _test_y = _test_df.Buggy
    _test_X = _test_df.drop(labels = ['Buggy'],axis = 1)
    prediction1 = clf1.predict(_test_X)
    print("From Clf1----------------------")
    print(classification_report(_test_y, prediction1))
    _test_df = test_df[s2_cols]
    _test_y = _test_df.Buggy
    _test_X = _test_df.drop(labels = ['Buggy'],axis = 1)
    prediction2 = clf2.predict(_test_X)
    print("From Clf2-----------------------")
    print(classification_report(_test_y, prediction2))
    prediction = []
    for i in range(len(prediction1)):
        if (prediction1[i] == True) and (prediction2[i] == True):
            prediction.append(True)
        elif (prediction1[i] == False) and (prediction2[i] == False):
            prediction.append(False)
        elif (prediction1[i] == False) and (prediction2[i] == True):
            prediction.append(True)
        elif (prediction1[i] == True) and (prediction2[i] == False):
            prediction.append(False)
    #prediction = [a and b for a, b in zip(prediction1, prediction2)]
    print("From Clf mixed-------------------")
    print(classification_report(_test_y, prediction))
# Out:
# Selcted Project==============================================
# From Clf1----------------------
#               precision    recall  f1-score   support
#
#        False       0.12      1.00      0.22         2
#         True       1.00      0.82      0.90        80
#
#     accuracy                           0.83        82
#    macro avg       0.56      0.91      0.56        82
# weighted avg       0.98      0.83      0.89        82
#
# From Clf2-----------------------
#               precision    recall  f1-score   support
#
#        False       0.03      1.00      0.05         2
#         True       1.00      0.09      0.16        80
#
#     accuracy                           0.11        82
#    macro avg       0.51      0.54      0.11        82
# weighted avg       0.98      0.11      0.16        82
#
# From Clf mixed-------------------
#               precision    recall  f1-score   support
#
#        False       0.03      1.00      0.05         2
#         True       1.00      0.09      0.16        80
#
#     accuracy                           0.11        82
#    macro avg       0.51      0.54      0.11        82
# weighted avg       0.98      0.11      0.16        82
#
# Selcted Project==============================================
# From Clf1----------------------
#               precision    recall  f1-score   support
#
#        False       0.25      0.03      0.05        40
#         True       0.37      0.88      0.52        26
#
#     accuracy                           0.36        66
#    macro avg       0.31      0.45      0.28        66
# weighted avg       0.30      0.36      0.23        66
#
# From Clf2-----------------------
#               precision    recall  f1-score   support
#
#        False       0.72      0.78      0.75        40
#         True       0.61      0.54      0.57        26
#
#     accuracy                           0.68        66
#    macro avg       0.66      0.66      0.66        66
# weighted avg       0.68      0.68      0.68        66
#
# From Clf mixed-------------------
#               precision    recall  f1-score   support
#
#        False       0.72      0.78      0.75        40
#         True       0.61      0.54      0.57        26
#
#     accuracy                           0.68        66
#    macro avg       0.66      0.66      0.66        66
# weighted avg       0.68      0.68      0.68        66
#
# Selcted Project==============================================
# From Clf1----------------------
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        16
#         True       0.76      1.00      0.86        50
#
#     accuracy                           0.76        66
#    macro avg       0.38      0.50      0.43        66
# weighted avg       0.57      0.76      0.65        66
#
# From Clf2-----------------------
#               precision    recall  f1-score   support
#
#        False       0.31      0.50      0.38        16
#         True       0.80      0.64      0.71        50
#
#     accuracy                           0.61        66
#    macro avg       0.55      0.57      0.55        66
# weighted avg       0.68      0.61      0.63        66
#
# From Clf mixed-------------------
#               precision    recall  f1-score   support
#
#        False       0.31      0.50      0.38        16
#         True       0.80      0.64      0.71        50
#
#     accuracy                           0.61        66
#    macro avg       0.55      0.57      0.55        66
# weighted avg       0.68      0.61      0.63        66
#
# Selcted Project==============================================
# From Clf1----------------------
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        48
#         True       0.56      1.00      0.71        60
#
#     accuracy                           0.56       108
#    macro avg       0.28      0.50      0.36       108
# weighted avg       0.31      0.56      0.40       108
#
# From Clf2-----------------------
#               precision    recall  f1-score   support
#
#        False       0.44      0.96      0.61        48
#         True       0.50      0.03      0.06        60
#
#     accuracy                           0.44       108
#    macro avg       0.47      0.50      0.33       108
# weighted avg       0.47      0.44      0.30       108
#
# From Clf mixed-------------------
#               precision    recall  f1-score   support
#
#        False       0.44      0.96      0.61        48
#         True       0.50      0.03      0.06        60
#
#     accuracy                           0.44       108
#    macro avg       0.47      0.50      0.33       108
# weighted avg       0.47      0.44      0.30       108
#
# Selcted Project==============================================
# From Clf1----------------------
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        28
#         True       0.74      0.99      0.84        79
#
#     accuracy                           0.73       107
#    macro avg       0.37      0.49      0.42       107
# weighted avg       0.54      0.73      0.62       107
#
# From Clf2-----------------------
#               precision    recall  f1-score   support
#
#        False       0.28      0.93      0.43        28
#         True       0.85      0.14      0.24        79
#
#     accuracy                           0.35       107
#    macro avg       0.56      0.53      0.33       107
# weighted avg       0.70      0.35      0.29       107
#
# From Clf mixed-------------------
#               precision    recall  f1-score   support
#
#        False       0.28      0.93      0.43        28
#         True       0.85      0.14      0.24        79
#
#     accuracy                           0.35       107
#    macro avg       0.56      0.53      0.33       107
# weighted avg       0.70      0.35      0.29       107
#
# Selcted Project==============================================
# From Clf1----------------------
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        41
#         True       0.29      1.00      0.45        17
#
#     accuracy                           0.29        58
#    macro avg       0.15      0.50      0.23        58
# weighted avg       0.09      0.29      0.13        58
#
# From Clf2-----------------------
#               precision    recall  f1-score   support
#
#        False       0.80      0.78      0.79        41
#         True       0.50      0.53      0.51        17
#
#     accuracy                           0.71        58
#    macro avg       0.65      0.65      0.65        58
# weighted avg       0.71      0.71      0.71        58
#
# From Clf mixed-------------------
#               precision    recall  f1-score   support
#
#        False       0.80      0.78      0.79        41
#         True       0.50      0.53      0.51        17
#
#     accuracy                           0.71        58
#    macro avg       0.65      0.65      0.65        58
# weighted avg       0.71      0.71      0.71        58
#
# Selcted Project==============================================
# From Clf1----------------------
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        70
#         True       0.35      1.00      0.51        37
#
#     accuracy                           0.35       107
#    macro avg       0.17      0.50      0.26       107
# weighted avg       0.12      0.35      0.18       107
#
# From Clf2-----------------------
#               precision    recall  f1-score   support
#
#        False       0.64      0.77      0.70        70
#         True       0.27      0.16      0.20        37
#
#     accuracy                           0.56       107
#    macro avg       0.45      0.47      0.45       107
# weighted avg       0.51      0.56      0.53       107
#
# From Clf mixed-------------------
#               precision    recall  f1-score   support
#
#        False       0.64      0.77      0.70        70
#         True       0.27      0.16      0.20        37
#
#     accuracy                           0.56       107
#    macro avg       0.45      0.47      0.45       107
# weighted avg       0.51      0.56      0.53       107
#
# Selcted Project==============================================
# From Clf1----------------------
#               precision    recall  f1-score   support
#
#        False       0.50      0.03      0.06        32
#         True       0.38      0.95      0.54        20
#
#     accuracy                           0.38        52
#    macro avg       0.44      0.49      0.30        52
# weighted avg       0.45      0.38      0.24        52
#
# From Clf2-----------------------
#               precision    recall  f1-score   support
#
#        False       0.72      0.72      0.72        32
#         True       0.55      0.55      0.55        20
#
#     accuracy                           0.65        52
#    macro avg       0.63      0.63      0.63        52
# weighted avg       0.65      0.65      0.65        52
#
# From Clf mixed-------------------
#               precision    recall  f1-score   support
#
#        False       0.72      0.72      0.72        32
#         True       0.55      0.55      0.55        20
#
#     accuracy                           0.65        52
#    macro avg       0.63      0.63      0.63        52
# weighted avg       0.65      0.65      0.65        52
#
# Selcted Project==============================================
# From Clf1----------------------
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        92
#         True       0.08      1.00      0.15         8
#
#     accuracy                           0.08       100
#    macro avg       0.04      0.50      0.07       100
# weighted avg       0.01      0.08      0.01       100
#
# From Clf2-----------------------
#               precision    recall  f1-score   support
#
#        False       0.95      0.76      0.84        92
#         True       0.15      0.50      0.24         8
#
#     accuracy                           0.74       100
#    macro avg       0.55      0.63      0.54       100
# weighted avg       0.88      0.74      0.79       100
#
# From Clf mixed-------------------
#               precision    recall  f1-score   support
#
#        False       0.95      0.76      0.84        92
#         True       0.15      0.50      0.24         8
#
#     accuracy                           0.74       100
#    macro avg       0.55      0.63      0.54       100
# weighted avg       0.88      0.74      0.79       100
#
# Selcted Project==============================================
# From Clf1----------------------
#               precision    recall  f1-score   support
#
#        False       0.67      0.16      0.26        25
#         True       0.73      0.97      0.83        60
#
#     accuracy                           0.73        85
#    macro avg       0.70      0.56      0.55        85
# weighted avg       0.71      0.73      0.66        85
#
# From Clf2-----------------------
#               precision    recall  f1-score   support
#
#        False       0.39      0.72      0.51        25
#         True       0.82      0.53      0.65        60
#
#     accuracy                           0.59        85
#    macro avg       0.61      0.63      0.58        85
# weighted avg       0.69      0.59      0.61        85
#
# From Clf mixed-------------------
#               precision    recall  f1-score   support
#
#        False       0.39      0.72      0.51        25
#         True       0.82      0.53      0.65        60
#
#     accuracy                           0.59        85
#    macro avg       0.61      0.63      0.58        85
# weighted avg       0.69      0.59      0.61        85
#
# Selcted Project==============================================
# From Clf1----------------------
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        62
#         True       0.05      1.00      0.09         3
#
#     accuracy                           0.05        65
#    macro avg       0.02      0.50      0.04        65
# weighted avg       0.00      0.05      0.00        65
#
# From Clf2-----------------------
#               precision    recall  f1-score   support
#
#        False       0.95      0.95      0.95        62
#         True       0.00      0.00      0.00         3
#
#     accuracy                           0.91        65
#    macro avg       0.48      0.48      0.48        65
# weighted avg       0.91      0.91      0.91        65
#
# From Clf mixed-------------------
#               precision    recall  f1-score   support
#
#        False       0.95      0.95      0.95        62
#         True       0.00      0.00      0.00         3
#
#     accuracy                           0.91        65
#    macro avg       0.48      0.48      0.48        65
# weighted avg       0.91      0.91      0.91        65
#
# Selcted Project==============================================
# From Clf1----------------------
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        45
#         True       0.37      1.00      0.54        26
#
#     accuracy                           0.37        71
#    macro avg       0.18      0.50      0.27        71
# weighted avg       0.13      0.37      0.20        71
#
# From Clf2-----------------------
#               precision    recall  f1-score   support
#
#        False       0.77      0.76      0.76        45
#         True       0.59      0.62      0.60        26
#
#     accuracy                           0.70        71
#    macro avg       0.68      0.69      0.68        71
# weighted avg       0.71      0.70      0.71        71
#
# From Clf mixed-------------------
#               precision    recall  f1-score   support
#
#        False       0.77      0.76      0.76        45
#         True       0.59      0.62      0.60        26
#
#     accuracy                           0.70        71
#    macro avg       0.68      0.69      0.68        71
# weighted avg       0.71      0.70      0.71        71
#
# Selcted Project==============================================
# From Clf1----------------------
#               precision    recall  f1-score   support
#
#        False       1.00      0.00      0.01       214
#         True       0.29      1.00      0.44        85
#
#     accuracy                           0.29       299
#    macro avg       0.64      0.50      0.23       299
# weighted avg       0.80      0.29      0.13       299
#
# From Clf2-----------------------
#               precision    recall  f1-score   support
#
#        False       0.75      0.80      0.77       214
#         True       0.39      0.32      0.35        85
#
#     accuracy                           0.66       299
#    macro avg       0.57      0.56      0.56       299
# weighted avg       0.64      0.66      0.65       299
#
# From Clf mixed-------------------
#               precision    recall  f1-score   support
#
#        False       0.75      0.80      0.77       214
#         True       0.39      0.32      0.35        85
#
#     accuracy                           0.66       299
#    macro avg       0.57      0.56      0.56       299
# weighted avg       0.64      0.66      0.65       299
#
# Selcted Project==============================================
# From Clf1----------------------
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        46
#         True       0.27      1.00      0.42        17
#
#     accuracy                           0.27        63
#    macro avg       0.13      0.50      0.21        63
# weighted avg       0.07      0.27      0.11        63
#
# From Clf2-----------------------
#               precision    recall  f1-score   support
#
#        False       0.80      0.93      0.86        46
#         True       0.67      0.35      0.46        17
#
#     accuracy                           0.78        63
#    macro avg       0.73      0.64      0.66        63
# weighted avg       0.76      0.78      0.75        63
#
# From Clf mixed-------------------
#               precision    recall  f1-score   support
#
#        False       0.80      0.93      0.86        46
#         True       0.67      0.35      0.46        17
#
#     accuracy                           0.78        63
#    macro avg       0.73      0.64      0.66        63
# weighted avg       0.76      0.78      0.75        63
#
# Selcted Project==============================================
# From Clf1----------------------
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        41
#         True       0.63      1.00      0.78        71
#
#     accuracy                           0.63       112
#    macro avg       0.32      0.50      0.39       112
# weighted avg       0.40      0.63      0.49       112
#
# From Clf2-----------------------
#               precision    recall  f1-score   support
#
#        False       0.37      0.98      0.54        41
#         True       0.75      0.04      0.08        71
#
#     accuracy                           0.38       112
#    macro avg       0.56      0.51      0.31       112
# weighted avg       0.61      0.38      0.25       112
#
# From Clf mixed-------------------
#               precision    recall  f1-score   support
#
#        False       0.37      0.98      0.54        41
#         True       0.75      0.04      0.08        71
#
#     accuracy                           0.38       112
#    macro avg       0.56      0.51      0.31       112
# weighted avg       0.61      0.38      0.25       112
#
# Selcted Project==============================================
# From Clf1----------------------
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        37
#         True       0.52      1.00      0.68        40
#
#     accuracy                           0.52        77
#    macro avg       0.26      0.50      0.34        77
# weighted avg       0.27      0.52      0.36        77
#
# From Clf2-----------------------
#               precision    recall  f1-score   support
#
#        False       0.50      0.92      0.65        37
#         True       0.67      0.15      0.24        40
#
#     accuracy                           0.52        77
#    macro avg       0.58      0.53      0.45        77
# weighted avg       0.59      0.52      0.44        77
#
# From Clf mixed-------------------
#               precision    recall  f1-score   support
#
#        False       0.50      0.92      0.65        37
#         True       0.67      0.15      0.24        40
#
#     accuracy                           0.52        77
#    macro avg       0.58      0.53      0.45        77
# weighted avg       0.59      0.52      0.44        77
#
# Selcted Project==============================================
# From Clf1----------------------
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        43
#         True       0.40      1.00      0.57        29
#
#     accuracy                           0.40        72
#    macro avg       0.20      0.50      0.29        72
# weighted avg       0.16      0.40      0.23        72
#
# From Clf2-----------------------
#               precision    recall  f1-score   support
#
#        False       0.61      0.95      0.75        43
#         True       0.60      0.10      0.18        29
#
#     accuracy                           0.61        72
#    macro avg       0.61      0.53      0.46        72
# weighted avg       0.61      0.61      0.52        72
#
# From Clf mixed-------------------
#               precision    recall  f1-score   support
#
#        False       0.61      0.95      0.75        43
#         True       0.60      0.10      0.18        29
#
#     accuracy                           0.61        72
#    macro avg       0.61      0.53      0.46        72
# weighted avg       0.61      0.61      0.52        72
#
# Selcted Project==============================================
# From Clf1----------------------
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        10
#         True       0.96      1.00      0.98       241
#
#     accuracy                           0.96       251
#    macro avg       0.48      0.50      0.49       251
# weighted avg       0.92      0.96      0.94       251
#
# From Clf2-----------------------
#               precision    recall  f1-score   support
#
#        False       0.06      0.80      0.12        10
#         True       0.98      0.51      0.68       241
#
#     accuracy                           0.53       251
#    macro avg       0.52      0.66      0.40       251
# weighted avg       0.95      0.53      0.65       251
#
# From Clf mixed-------------------
#               precision    recall  f1-score   support
#
#        False       0.06      0.80      0.12        10
#         True       0.98      0.51      0.68       241
#
#     accuracy                           0.53       251
#    macro avg       0.52      0.66      0.40       251
# weighted avg       0.95      0.53      0.65       251

# %%
z = [a and b for a, b in zip(x, y)]

# %%
z
# Out:
# [True, False, False, False]
