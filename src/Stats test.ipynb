# %%
import pandas as pd
import numpy as np
import math
import pickle

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold

import platform
from os import listdir
from os.path import isfile, join
from glob import glob
from pathlib import Path
import sys
import os
import copy
import traceback
from pathlib import Path


import matplotlib.pyplot as plt

import SMOTE
import feature_selector
import DE
import CFS
import birch
import metrics.abcd

import metrices
import measures

import sys
import traceback
import warnings
warnings.filterwarnings("ignore")

# %%
data_source1 = '/Users/suvodeepmajumder/Documents/AI4SE/bellwether_comminity/src/data/1385/exp1/1'
if platform.system() == 'Darwin' or platform.system() == 'Linux':
    _dir = data_source1 + '/'
else:
    _dir = data_source1 + '\\'

clusters = [(join(_dir, f)) for f in listdir(_dir) if Path(join(_dir, f)).is_dir()]

# %%
#get stats test data
count = 0
count_not = 0
count_yes = 0
precentage = 0
score = []
size = 0
for cluster in clusters:
    df = pd.read_csv(cluster + '/1385_LR_bellwether_pf.csv')
    size += df.shape[1]
    counts = []
    for row in range(df.shape[0]):
        j = df.iloc[row].values[1:]
        value = sum(i <= 0.33 for i in j)
        counts.append(value)
    df['>=0.6'] = counts
    precentage = max(counts)/df.shape[0]
    score = score + df.iloc[counts.index(max(counts))].values[1:].tolist()
    count += max(counts)
with open('data/1385/exp1/level1.txt', 'w') as f:
    for item in score:
        f.write("%s " % item)

# %%
#get stats test data for finding bellwether
count = 0
count_not = 0
count_yes = 0
precentage = 0
score = []
size = 0
for cluster in clusters[0:1]:
    print(cluster)
    df = pd.read_csv(cluster + '/1385_LR_bellwether_f1.csv')
    size += df.shape[1]
    counts = []
    for row in range(df.shape[0]):
        j = df.iloc[row].values
        counts.append(j)
    with open('data/1385/exp1/level1.txt', 'w') as f:
        for project in counts:
            f.write("%s \n" % project[0])
            for item in project[1:]:
                f.write("%s " % item)
            f.write("\n\n")
# Out:
# /Users/suvodeepmajumder/Documents/AI4SE/bellwether_comminity/src/data/1385/exp1/1/35

# %%
# Out:
# 706

# %%
count
# Out:
# 264

# %%
score_df
# Out:
#     id  expected  max_bell  avge                  bellwether
# 61   2         1         2  1.50               logicmail.csv
# 56   3         2         2  1.29                 jam-daq.csv
# 54   4         6         9  3.59                   exist.csv
# 62   5         2         2  0.67                    mule.csv
# 25   6         6         8  4.28                geotools.csv
# 18   7         5         3  0.67                   sblim.csv
# 29   8         4         7  2.92            javaprofiler.csv
# 17   9         2         1  0.17                ambulant.csv
# 27  10         1         1  0.50                 autofac.csv
# 55  15         1         2  1.00                  amanda.csv
# 20  16         1         2  1.75               cascading.csv
# 26  17         5         5  1.81                    gebr.csv
# 16  18         4         6  2.00           enlightenment.csv
# 28  19         6         5  2.21                   jmule.csv
# 15  20         1         1  0.33                    lmms.csv
# 30  21         3         4  2.10             playerstage.csv
# 63  22         2         1  0.40             foursquared.csv
# 53  23         4         4  2.15                  biopax.csv
# 52  24         6         6  2.53          patterntesting.csv
# 19  29         3         3  1.11                   bochs.csv
# 42  30         4         2  0.58             smbopensoft.csv
# 37  31         5         7  2.33                   somap.csv
# 6   32         5        10  5.60             google-caja.csv
# 14  33         2         4  2.20             botsnscouts.csv
# 13  34         2         1  0.43                    fido.csv
# 36  36         4         3  1.58                 igarden.csv
# 43  37         3         4  1.60            mob-sen-plat.csv
# 35  38         1         2  1.00                   jajuk.csv
# 44  39         6         9  5.00                     gss.csv
# 59  40         7         9  4.25              planeshift.csv
# ..  ..       ...       ...   ...                         ...
# 22  45         2         2  1.14             adaptagrams.csv
# 48  46         6        10  5.71                irrlicht.csv
# 60  47         6         6  3.32             critterding.csv
# 50  48         2         2  1.00                 jparsec.csv
# 58  49         2         2  1.40                   pcgen.csv
# 3   50         4         6  1.92              sumatrapdf.csv
# 9   51         4         5  2.08                  mscore.csv
# 45  52         6         7  4.63                  decidr.csv
# 41  53         1         2  1.75                 genecys.csv
# 40  54         2         4  1.86                  mimosa.csv
# 8   56         3         4  1.90         ivataopenportal.csv
# 5   57         6         5  2.35               fontforge.csv
# 10  58         1         2  1.67                graphmak.csv
# 1   59         4         2  0.45                    nh3d.csv
# 12  60         3         3  1.22                    zact.csv
# 0   61         6         6  3.06                  xuggle.csv
# 39  62         5         6  3.14                 web-cat.csv
# 46  63         1         1  0.50                    jmol.csv
# 47  64         2         2  0.60                     nug.csv
# 38  65         4         3  1.31          free-evolution.csv
# 2   66         2         1  0.83  buddata-ebxml-registry.csv
# 11  67         4         4  2.18            barracudamvc.csv
# 4   68         1         2  1.50              silvertree.csv
# 7   69         0         0  0.00                    jrdf.csv
# 51  70         4         7  4.45                   wpdev.csv
# 57  71         6         6  2.28                  grisbi.csv
# 32  72         6         5  1.76               zemljanka.csv
# 23  73         7        11  5.75                kolmafia.csv
# 24  74         2         3  1.71                 glelite.csv
# 31  75         3         2  1.11               carabiner.csv
#
# [64 rows x 5 columns]
