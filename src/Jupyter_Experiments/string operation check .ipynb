# %%
file = 'src/main/org/apache/tools/ant/taskdefs/optional/clearcase/ClearCase.java'
file = file.replace('/','.')

# %%
class_name = 'org.apache.tools.ant.taskdefs.optional.clearcase.ClearCase'
# Out:
# 'src.main.org.apache.tools.ant.taskdefs.optional.clearcase.ClearCase.java'

# %%
import pandas as pd

# %%
df = pd.read_pickle('/Users/suvodeepmajumder/Documents/AI4SE/git_miner/data/spark_committed_file.pkl')

# %%
df
# Out:
#                                      commit_id  \
# 0     3ffb47315c69a3d3a8c96077f15f699fe68c3f08
# 1     3ffb47315c69a3d3a8c96077f15f699fe68c3f08
# 2     3ffb47315c69a3d3a8c96077f15f699fe68c3f08
# 3     3ffb47315c69a3d3a8c96077f15f699fe68c3f08
# 4     3ffb47315c69a3d3a8c96077f15f699fe68c3f08
# 5     3ffb47315c69a3d3a8c96077f15f699fe68c3f08
# 6     3ffb47315c69a3d3a8c96077f15f699fe68c3f08
# 7     3ffb47315c69a3d3a8c96077f15f699fe68c3f08
# 8     3ffb47315c69a3d3a8c96077f15f699fe68c3f08
# 9     3ffb47315c69a3d3a8c96077f15f699fe68c3f08
# 10    3ffb47315c69a3d3a8c96077f15f699fe68c3f08
# 11    3ffb47315c69a3d3a8c96077f15f699fe68c3f08
# 12    3ffb47315c69a3d3a8c96077f15f699fe68c3f08
# 13    3ffb47315c69a3d3a8c96077f15f699fe68c3f08
# 14    3ffb47315c69a3d3a8c96077f15f699fe68c3f08
# 15    3ffb47315c69a3d3a8c96077f15f699fe68c3f08
# 16    0317f40cf792b293ac9ff47639490c8928572e72
# 17    0317f40cf792b293ac9ff47639490c8928572e72
# 18    cb43579bdb648cc2503d230bdb7fec6381cd4f2a
# ...

# %%
spark.JettyLogger
org.mortbay.log.Logger
org.apache.log4j.Logger
String
Throwable
Exception
spark.Start
spark.Spark
org.mortbay.jetty.Connector
org.mortbay.jetty.Server
org.mortbay.jetty.bio.SocketConnector
spark.Context
java.util.ArrayList
Class
java.util.List
java.lang.reflect.Method
spark.SparkUtils
spark.WebContext
spark.Node
spark.Node.SearchContext
spark.DispatcherFilter
javax.servlet.Filter
javax.servlet.FilterChain
javax.servlet.FilterConfig
javax.servlet.http.HttpServletRequest
javax.servlet.http.HttpServletResponse
java.io.IOException
org.reflections.scanners.MethodAnnotationsScanner
java.lang.reflect.Modifier
org.reflections.Reflections
javax.servlet.ServletException
javax.servlet.ServletRequest
javax.servlet.ServletResponse
java.util.Set
spark.RouteMatcher
spark.RouteMatch
spark.HttpMethod
spark.RouteTest
org.mortbay.jetty.handler.AbstractHandler
org.mortbay.log.Log
java.util.HashMap
java.util.Map
java.lang.annotation.Retention
java.lang.annotation.RetentionPolicy
java.lang.annotation.Target
