# %%
import pandas as pd
import numpy as np
import math
import pickle

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold

import platform
from os import listdir
from os.path import isfile, join
from glob import glob
from pathlib import Path
import sys
import os
import copy
import traceback



import matplotlib.pyplot as plt

import SMOTE
import feature_selector
import DE
import CFS
import metrics.abcd

import metrices
import measures

import sys
import traceback
import warnings
warnings.filterwarnings("ignore")

# %%
data_source1 = '/Users/suvodeepmajumder/Documents/AI4SE/bellwether_comminity/data/1385/converted'
if platform.system() == 'Darwin' or platform.system() == 'Linux':
    _dir = data_source1 + '/'
else:
    _dir = data_source1 + '\\'
projects = [f for f in listdir(_dir) if isfile(join(_dir, f))]

# %%
def prepare_data(path):
    df = pd.read_csv(path)
    df = df.drop(labels = ['Host','Vcs','Project','File','PL','IssueTracking'],axis=1)
    df = df.dropna()
    df = df[['TLOC', 'TNF', 'TNC', 'TND', 'LOC', 'CL', 'NStmt', 'NFunc',
       'RCC', 'MNL', 'avg_WMC', 'max_WMC', 'total_WMC', 'avg_DIT', 'max_DIT',
       'total_DIT', 'avg_RFC', 'max_RFC', 'total_RFC', 'avg_NOC', 'max_NOC',
       'total_NOC', 'avg_CBO', 'max_CBO', 'total_CBO', 'avg_DIT.1',
       'max_DIT.1', 'total_DIT.1', 'avg_NIV', 'max_NIV', 'total_NIV',
       'avg_NIM', 'max_NIM', 'total_NIM', 'avg_NOM', 'max_NOM', 'total_NOM',
       'avg_NPBM', 'max_NPBM', 'total_NPBM', 'avg_NPM', 'max_NPM', 'total_NPM',
       'avg_NPRM', 'max_NPRM', 'total_NPRM', 'avg_CC', 'max_CC', 'total_CC',
       'avg_FANIN', 'max_FANIN', 'total_FANIN', 'avg_FANOUT', 'max_FANOUT',
       'total_FANOUT', 'NRev', 'NFix', 'avg_AddedLOC', 'max_AddedLOC',
       'total_AddedLOC', 'avg_DeletedLOC', 'max_DeletedLOC',
       'total_DeletedLOC', 'avg_ModifiedLOC', 'max_ModifiedLOC',
       'total_ModifiedLOC','Buggy']]
    return df

def get_features(df):
    fs = feature_selector.featureSelector()
    df,_feature_nums,features = fs.cfs_bfs(df)
    return df,features

def apply_cfs(df):
    y = df.Buggy.values
    X = df.drop(labels = ['Buggy'],axis = 1)
    X = X.values
    selected_cols = CFS.cfs(X,y)
    cols = df.columns[[selected_cols]].tolist()
    cols.append('Buggy')
    return df[cols],cols
    
def apply_smote(df):
    cols = df.columns
    smt = SMOTE.smote(df)
    df = smt.run()
    df.columns = cols
    return df

def tune_learner(learner, train_X, train_Y, tune_X, tune_Y, goal,loc=None,target_class=None):
    if not target_class:
        target_class = goal
    clf = learner(train_X, train_Y, tune_X, tune_Y, goal,loc)
    tuner = DE.DE_Tune_ML(clf, clf.get_param(), goal, target_class)
    return tuner.Tune()

# %%
selected_projects = []
unselected_projects = []

for project in projects:
    try:
        path = '/Users/suvodeepmajumder/Documents/AI4SE/bellwether_comminity/data/1385/converted/' + project
        df = prepare_data(path)
        if df.shape[0] >= 50:
            selected_projects.append(project)
        else:
            unselected_projects.append(project)
    except:
        continue

# %%
selected_projects = ['firebird.csv']

# %%
final_score = {}
count = 0
for s_project in selected_projects:
    try:
        s_path = '/Users/suvodeepmajumder/Documents/AI4SE/bellwether_comminity/data/1385/converted/' + s_project
        print(s_project)
        df = prepare_data(s_path)
        if df.shape[0] < 50:
            continue
        else:
            count+=1
        df.reset_index(drop=True,inplace=True)
        d = {'buggy': True, 'clean': False}
        df['Buggy'] = df['Buggy'].map(d)
        df, s_cols = apply_cfs(df)
        y = df.Buggy
        X = df.drop(labels = ['Buggy'],axis = 1)
        kf = StratifiedKFold(n_splits = 5)
        score = {}
        F = {}
        for i in range(5):
            for train_index, tune_index in kf.split(X, y):
                X_train, X_tune = X.iloc[train_index], X.iloc[tune_index]
                y_train, y_tune = y[train_index], y[tune_index]
                clf = LogisticRegression()
                clf.fit(X_train,y_train)
                #destination_projects = copy.deepcopy(selected_projects)
                #destination_projects.remove(s_project)
                for d_project in unselected_projects:
                    try:
                        d_path = '/Users/suvodeepmajumder/Documents/AI4SE/bellwether_comminity/data/1385/converted/' + d_project
                        _test_df = prepare_data(d_path)
                        _df_test_loc = _test_df.LOC
                        test_df = _test_df[s_cols]
                        test_df.reset_index(drop=True,inplace=True)
                        d = {'buggy': True, 'clean': False}
                        test_df['Buggy'] = test_df['Buggy'].map(d)
                        test_y = test_df.Buggy
                        test_X = test_df.drop(labels = ['Buggy'],axis = 1)
                        predicted = clf.predict(test_X)
                        _df_test_loc = test_X.LOC
                        abcd = metrices.measures(test_y,predicted,_df_test_loc)
                        F['f1'] = [abcd.calculate_f1_score()]
                        F['precision'] = [abcd.calculate_precision()]
                        F['recall'] = [abcd.calculate_recall()]
                        F['g-score'] = [abcd.get_g_score()]
                        F['d2h'] = [abcd.calculate_d2h()]
                        F['pci_20'] = [abcd.get_pci_20()]
                        F['ifa'] = [abcd.get_ifa()]
                        F['pd'] = [abcd.get_pd()]
                        F['pf'] = [abcd.get_pf()]
                        _F = copy.deepcopy(F)
                        if 'f1' not in score.keys():
                            score[d_project] = _F
                        else:
                            score[d_project]['f1'].append(F['f1'][0])
                            score[d_project]['precision'].append(F['precision'][0])
                            score[d_project]['recall'].append(F['recall'][0])
                            score[d_project]['g-score'].append(F['g-score'][0])
                            score[d_project]['d2h'].append(F['d2h'][0])
                            score[d_project]['pci_20'].append(F['pci_20'][0])
                            score[d_project]['ifa'].append(F['ifa'][0])
                            score[d_project]['pd'].append(F['pd'][0])
                            score[d_project]['pf'].append(F['pf'][0])
                    except Exception as e:
                        print("dest",d_project,e)
                        continue
            final_score[s_project] = score 
    except ArithmeticError as e:
        print("src",s_project,e)
        continue
# Out:
# firebird.csv
# dest ceps.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest pugs.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest gwittir.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest vba.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest wiquery.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest wiquery.csv index 1 is out of bounds for axis 0 with size 1
# dest simulationcraft.csv index 1 is out of bounds for axis 0 with size 1
# dest ceps.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest ceps.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest pugs.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest gwittir.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest vba.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest wiquery.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest wiquery.csv index 1 is out of bounds for axis 0 with size 1
# dest simulationcraft.csv index 1 is out of bounds for axis 0 with size 1
# dest ceps.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest ceps.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest pugs.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest gwittir.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest vba.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest wiquery.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest wiquery.csv index 1 is out of bounds for axis 0 with size 1
# dest simulationcraft.csv index 1 is out of bounds for axis 0 with size 1
# dest ceps.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest ceps.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest pugs.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest gwittir.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest vba.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest wiquery.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest wiquery.csv index 1 is out of bounds for axis 0 with size 1
# dest simulationcraft.csv index 1 is out of bounds for axis 0 with size 1
# dest ceps.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest ceps.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest pugs.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest gwittir.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest vba.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest wiquery.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest wiquery.csv index 1 is out of bounds for axis 0 with size 1
# dest simulationcraft.csv index 1 is out of bounds for axis 0 with size 1
# dest ceps.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1
# dest jactr.csv index 1 is out of bounds for axis 0 with size 1
# dest synopsis.csv index 1 is out of bounds for axis 0 with size 1
# dest scribus.csv index 1 is out of bounds for axis 0 with size 1
# dest mvt.csv index 1 is out of bounds for axis 0 with size 1
# dest jupload.csv index 1 is out of bounds for axis 0 with size 1
# dest ajqtgui.csv index 1 is out of bounds for axis 0 with size 1
# dest dbrefactor.csv index 1 is out of bounds for axis 0 with size 1
# dest veryquickwiki.csv index 1 is out of bounds for axis 0 with size 1
# dest math-game.csv index 1 is out of bounds for axis 0 with size 1

# %%
final_score
# Out:
# {'firebird.csv': {'lcdata.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.12],
#    'ifa': [7],
#    'pd': [0.0],
#    'pf': [0.0]},
#   'llcon.csv': {'f1': [0.8],
#    'precision': [0.81],
#    'recall': [0.79],
#    'g-score': [0.73],
#    'd2h': [0.5],
#    'pci_20': [0.18],
#    'ifa': [0],
#    'pd': [0.79],
#    'pf': [0.45]},
#   'gpsee.csv': {'f1': [0.53],
#    'precision': [0.4],
#    'recall': [0.77],
#    'g-score': [0.58],
#    'd2h': [0.75],
#    'pci_20': [0.24],
#    'ifa': [3],
#    'pd': [0.77],
#    'pf': [0.71]},
#   'tauruss.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [nan],
#    'd2h': [1.27],
#    'pci_20': [0.11],
#    'ifa': [8],
#    'pd': [nan],
#    'pf': [0.78]},
#   'makumba.csv': {'f1': [0.78],
#    'precision': [0.76],
#    'recall': [0.81],
#    'g-score': [0.71],
#    'd2h': [0.57],
#    'pci_20': [0.17],
#    'ifa': [0],
#    'pd': [0.81],
#    'pf': [0.53]},
#   'openi.csv': {'f1': [0.6],
#    'precision': [0.62],
#    'recall': [0.59],
#    'g-score': [0.55],
#    'd2h': [0.69],
#    'pci_20': [0.22],
#    'ifa': [2],
#    'pd': [0.59],
#    'pf': [0.56]},
#   'pure-lang.csv': {'f1': [0.52],
#    'precision': [0.38],
#    'recall': [0.86],
#    'g-score': [0.56],
#    'd2h': [0.78],
#    'pci_20': [0.2],
#    'ifa': [0],
#    'pd': [0.86],
#    'pf': [0.77]},
#   'roguelike.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.04],
#    'pci_20': [0.17],
#    'ifa': [17],
#    'pd': [0.0],
#    'pf': [0.29]},
#   'wiquery.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [nan],
#    'd2h': [1.41],
#    'pci_20': [0.0],
#    'ifa': [0],
#    'pd': [nan],
#    'pf': [1.0]},
#   'owasp-esapi-java.csv': {'f1': [0.57],
#    'precision': [0.43],
#    'recall': [0.86],
#    'g-score': [0.78],
#    'd2h': [0.44],
#    'pci_20': [0.23],
#    'ifa': [5],
#    'pd': [0.86],
#    'pf': [0.42]},
#   'voot.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.16],
#    'ifa': [42],
#    'pd': [0.0],
#    'pf': [0.0]},
#   'airhead-research.csv': {'f1': [0.85],
#    'precision': [0.92],
#    'recall': [0.8],
#    'g-score': [0.67],
#    'd2h': [0.63],
#    'pci_20': [0.16],
#    'ifa': [1],
#    'pd': [0.8],
#    'pf': [0.6]},
#   'x10.csv': {'f1': [0.5],
#    'precision': [0.33],
#    'recall': [1.0],
#    'g-score': [0.83],
#    'd2h': [0.5],
#    'pci_20': [0.2],
#    'ifa': [1],
#    'pd': [1.0],
#    'pf': [0.5]},
#   'wmii.csv': {'f1': [0.84],
#    'precision': [0.83],
#    'recall': [0.86],
#    'g-score': [0.47],
#    'd2h': [0.85],
#    'pci_20': [0.18],
#    'ifa': [1],
#    'pd': [0.86],
#    'pf': [0.83]},
#   'bungeni-editor.csv': {'f1': [0.37],
#    'precision': [0.26],
#    'recall': [0.62],
#    'g-score': [0.45],
#    'd2h': [0.86],
#    'pci_20': [0.23],
#    'ifa': [14],
#    'pd': [0.62],
#    'pf': [0.78]},
#   'openejb.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.17],
#    'pci_20': [0.17],
#    'ifa': [29],
#    'pd': [0.0],
#    'pf': [0.61]},
#   'gogglesmm.csv': {'f1': [0.7],
#    'precision': [0.59],
#    'recall': [0.87],
#    'g-score': [0.81],
#    'd2h': [0.4],
#    'pci_20': [0.21],
#    'ifa': [5],
#    'pd': [0.87],
#    'pf': [0.38]},
#   'workhub2.csv': {'f1': [0.76],
#    'precision': [0.83],
#    'recall': [0.69],
#    'g-score': [0.54],
#    'd2h': [0.78],
#    'pci_20': [0.19],
#    'ifa': [1],
#    'pd': [0.69],
#    'pf': [0.71]},
#   'mozzie.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [nan],
#    'd2h': [1.35],
#    'pci_20': [0.18],
#    'ifa': [21],
#    'pd': [nan],
#    'pf': [0.91]},
#   'gild.csv': {'f1': [0.8],
#    'precision': [0.67],
#    'recall': [1.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.0],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [1.0]},
#   'arcanea-project.csv': {'f1': [0.71],
#    'precision': [0.65],
#    'recall': [0.8],
#    'g-score': [0.68],
#    'd2h': [0.61],
#    'pci_20': [0.18],
#    'ifa': [0],
#    'pd': [0.8],
#    'pf': [0.58]},
#   'vito.csv': {'f1': [0.47],
#    'precision': [0.37],
#    'recall': [0.64],
#    'g-score': [0.54],
#    'd2h': [0.76],
#    'pci_20': [0.1],
#    'ifa': [0],
#    'pd': [0.64],
#    'pf': [0.67]},
#   'middle-man.csv': {'f1': [0.55],
#    'precision': [0.43],
#    'recall': [0.76],
#    'g-score': [0.62],
#    'd2h': [0.69],
#    'pci_20': [0.21],
#    'ifa': [0],
#    'pd': [0.76],
#    'pf': [0.65]},
#   'pernband.csv': {'f1': [0.74],
#    'precision': [0.63],
#    'recall': [0.89],
#    'g-score': [0.27],
#    'd2h': [0.94],
#    'pci_20': [0.19],
#    'ifa': [2],
#    'pd': [0.89],
#    'pf': [0.93]},
#   'aquachat.csv': {'f1': [0.33],
#    'precision': [0.5],
#    'recall': [0.25],
#    'g-score': [0.29],
#    'd2h': [0.75],
#    'pci_20': [0.15],
#    'ifa': [12],
#    'pd': [0.25],
#    'pf': [0.05]},
#   'tgl.csv': {'f1': [0.62],
#    'precision': [0.53],
#    'recall': [0.77],
#    'g-score': [0.47],
#    'd2h': [0.85],
#    'pci_20': [0.21],
#    'ifa': [9],
#    'pd': [0.77],
#    'pf': [0.82]},
#   'guitoo.csv': {'f1': [0.8],
#    'precision': [0.67],
#    'recall': [1.0],
#    'g-score': [0.71],
#    'd2h': [0.67],
#    'pci_20': [0.14],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [0.67]},
#   'vrmoo.csv': {'f1': [0.34],
#    'precision': [0.21],
#    'recall': [0.91],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.16],
#    'ifa': [4],
#    'pd': [0.91],
#    'pf': [1.0]},
#   'j4fry.csv': {'f1': [0.78],
#    'precision': [0.64],
#    'recall': [1.0],
#    'g-score': [0.93],
#    'd2h': [0.26],
#    'pci_20': [0.25],
#    'ifa': [7],
#    'pd': [1.0],
#    'pf': [0.26]},
#   'chatforte.csv': {'f1': [0.5],
#    'precision': [0.33],
#    'recall': [1.0],
#    'g-score': [0.59],
#    'd2h': [0.78],
#    'pci_20': [0.16],
#    'ifa': [1],
#    'pd': [1.0],
#    'pf': [0.78]},
#   'allacrost.csv': {'f1': [0.41],
#    'precision': [0.38],
#    'recall': [0.46],
#    'g-score': [0.49],
#    'd2h': [0.65],
#    'pci_20': [0.15],
#    'ifa': [3],
#    'pd': [0.46],
#    'pf': [0.37]},
#   'phission.csv': {'f1': [0.53],
#    'precision': [0.8],
#    'recall': [0.4],
#    'g-score': [0.45],
#    'd2h': [0.61],
#    'pci_20': [0.16],
#    'ifa': [1],
#    'pd': [0.4],
#    'pf': [0.11]},
#   'mixxx.csv': {'f1': [0.25],
#    'precision': [1.0],
#    'recall': [0.14],
#    'g-score': [0.17],
#    'd2h': [0.86],
#    'pci_20': [0.27],
#    'ifa': [3],
#    'pd': [0.14],
#    'pf': [0.0]},
#   'toop.csv': {'f1': [0.63],
#    'precision': [1.0],
#    'recall': [0.46],
#    'g-score': [0.52],
#    'd2h': [0.54],
#    'pci_20': [0.22],
#    'ifa': [0],
#    'pd': [0.46],
#    'pf': [0.0]},
#   'openwebbuilder.csv': {'f1': [0.58],
#    'precision': [0.46],
#    'recall': [0.76],
#    'g-score': [0.5],
#    'd2h': [0.82],
#    'pci_20': [0.14],
#    'ifa': [4],
#    'pd': [0.76],
#    'pf': [0.79]},
#   'google-secure-data-connector.csv': {'f1': [0.97],
#    'precision': [0.94],
#    'recall': [1.0],
#    'g-score': [0.83],
#    'd2h': [0.5],
#    'pci_20': [0.17],
#    'ifa': [1],
#    'pd': [1.0],
#    'pf': [0.5]},
#   'opencollada.csv': {'f1': [0.24],
#    'precision': [0.18],
#    'recall': [0.36],
#    'g-score': [0.38],
#    'd2h': [0.84],
#    'pci_20': [0.27],
#    'ifa': [20],
#    'pd': [0.36],
#    'pf': [0.55]},
#   'spinn3r-client.csv': {'f1': [0.54],
#    'precision': [0.58],
#    'recall': [0.5],
#    'g-score': [0.5],
#    'd2h': [0.71],
#    'pci_20': [0.17],
#    'ifa': [0],
#    'pd': [0.5],
#    'pf': [0.5]},
#   'rocket-gwt.csv': {'f1': [0.36],
#    'precision': [0.22],
#    'recall': [1.0],
#    'g-score': [0.41],
#    'd2h': [0.88],
#    'pci_20': [0.15],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [0.88]},
#   'facecart.csv': {'f1': [0.47],
#    'precision': [0.57],
#    'recall': [0.4],
#    'g-score': [0.45],
#    'd2h': [0.62],
#    'pci_20': [0.23],
#    'ifa': [2],
#    'pd': [0.4],
#    'pf': [0.14]},
#   'swecr.csv': {'f1': [0.23],
#    'precision': [0.13],
#    'recall': [1.0],
#    'g-score': [0.57],
#    'd2h': [0.79],
#    'pci_20': [0.17],
#    'ifa': [10],
#    'pd': [1.0],
#    'pf': [0.79]},
#   'apophenia.csv': {'f1': [0.87],
#    'precision': [0.94],
#    'recall': [0.81],
#    'g-score': [0.0],
#    'd2h': [1.02],
#    'pci_20': [0.09],
#    'ifa': [0],
#    'pd': [0.81],
#    'pf': [1.0]},
#   'nemerle.csv': {'f1': [0.8],
#    'precision': [1.0],
#    'recall': [0.67],
#    'g-score': [0.72],
#    'd2h': [0.33],
#    'pci_20': [0.17],
#    'ifa': [2],
#    'pd': [0.67],
#    'pf': [0.0]},
#   'android-scripting.csv': {'f1': [0.41],
#    'precision': [0.27],
#    'recall': [0.89],
#    'g-score': [0.39],
#    'd2h': [0.89],
#    'pci_20': [0.21],
#    'ifa': [6],
#    'pd': [0.89],
#    'pf': [0.88]},
#   'jaffa.csv': {'f1': [0.3],
#    'precision': [0.19],
#    'recall': [0.75],
#    'g-score': [0.0],
#    'd2h': [1.03],
#    'pci_20': [0.18],
#    'ifa': [9],
#    'pd': [0.75],
#    'pf': [1.0]},
#   'javapalm.csv': {'f1': [0.47],
#    'precision': [0.31],
#    'recall': [1.0],
#    'g-score': [0.17],
#    'd2h': [0.96],
#    'pci_20': [0.2],
#    'ifa': [14],
#    'pd': [1.0],
#    'pf': [0.96]},
#   'webswell.csv': {'f1': [0.56],
#    'precision': [0.44],
#    'recall': [0.78],
#    'g-score': [0.68],
#    'd2h': [0.6],
#    'pci_20': [0.16],
#    'ifa': [1],
#    'pd': [0.78],
#    'pf': [0.56]},
#   'uml.csv': {'f1': [0.85],
#    'precision': [0.82],
#    'recall': [0.88],
#    'g-score': [0.59],
#    'd2h': [0.76],
#    'pci_20': [0.2],
#    'ifa': [0],
#    'pd': [0.88],
#    'pf': [0.75]},
#   'gauche.csv': {'f1': [0.42],
#    'precision': [0.26],
#    'recall': [1.0],
#    'g-score': [0.38],
#    'd2h': [0.89],
#    'pci_20': [0.27],
#    'ifa': [14],
#    'pd': [1.0],
#    'pf': [0.89]},
#   'route-me.csv': {'f1': [0.32],
#    'precision': [0.38],
#    'recall': [0.27],
#    'g-score': [0.29],
#    'd2h': [0.92],
#    'pci_20': [0.2],
#    'ifa': [4],
#    'pd': [0.27],
#    'pf': [0.56]},
#   'jacareto.csv': {'f1': [0.07],
#    'precision': [0.04],
#    'recall': [0.5],
#    'g-score': [0.41],
#    'd2h': [0.91],
#    'pci_20': [0.22],
#    'ifa': [11],
#    'pd': [0.5],
#    'pf': [0.76]},
#   'gridbusbroker.csv': {'f1': [0.56],
#    'precision': [0.44],
#    'recall': [0.79],
#    'g-score': [0.71],
#    'd2h': [0.54],
#    'pci_20': [0.14],
#    'ifa': [1],
#    'pd': [0.79],
#    'pf': [0.5]},
#   'unistat.csv': {'f1': [0.25],
#    'precision': [0.14],
#    'recall': [1.0],
#    'g-score': [0.75],
#    'd2h': [0.62],
#    'pci_20': [0.22],
#    'ifa': [4],
#    'pd': [1.0],
#    'pf': [0.62]},
#   'freedots.csv': {'f1': [0.29],
#    'precision': [0.17],
#    'recall': [1.0],
#    'g-score': [0.75],
#    'd2h': [0.62],
#    'pci_20': [0.22],
#    'ifa': [5],
#    'pd': [1.0],
#    'pf': [0.62]},
#   'zxtune.csv': {'f1': [0.53],
#    'precision': [0.69],
#    'recall': [0.43],
#    'g-score': [0.35],
#    'd2h': [0.98],
#    'pci_20': [0.19],
#    'ifa': [2],
#    'pd': [0.43],
#    'pf': [0.8]},
#   'rails.csv': {'f1': [0.71],
#    'precision': [0.83],
#    'recall': [0.62],
#    'g-score': [0.64],
#    'd2h': [0.45],
#    'pci_20': [0.17],
#    'ifa': [2],
#    'pd': [0.62],
#    'pf': [0.25]},
#   'replicatorg.csv': {'f1': [0.46],
#    'precision': [0.31],
#    'recall': [0.9],
#    'g-score': [0.65],
#    'd2h': [0.7],
#    'pci_20': [0.15],
#    'ifa': [0],
#    'pd': [0.9],
#    'pf': [0.69]},
#   'moviejukebox.csv': {'f1': [0.84],
#    'precision': [0.85],
#    'recall': [0.83],
#    'g-score': [0.0],
#    'd2h': [1.01],
#    'pci_20': [0.17],
#    'ifa': [0],
#    'pd': [0.83],
#    'pf': [1.0]},
#   'wifidog.csv': {'f1': [0.79],
#    'precision': [0.73],
#    'recall': [0.85],
#    'g-score': [0.52],
#    'd2h': [0.81],
#    'pci_20': [0.17],
#    'ifa': [1],
#    'pd': [0.85],
#    'pf': [0.8]},
#   'grok.csv': {'f1': [0.71],
#    'precision': [0.65],
#    'recall': [0.79],
#    'g-score': [0.75],
#    'd2h': [0.44],
#    'pci_20': [0.15],
#    'ifa': [0],
#    'pd': [0.79],
#    'pf': [0.38]},
#   'google-guice.csv': {'f1': [0.79],
#    'precision': [0.9],
#    'recall': [0.7],
#    'g-score': [0.57],
#    'd2h': [0.73],
#    'pci_20': [0.17],
#    'ifa': [0],
#    'pd': [0.7],
#    'pf': [0.67]},
#   'beepmp.csv': {'f1': [0.67],
#    'precision': [0.89],
#    'recall': [0.53],
#    'g-score': [0.57],
#    'd2h': [0.51],
#    'pci_20': [0.15],
#    'ifa': [1],
#    'pd': [0.53],
#    'pf': [0.2]},
#   'jrds.csv': {'f1': [0.54],
#    'precision': [0.39],
#    'recall': [0.89],
#    'g-score': [0.48],
#    'd2h': [0.84],
#    'pci_20': [0.19],
#    'ifa': [6],
#    'pd': [0.89],
#    'pf': [0.83]},
#   'blackholespam.csv': {'f1': [0.67],
#    'precision': [0.57],
#    'recall': [0.8],
#    'g-score': [0.77],
#    'd2h': [0.39],
#    'pci_20': [0.07],
#    'ifa': [1],
#    'pd': [0.8],
#    'pf': [0.33]},
#   'mockcpp.csv': {'f1': [0.18],
#    'precision': [0.17],
#    'recall': [0.2],
#    'g-score': [0.23],
#    'd2h': [0.85],
#    'pci_20': [0.32],
#    'ifa': [16],
#    'pd': [0.2],
#    'pf': [0.29]},
#   'tdt.csv': {'f1': [0.1],
#    'precision': [0.05],
#    'recall': [1.0],
#    'g-score': [0.36],
#    'd2h': [0.9],
#    'pci_20': [0.18],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [0.9]},
#   'mosesdecoder.csv': {'f1': [0.18],
#    'precision': [0.14],
#    'recall': [0.25],
#    'g-score': [0.27],
#    'd2h': [0.96],
#    'pci_20': [0.14],
#    'ifa': [6],
#    'pd': [0.25],
#    'pf': [0.6]},
#   'freemarker.csv': {'f1': [0.47],
#    'precision': [0.31],
#    'recall': [1.0],
#    'g-score': [0.27],
#    'd2h': [0.93],
#    'pci_20': [0.17],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [0.93]},
#   'cs-javaphp.csv': {'f1': [0.75],
#    'precision': [0.6],
#    'recall': [1.0],
#    'g-score': [0.56],
#    'd2h': [0.8],
#    'pci_20': [0.18],
#    'ifa': [1],
#    'pd': [1.0],
#    'pf': [0.8]},
#   'aost.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.08],
#    'pci_20': [0.23],
#    'ifa': [12],
#    'pd': [0.0],
#    'pf': [0.4]},
#   'bitpeddler.csv': {'f1': [0.31],
#    'precision': [0.19],
#    'recall': [1.0],
#    'g-score': [0.65],
#    'd2h': [0.73],
#    'pci_20': [0.14],
#    'ifa': [2],
#    'pd': [1.0],
#    'pf': [0.73]},
#   'reportmaster.csv': {'f1': [0.4],
#    'precision': [0.29],
#    'recall': [0.67],
#    'g-score': [0.64],
#    'd2h': [0.58],
#    'pci_20': [0.2],
#    'ifa': [0],
#    'pd': [0.67],
#    'pf': [0.47]},
#   'systats.csv': {'f1': [0.44],
#    'precision': [0.36],
#    'recall': [0.57],
#    'g-score': [0.58],
#    'd2h': [0.58],
#    'pci_20': [0.12],
#    'ifa': [2],
#    'pd': [0.57],
#    'pf': [0.39]},
#   'irad.csv': {'f1': [0.42],
#    'precision': [0.31],
#    'recall': [0.62],
#    'g-score': [0.62],
#    'd2h': [0.52],
#    'pci_20': [0.32],
#    'ifa': [0],
#    'pd': [0.62],
#    'pf': [0.37]},
#   'robocup-msl.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.0],
#    'ifa': [1],
#    'pd': [0.0],
#    'pf': [0.0]},
#   'hawkscope.csv': {'f1': [0.67],
#    'precision': [0.68],
#    'recall': [0.65],
#    'g-score': [0.64],
#    'd2h': [0.53],
#    'pci_20': [0.2],
#    'ifa': [0],
#    'pd': [0.65],
#    'pf': [0.4]},
#   'openstreaming.csv': {'f1': [0.38],
#    'precision': [0.25],
#    'recall': [0.8],
#    'g-score': [0.29],
#    'd2h': [0.94],
#    'pci_20': [0.17],
#    'ifa': [6],
#    'pd': [0.8],
#    'pf': [0.92]},
#   'clisp.csv': {'f1': [0.67],
#    'precision': [1.0],
#    'recall': [0.5],
#    'g-score': [0.56],
#    'd2h': [0.5],
#    'pci_20': [0.0],
#    'ifa': [0],
#    'pd': [0.5],
#    'pf': [0.0]},
#   'ncut.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.0],
#    'ifa': [1],
#    'pd': [0.0],
#    'pf': [0.0]},
#   'japi.csv': {'f1': [0.57],
#    'precision': [0.44],
#    'recall': [0.8],
#    'g-score': [0.59],
#    'd2h': [0.74],
#    'pci_20': [0.17],
#    'ifa': [2],
#    'pd': [0.8],
#    'pf': [0.71]},
#   'opengrads.csv': {'f1': [0.23],
#    'precision': [0.13],
#    'recall': [0.8],
#    'g-score': [0.62],
#    'd2h': [0.7],
#    'pci_20': [0.16],
#    'ifa': [18],
#    'pd': [0.8],
#    'pf': [0.67]},
#   'processing.csv': {'f1': [0.81],
#    'precision': [1.0],
#    'recall': [0.68],
#    'g-score': [0.73],
#    'd2h': [0.32],
#    'pci_20': [0.2],
#    'ifa': [1],
#    'pd': [0.68],
#    'pf': [0.0]},
#   'neudist.csv': {'f1': [0.2],
#    'precision': [0.12],
#    'recall': [0.67],
#    'g-score': [0.59],
#    'd2h': [0.69],
#    'pci_20': [0.21],
#    'ifa': [2],
#    'pd': [0.67],
#    'pf': [0.6]},
#   'nano.csv': {'f1': [0.9],
#    'precision': [1.0],
#    'recall': [0.82],
#    'g-score': [0.85],
#    'd2h': [0.18],
#    'pci_20': [0.13],
#    'ifa': [1],
#    'pd': [0.82],
#    'pf': [0.0]},
#   'mwengine.csv': {'f1': [0.35],
#    'precision': [0.21],
#    'recall': [1.0],
#    'g-score': [0.86],
#    'd2h': [0.45],
#    'pci_20': [0.16],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [0.45]},
#   'protomol.csv': {'f1': [0.18],
#    'precision': [0.12],
#    'recall': [0.33],
#    'g-score': [0.37],
#    'd2h': [0.72],
#    'pci_20': [0.14],
#    'ifa': [6],
#    'pd': [0.33],
#    'pf': [0.28]},
#   'vcgviewer.csv': {'f1': [0.75],
#    'precision': [1.0],
#    'recall': [0.6],
#    'g-score': [0.65],
#    'd2h': [0.4],
#    'pci_20': [0.08],
#    'ifa': [0],
#    'pd': [0.6],
#    'pf': [0.0]},
#   'grailrtls.csv': {'f1': [0.6],
#    'precision': [0.56],
#    'recall': [0.64],
#    'g-score': [0.55],
#    'd2h': [0.73],
#    'pci_20': [0.2],
#    'ifa': [5],
#    'pd': [0.64],
#    'pf': [0.64]},
#   'simulationcraft.csv': {'f1': [0.92],
#    'precision': [1.0],
#    'recall': [0.86],
#    'g-score': [nan],
#    'd2h': [0.14],
#    'pci_20': [0.14],
#    'ifa': [0],
#    'pd': [0.86],
#    'pf': [nan]},
#   'bfin-test-proj.csv': {'f1': [0.47],
#    'precision': [0.4],
#    'recall': [0.57],
#    'g-score': [0.61],
#    'd2h': [0.47],
#    'pci_20': [0.15],
#    'ifa': [16],
#    'pd': [0.57],
#    'pf': [0.18]},
#   'jlibrary.csv': {'f1': [0.26],
#    'precision': [0.17],
#    'recall': [0.6],
#    'g-score': [0.6],
#    'd2h': [0.57],
#    'pci_20': [0.12],
#    'ifa': [7],
#    'pd': [0.6],
#    'pf': [0.41]},
#   'jsbsim.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.17],
#    'ifa': [40],
#    'pd': [0.0],
#    'pf': [0.04]},
#   'loserjabber.csv': {'f1': [0.9],
#    'precision': [1.0],
#    'recall': [0.81],
#    'g-score': [0.84],
#    'd2h': [0.19],
#    'pci_20': [0.14],
#    'ifa': [0],
#    'pd': [0.81],
#    'pf': [0.0]},
#   'nextobjects.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.2],
#    'pci_20': [0.14],
#    'ifa': [6],
#    'pd': [0.0],
#    'pf': [0.67]},
#   'tinycad.csv': {'f1': [0.2],
#    'precision': [0.14],
#    'recall': [0.33],
#    'g-score': [0.37],
#    'd2h': [0.69],
#    'pci_20': [0.21],
#    'ifa': [17],
#    'pd': [0.33],
#    'pf': [0.19]},
#   'linux-mips.csv': {'f1': [0.24],
#    'precision': [0.29],
#    'recall': [0.2],
#    'g-score': [0.23],
#    'd2h': [0.85],
#    'pci_20': [0.19],
#    'ifa': [10],
#    'pd': [0.2],
#    'pf': [0.29]},
#   'pokersource.csv': {'f1': [0.69],
#    'precision': [0.59],
#    'recall': [0.83],
#    'g-score': [0.71],
#    'd2h': [0.56],
#    'pci_20': [0.16],
#    'ifa': [0],
#    'pd': [0.83],
#    'pf': [0.54]},
#   'bdwgc.csv': {'f1': [0.5],
#    'precision': [1.0],
#    'recall': [0.33],
#    'g-score': [0.38],
#    'd2h': [0.67],
#    'pci_20': [0.11],
#    'ifa': [3],
#    'pd': [0.33],
#    'pf': [0.0]},
#   'macaulay2.csv': {'f1': [0.21],
#    'precision': [0.25],
#    'recall': [0.18],
#    'g-score': [0.21],
#    'd2h': [0.89],
#    'pci_20': [0.21],
#    'ifa': [10],
#    'pd': [0.18],
#    'pf': [0.35]},
#   'moneymanagerex.csv': {'f1': [1.0],
#    'precision': [1.0],
#    'recall': [1.0],
#    'g-score': [1.0],
#    'd2h': [0.0],
#    'pci_20': [0.2],
#    'ifa': [1],
#    'pd': [1.0],
#    'pf': [0.0]},
#   'wxerlang.csv': {'f1': [0.82],
#    'precision': [0.88],
#    'recall': [0.78],
#    'g-score': [0.79],
#    'd2h': [0.26],
#    'pci_20': [0.06],
#    'ifa': [0],
#    'pd': [0.78],
#    'pf': [0.14]},
#   'syllable.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.28],
#    'pci_20': [0.29],
#    'ifa': [6],
#    'pd': [0.0],
#    'pf': [0.8]},
#   'opentac2.csv': {'f1': [0.62],
#    'precision': [0.45],
#    'recall': [1.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.15],
#    'ifa': [2],
#    'pd': [1.0],
#    'pf': [1.0]},
#   'geoserver.csv': {'f1': [0.36],
#    'precision': [0.27],
#    'recall': [0.57],
#    'g-score': [0.51],
#    'd2h': [0.78],
#    'pci_20': [0.21],
#    'ifa': [0],
#    'pd': [0.57],
#    'pf': [0.65]},
#   'carbonkernel.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.25],
#    'ifa': [3],
#    'pd': [0.0],
#    'pf': [0.0]},
#   'pmsqueak.csv': {'f1': [0.82],
#    'precision': [0.79],
#    'recall': [0.85],
#    'g-score': [0.0],
#    'd2h': [1.01],
#    'pci_20': [0.15],
#    'ifa': [0],
#    'pd': [0.85],
#    'pf': [1.0]},
#   'dryad.csv': {'f1': [0.18],
#    'precision': [0.1],
#    'recall': [1.0],
#    'g-score': [0.36],
#    'd2h': [0.9],
#    'pci_20': [0.09],
#    'ifa': [1],
#    'pd': [1.0],
#    'pf': [0.9]},
#   'tinymux.csv': {'f1': [0.8],
#    'precision': [1.0],
#    'recall': [0.67],
#    'g-score': [0.72],
#    'd2h': [0.33],
#    'pci_20': [0.0],
#    'ifa': [1],
#    'pd': [0.67],
#    'pf': [0.0]},
#   'aqsis.csv': {'f1': [0.43],
#    'precision': [0.43],
#    'recall': [0.43],
#    'g-score': [0.45],
#    'd2h': [0.72],
#    'pci_20': [0.19],
#    'ifa': [0],
#    'pd': [0.43],
#    'pf': [0.44]},
#   'iky.csv': {'f1': [0.76],
#    'precision': [0.84],
#    'recall': [0.7],
#    'g-score': [0.72],
#    'd2h': [0.37],
#    'pci_20': [0.22],
#    'ifa': [7],
#    'pd': [0.7],
#    'pf': [0.21]},
#   'mindquarry-desktop.csv': {'f1': [0.71],
#    'precision': [0.6],
#    'recall': [0.86],
#    'g-score': [0.78],
#    'd2h': [0.47],
#    'pci_20': [0.12],
#    'ifa': [0],
#    'pd': [0.86],
#    'pf': [0.44]},
#   'wockets.csv': {'f1': [0.77],
#    'precision': [0.8],
#    'recall': [0.74],
#    'g-score': [0.62],
#    'd2h': [0.68],
#    'pci_20': [0.11],
#    'ifa': [0],
#    'pd': [0.74],
#    'pf': [0.62]},
#   'villonanny.csv': {'f1': [0.59],
#    'precision': [0.42],
#    'recall': [1.0],
#    'g-score': [0.36],
#    'd2h': [0.9],
#    'pci_20': [0.18],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [0.9]},
#   'zumastor.csv': {'f1': [0.86],
#    'precision': [0.75],
#    'recall': [1.0],
#    'g-score': [0.83],
#    'd2h': [0.5],
#    'pci_20': [0.2],
#    'ifa': [2],
#    'pd': [1.0],
#    'pf': [0.5]},
#   'unigrok.csv': {'f1': [0.67],
#    'precision': [0.5],
#    'recall': [1.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.18],
#    'ifa': [7],
#    'pd': [1.0],
#    'pf': [1.0]},
#   'sitestarter.csv': {'f1': [0.73],
#    'precision': [0.67],
#    'recall': [0.82],
#    'g-score': [0.75],
#    'd2h': [0.47],
#    'pci_20': [0.16],
#    'ifa': [1],
#    'pd': [0.82],
#    'pf': [0.43]},
#   'molybdenum.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [nan],
#    'd2h': [1.1],
#    'pci_20': [0.09],
#    'ifa': [10],
#    'pd': [nan],
#    'pf': [0.45]},
#   'bluemusic.csv': {'f1': [0.6],
#    'precision': [0.43],
#    'recall': [1.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.14],
#    'ifa': [1],
#    'pd': [1.0],
#    'pf': [1.0]},
#   'mnemisis.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.0],
#    'ifa': [5],
#    'pd': [0.0],
#    'pf': [0.0]},
#   'rvdesignpattern.csv': {'f1': [0.5],
#    'precision': [1.0],
#    'recall': [0.33],
#    'g-score': [0.38],
#    'd2h': [0.67],
#    'pci_20': [0.25],
#    'ifa': [2],
#    'pd': [0.33],
#    'pf': [0.0]},
#   'unigelaber.csv': {'f1': [0.36],
#    'precision': [0.8],
#    'recall': [0.24],
#    'g-score': [0.28],
#    'd2h': [0.77],
#    'pci_20': [0.13],
#    'ifa': [4],
#    'pd': [0.24],
#    'pf': [0.08]},
#   'codewave.csv': {'f1': [0.71],
#    'precision': [0.68],
#    'recall': [0.75],
#    'g-score': [0.71],
#    'd2h': [0.48],
#    'pci_20': [0.3],
#    'ifa': [1],
#    'pd': [0.75],
#    'pf': [0.41]},
#   'glsof.csv': {'f1': [0.5],
#    'precision': [0.42],
#    'recall': [0.61],
#    'g-score': [0.54],
#    'd2h': [0.74],
#    'pci_20': [0.24],
#    'ifa': [7],
#    'pd': [0.61],
#    'pf': [0.62]},
#   'microemulator.csv': {'f1': [0.43],
#    'precision': [0.31],
#    'recall': [0.73],
#    'g-score': [0.57],
#    'd2h': [0.74],
#    'pci_20': [0.22],
#    'ifa': [0],
#    'pd': [0.73],
#    'pf': [0.69]},
#   'nsclspectcl.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.12],
#    'ifa': [7],
#    'pd': [0.0],
#    'pf': [0.0]},
#   'any23.csv': {'f1': [0.5],
#    'precision': [1.0],
#    'recall': [0.33],
#    'g-score': [0.38],
#    'd2h': [0.67],
#    'pci_20': [0.16],
#    'ifa': [0],
#    'pd': [0.33],
#    'pf': [0.0]},
#   'textgrounder.csv': {'f1': [0.79],
#    'precision': [0.73],
#    'recall': [0.85],
#    'g-score': [0.75],
#    'd2h': [0.52],
#    'pci_20': [0.19],
#    'ifa': [0],
#    'pd': [0.85],
#    'pf': [0.5]},
#   'jmlspecs.csv': {'f1': [0.44],
#    'precision': [0.29],
#    'recall': [1.0],
#    'g-score': [0.93],
#    'd2h': [0.26],
#    'pci_20': [0.1],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [0.26]},
#   'gfs.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.01],
#    'pci_20': [0.19],
#    'ifa': [25],
#    'pd': [0.0],
#    'pf': [0.12]},
#   'bripper.csv': {'f1': [0.42],
#    'precision': [0.82],
#    'recall': [0.28],
#    'g-score': [0.32],
#    'd2h': [0.79],
#    'pci_20': [0.11],
#    'ifa': [2],
#    'pd': [0.28],
#    'pf': [0.33]},
#   'anyconfig.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.23],
#    'ifa': [30],
#    'pd': [0.0],
#    'pf': [0.0]},
#   'eid-mw.csv': {'f1': [0.5],
#    'precision': [0.33],
#    'recall': [1.0],
#    'g-score': [0.92],
#    'd2h': [0.29],
#    'pci_20': [0.12],
#    'ifa': [2],
#    'pd': [1.0],
#    'pf': [0.29]},
#   'hugin.csv': {'f1': [0.67],
#    'precision': [0.62],
#    'recall': [0.72],
#    'g-score': [0.71],
#    'd2h': [0.41],
#    'pci_20': [0.16],
#    'ifa': [3],
#    'pd': [0.72],
#    'pf': [0.31]},
#   'boost-log.csv': {'f1': [0.34],
#    'precision': [0.23],
#    'recall': [0.71],
#    'g-score': [0.65],
#    'd2h': [0.59],
#    'pci_20': [0.17],
#    'ifa': [7],
#    'pd': [0.71],
#    'pf': [0.52]},
#   'ast.csv': {'f1': [0.41],
#    'precision': [0.28],
#    'recall': [0.8],
#    'g-score': [0.31],
#    'd2h': [0.93],
#    'pci_20': [0.15],
#    'ifa': [0],
#    'pd': [0.8],
#    'pf': [0.91]},
#   'farsight.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.12],
#    'ifa': [15],
#    'pd': [0.0],
#    'pf': [0.0]},
#   'transdroid.csv': {'f1': [0.73],
#    'precision': [0.63],
#    'recall': [0.86],
#    'g-score': [0.71],
#    'd2h': [0.6],
#    'pci_20': [0.19],
#    'ifa': [1],
#    'pd': [0.86],
#    'pf': [0.58]},
#   'actiongame.csv': {'f1': [0.82],
#    'precision': [0.86],
#    'recall': [0.79],
#    'g-score': [0.68],
#    'd2h': [0.59],
#    'pci_20': [0.19],
#    'ifa': [4],
#    'pd': [0.79],
#    'pf': [0.56]},
#   'gcsaleve.csv': {'f1': [0.18],
#    'precision': [0.12],
#    'recall': [0.33],
#    'g-score': [0.37],
#    'd2h': [0.71],
#    'pci_20': [0.21],
#    'ifa': [31],
#    'pd': [0.33],
#    'pf': [0.23]},
#   'welly.csv': {'f1': [0.75],
#    'precision': [0.75],
#    'recall': [0.75],
#    'g-score': [0.77],
#    'd2h': [0.29],
#    'pci_20': [0.27],
#    'ifa': [5],
#    'pd': [0.75],
#    'pf': [0.14]},
#   'scintilla.csv': {'f1': [0.52],
#    'precision': [0.36],
#    'recall': [0.92],
#    'g-score': [0.56],
#    'd2h': [0.78],
#    'pci_20': [0.23],
#    'ifa': [3],
#    'pd': [0.92],
#    'pf': [0.78]},
#   'libfreedom.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.09],
#    'pci_20': [0.17],
#    'ifa': [23],
#    'pd': [0.0],
#    'pf': [0.43]},
#   'amrc.csv': {'f1': [0.33],
#    'precision': [0.2],
#    'recall': [0.89],
#    'g-score': [0.32],
#    'd2h': [0.92],
#    'pci_20': [0.16],
#    'ifa': [1],
#    'pd': [0.89],
#    'pf': [0.91]},
#   'gwtchismes.csv': {'f1': [0.82],
#    'precision': [0.9],
#    'recall': [0.75],
#    'g-score': [0.68],
#    'd2h': [0.56],
#    'pci_20': [0.14],
#    'ifa': [1],
#    'pd': [0.75],
#    'pf': [0.5]},
#   'bonkenc.csv': {'f1': [0.12],
#    'precision': [0.33],
#    'recall': [0.08],
#    'g-score': [0.1],
#    'd2h': [0.95],
#    'pci_20': [0.23],
#    'ifa': [7],
#    'pd': [0.08],
#    'pf': [0.22]},
#   'ghostscript.csv': {'f1': [0.4],
#    'precision': [0.67],
#    'recall': [0.29],
#    'g-score': [0.32],
#    'd2h': [0.87],
#    'pci_20': [0.22],
#    'ifa': [14],
#    'pd': [0.29],
#    'pf': [0.5]},
#   'sdscsyslog.csv': {'f1': [0.36],
#    'precision': [0.75],
#    'recall': [0.24],
#    'g-score': [0.0],
#    'd2h': [1.26],
#    'pci_20': [0.19],
#    'ifa': [2],
#    'pd': [0.24],
#    'pf': [1.0]},
#   'ayam.csv': {'f1': [0.62],
#    'precision': [0.5],
#    'recall': [0.8],
#    'g-score': [0.81],
#    'd2h': [0.25],
#    'pci_20': [0.19],
#    'ifa': [9],
#    'pd': [0.8],
#    'pf': [0.15]},
#   'ksi.csv': {'f1': [0.22],
#    'precision': [1.0],
#    'recall': [0.12],
#    'g-score': [0.15],
#    'd2h': [0.88],
#    'pci_20': [0.23],
#    'ifa': [13],
#    'pd': [0.12],
#    'pf': [0.0]},
#   'kisdnmon.csv': {'f1': [0.15],
#    'precision': [0.08],
#    'recall': [1.0],
#    'g-score': [0.54],
#    'd2h': [0.81],
#    'pci_20': [0.24],
#    'ifa': [6],
#    'pd': [1.0],
#    'pf': [0.81]},
#   'nutch.csv': {'f1': [0.57],
#    'precision': [0.42],
#    'recall': [0.88],
#    'g-score': [0.57],
#    'd2h': [0.77],
#    'pci_20': [0.15],
#    'ifa': [0],
#    'pd': [0.88],
#    'pf': [0.76]},
#   'jikesrvm.csv': {'f1': [0.46],
#    'precision': [0.42],
#    'recall': [0.5],
#    'g-score': [0.49],
#    'd2h': [0.74],
#    'pci_20': [0.25],
#    'ifa': [9],
#    'pd': [0.5],
#    'pf': [0.55]},
#   'audela.csv': {'f1': [0.33],
#    'precision': [0.2],
#    'recall': [1.0],
#    'g-score': [0.89],
#    'd2h': [0.38],
#    'pci_20': [0.14],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [0.38]},
#   'ooccollider.csv': {'f1': [0.36],
#    'precision': [0.23],
#    'recall': [0.88],
#    'g-score': [0.37],
#    'd2h': [0.9],
#    'pci_20': [0.2],
#    'ifa': [4],
#    'pd': [0.88],
#    'pf': [0.89]},
#   'coefficient.csv': {'f1': [0.15],
#    'precision': [0.08],
#    'recall': [1.0],
#    'g-score': [0.57],
#    'd2h': [0.79],
#    'pci_20': [0.2],
#    'ifa': [10],
#    'pd': [1.0],
#    'pf': [0.79]},
#   'gwittir.csv': {'f1': [0.86],
#    'precision': [1.0],
#    'recall': [0.75],
#    'g-score': [nan],
#    'd2h': [0.25],
#    'pci_20': [0.12],
#    'ifa': [0],
#    'pd': [0.75],
#    'pf': [nan]},
#   'google-enterprise-connector-manager.csv': {'f1': [0.78],
#    'precision': [0.86],
#    'recall': [0.71],
#    'g-score': [0.65],
#    'd2h': [0.58],
#    'pci_20': [0.16],
#    'ifa': [2],
#    'pd': [0.71],
#    'pf': [0.5]},
#   'lyophilizer.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [nan],
#    'd2h': [1.41],
#    'pci_20': [0.0],
#    'ifa': [0],
#    'pd': [nan],
#    'pf': [1.0]},
#   'digital-vita.csv': {'f1': [0.55],
#    'precision': [0.38],
#    'recall': [1.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.12],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [1.0]},
#   'bossogg.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.09],
#    'pci_20': [0.13],
#    'ifa': [14],
#    'pd': [0.0],
#    'pf': [0.43]},
#   'cpcsdk.csv': {'f1': [0.59],
#    'precision': [0.48],
#    'recall': [0.79],
#    'g-score': [0.59],
#    'd2h': [0.74],
#    'pci_20': [0.16],
#    'ifa': [3],
#    'pd': [0.79],
#    'pf': [0.71]},
#   'chopshop-166.csv': {'f1': [0.73],
#    'precision': [0.92],
#    'recall': [0.61],
#    'g-score': [0.62],
#    'd2h': [0.51],
#    'pci_20': [0.24],
#    'ifa': [0],
#    'pd': [0.61],
#    'pf': [0.33]},
#   'freeboogie.csv': {'f1': [0.56],
#    'precision': [0.42],
#    'recall': [0.83],
#    'g-score': [0.69],
#    'd2h': [0.61],
#    'pci_20': [0.11],
#    'ifa': [0],
#    'pd': [0.83],
#    'pf': [0.58]},
#   'bluelist.csv': {'f1': [0.4],
#    'precision': [1.0],
#    'recall': [0.25],
#    'g-score': [0.29],
#    'd2h': [0.75],
#    'pci_20': [0.21],
#    'ifa': [4],
#    'pd': [0.25],
#    'pf': [0.0]},
#   'cryptopp.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [nan],
#    'd2h': [1.0],
#    'pci_20': [0.0],
#    'ifa': [3],
#    'pd': [0.0],
#    'pf': [nan]},
#   'gpsvp.csv': {'f1': [0.37],
#    'precision': [0.25],
#    'recall': [0.71],
#    'g-score': [0.67],
#    'd2h': [0.53],
#    'pci_20': [0.17],
#    'ifa': [11],
#    'pd': [0.71],
#    'pf': [0.44]},
#   'solfec.csv': {'f1': [0.79],
#    'precision': [0.69],
#    'recall': [0.94],
#    'g-score': [0.27],
#    'd2h': [0.93],
#    'pci_20': [0.2],
#    'ifa': [0],
#    'pd': [0.94],
#    'pf': [0.93]},
#   'trap-gen.csv': {'f1': [0.71],
#    'precision': [0.62],
#    'recall': [0.83],
#    'g-score': [0.57],
#    'd2h': [0.77],
#    'pci_20': [0.2],
#    'ifa': [0],
#    'pd': [0.83],
#    'pf': [0.75]},
#   'vba.csv': {'f1': [0.5],
#    'precision': [1.0],
#    'recall': [0.33],
#    'g-score': [nan],
#    'd2h': [0.67],
#    'pci_20': [0.0],
#    'ifa': [1],
#    'pd': [0.33],
#    'pf': [nan]},
#   'od1n.csv': {'f1': [0.47],
#    'precision': [0.35],
#    'recall': [0.75],
#    'g-score': [0.67],
#    'd2h': [0.59],
#    'pci_20': [0.14],
#    'ifa': [0],
#    'pd': [0.75],
#    'pf': [0.53]},
#   'premake.csv': {'f1': [1.0],
#    'precision': [1.0],
#    'recall': [1.0],
#    'g-score': [1.0],
#    'd2h': [0.0],
#    'pci_20': [0.33],
#    'ifa': [2],
#    'pd': [1.0],
#    'pf': [0.0]},
#   'moreforcpp.csv': {'f1': [0.53],
#    'precision': [0.5],
#    'recall': [0.57],
#    'g-score': [0.59],
#    'd2h': [0.52],
#    'pci_20': [0.19],
#    'ifa': [8],
#    'pd': [0.57],
#    'pf': [0.29]},
#   'prolix.csv': {'f1': [0.52],
#    'precision': [0.64],
#    'recall': [0.44],
#    'g-score': [0.47],
#    'd2h': [0.65],
#    'pci_20': [0.25],
#    'ifa': [7],
#    'pd': [0.44],
#    'pf': [0.33]},
#   'opensocial-development-environment.csv': {'f1': [0.52],
#    'precision': [0.4],
#    'recall': [0.73],
#    'g-score': [0.4],
#    'd2h': [0.9],
#    'pci_20': [0.2],
#    'ifa': [0],
#    'pd': [0.73],
#    'pf': [0.86]},
#   'mvccontrib.csv': {'f1': [0.27],
#    'precision': [0.16],
#    'recall': [0.88],
#    'g-score': [0.29],
#    'd2h': [0.93],
#    'pci_20': [0.17],
#    'ifa': [9],
#    'pd': [0.88],
#    'pf': [0.92]},
#   'coldstore.csv': {'f1': [0.31],
#    'precision': [0.19],
#    'recall': [0.83],
#    'g-score': [0.7],
#    'd2h': [0.59],
#    'pci_20': [0.16],
#    'ifa': [1],
#    'pd': [0.83],
#    'pf': [0.57]},
#   'xradar.csv': {'f1': [0.61],
#    'precision': [0.47],
#    'recall': [0.88],
#    'g-score': [0.7],
#    'd2h': [0.63],
#    'pci_20': [0.14],
#    'ifa': [0],
#    'pd': [0.88],
#    'pf': [0.62]},
#   'freecivac.csv': {'f1': [0.67],
#    'precision': [0.56],
#    'recall': [0.82],
#    'g-score': [0.63],
#    'd2h': [0.69],
#    'pci_20': [0.21],
#    'ifa': [6],
#    'pd': [0.82],
#    'pf': [0.67]},
#   'sirat.csv': {'f1': [0.1],
#    'precision': [0.05],
#    'recall': [1.0],
#    'g-score': [0.45],
#    'd2h': [0.86],
#    'pci_20': [0.22],
#    'ifa': [10],
#    'pd': [1.0],
#    'pf': [0.86]},
#   'softgun.csv': {'f1': [0.12],
#    'precision': [0.1],
#    'recall': [0.14],
#    'g-score': [0.17],
#    'd2h': [0.89],
#    'pci_20': [0.18],
#    'ifa': [9],
#    'pd': [0.14],
#    'pf': [0.24]},
#   'din.csv': {'f1': [0.86],
#    'precision': [0.86],
#    'recall': [0.86],
#    'g-score': [0.65],
#    'd2h': [0.68],
#    'pci_20': [0.24],
#    'ifa': [1],
#    'pd': [0.86],
#    'pf': [0.67]},
#   'wc-mdx-editor.csv': {'f1': [0.54],
#    'precision': [0.41],
#    'recall': [0.78],
#    'g-score': [0.63],
#    'd2h': [0.68],
#    'pci_20': [0.2],
#    'ifa': [10],
#    'pd': [0.78],
#    'pf': [0.65]},
#   'violet.csv': {'f1': [0.77],
#    'precision': [0.71],
#    'recall': [0.83],
#    'g-score': [0.77],
#    'd2h': [0.43],
#    'pci_20': [0.18],
#    'ifa': [0],
#    'pd': [0.83],
#    'pf': [0.4]},
#   'ugaagga.csv': {'f1': [0.74],
#    'precision': [0.83],
#    'recall': [0.67],
#    'g-score': [0.0],
#    'd2h': [1.05],
#    'pci_20': [0.12],
#    'ifa': [0],
#    'pd': [0.67],
#    'pf': [1.0]},
#   'open-gpstracker.csv': {'f1': [0.93],
#    'precision': [1.0],
#    'recall': [0.88],
#    'g-score': [nan],
#    'd2h': [0.12],
#    'pci_20': [0.12],
#    'ifa': [0],
#    'pd': [0.88],
#    'pf': [nan]},
#   'vmx.csv': {'f1': [0.15],
#    'precision': [0.25],
#    'recall': [0.11],
#    'g-score': [0.12],
#    'd2h': [1.16],
#    'pci_20': [0.31],
#    'ifa': [5],
#    'pd': [0.11],
#    'pf': [0.75]},
#   'indiestep.csv': {'f1': [0.52],
#    'precision': [0.4],
#    'recall': [0.75],
#    'g-score': [0.66],
#    'd2h': [0.62],
#    'pci_20': [0.12],
#    'ifa': [0],
#    'pd': [0.75],
#    'pf': [0.56]},
#   'ra-ajax.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.06],
#    'pci_20': [0.19],
#    'ifa': [30],
#    'pd': [0.0],
#    'pf': [0.35]},
#   'alexoholdem.csv': {'f1': [0.77],
#    'precision': [0.71],
#    'recall': [0.83],
#    'g-score': [0.71],
#    'd2h': [0.57],
#    'pci_20': [0.14],
#    'ifa': [1],
#    'pd': [0.83],
#    'pf': [0.55]},
#   'ryuon.csv': {'f1': [0.33],
#    'precision': [0.21],
#    'recall': [0.8],
#    'g-score': [0.67],
#    'd2h': [0.63],
#    'pci_20': [0.27],
#    'ifa': [10],
#    'pd': [0.8],
#    'pf': [0.6]},
#   'adaptit.csv': {'f1': [0.5],
#    'precision': [0.42],
#    'recall': [0.62],
#    'g-score': [0.54],
#    'd2h': [0.74],
#    'pci_20': [0.16],
#    'ifa': [0],
#    'pd': [0.62],
#    'pf': [0.64]},
#   'gdipp.csv': {'f1': [0.67],
#    'precision': [0.56],
#    'recall': [0.82],
#    'g-score': [0.7],
#    'd2h': [0.58],
#    'pci_20': [0.16],
#    'ifa': [2],
#    'pd': [0.82],
#    'pf': [0.55]},
#   'krusader.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.01],
#    'pci_20': [0.19],
#    'ifa': [31],
#    'pd': [0.0],
#    'pf': [0.13]},
#   'echoes2.csv': {'f1': [0.28],
#    'precision': [0.17],
#    'recall': [0.83],
#    'g-score': [0.36],
#    'd2h': [0.91],
#    'pci_20': [0.15],
#    'ifa': [9],
#    'pd': [0.83],
#    'pf': [0.89]},
#   'barry.csv': {'f1': [0.58],
#    'precision': [0.47],
#    'recall': [0.78],
#    'g-score': [0.57],
#    'd2h': [0.76],
#    'pci_20': [0.15],
#    'ifa': [1],
#    'pd': [0.78],
#    'pf': [0.73]},
#   'generateur-minisat.csv': {'f1': [0.76],
#    'precision': [0.72],
#    'recall': [0.81],
#    'g-score': [0.6],
#    'd2h': [0.74],
#    'pci_20': [0.13],
#    'ifa': [0],
#    'pd': [0.81],
#    'pf': [0.71]},
#   'wisegames.csv': {'f1': [0.88],
#    'precision': [0.8],
#    'recall': [0.97],
#    'g-score': [0.4],
#    'd2h': [0.88],
#    'pci_20': [0.16],
#    'ifa': [0],
#    'pd': [0.97],
#    'pf': [0.88]},
#   'lilith3d.csv': {'f1': [0.87],
#    'precision': [0.79],
#    'recall': [0.96],
#    'g-score': [0.4],
#    'd2h': [0.88],
#    'pci_20': [0.22],
#    'ifa': [0],
#    'pd': [0.96],
#    'pf': [0.88]},
#   'dtemplatelib.csv': {'f1': [0.88],
#    'precision': [0.79],
#    'recall': [1.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.18],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [1.0]},
#   'desqiss.csv': {'f1': [0.67],
#    'precision': [0.62],
#    'recall': [0.71],
#    'g-score': [0.66],
#    'd2h': [0.55],
#    'pci_20': [0.15],
#    'ifa': [0],
#    'pd': [0.71],
#    'pf': [0.47]},
#   'istar-uidiagram.csv': {'f1': [0.4],
#    'precision': [0.25],
#    'recall': [1.0],
#    'g-score': [0.83],
#    'd2h': [0.5],
#    'pci_20': [0.23],
#    'ifa': [2],
#    'pd': [1.0],
#    'pf': [0.5]},
#   'ztracker.csv': {'f1': [0.72],
#    'precision': [0.65],
#    'recall': [0.81],
#    'g-score': [0.74],
#    'd2h': [0.48],
#    'pci_20': [0.28],
#    'ifa': [3],
#    'pd': [0.81],
#    'pf': [0.44]},
#   'ballgame.csv': {'f1': [0.32],
#    'precision': [0.75],
#    'recall': [0.2],
#    'g-score': [0.24],
#    'd2h': [0.8],
#    'pci_20': [0.25],
#    'ifa': [3],
#    'pd': [0.2],
#    'pf': [0.08]},
#   'meaggregator.csv': {'f1': [0.55],
#    'precision': [0.38],
#    'recall': [1.0],
#    'g-score': [0.8],
#    'd2h': [0.56],
#    'pci_20': [0.17],
#    'ifa': [1],
#    'pd': [1.0],
#    'pf': [0.56]},
#   'gbif-registry.csv': {'f1': [0.56],
#    'precision': [0.44],
#    'recall': [0.78],
#    'g-score': [0.63],
#    'd2h': [0.68],
#    'pci_20': [0.17],
#    'ifa': [0],
#    'pd': [0.78],
#    'pf': [0.64]},
#   'gxp.csv': {'f1': [0.21],
#    'precision': [0.12],
#    'recall': [1.0],
#    'g-score': [0.57],
#    'd2h': [0.79],
#    'pci_20': [0.23],
#    'ifa': [1],
#    'pd': [1.0],
#    'pf': [0.79]},
#   'ivc.csv': {'f1': [0.44],
#    'precision': [0.3],
#    'recall': [0.78],
#    'g-score': [0.63],
#    'd2h': [0.68],
#    'pci_20': [0.21],
#    'ifa': [5],
#    'pd': [0.78],
#    'pf': [0.64]},
#   'cspoker.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [nan],
#    'd2h': [1.32],
#    'pci_20': [0.19],
#    'ifa': [41],
#    'pd': [nan],
#    'pf': [0.86]},
#   'housekeeper.csv': {'f1': [0.33],
#    'precision': [0.22],
#    'recall': [0.67],
#    'g-score': [0.35],
#    'd2h': [0.94],
#    'pci_20': [0.36],
#    'ifa': [5],
#    'pd': [0.67],
#    'pf': [0.88]},
#   'windage.csv': {'f1': [0.2],
#    'precision': [0.17],
#    'recall': [0.25],
#    'g-score': [0.29],
#    'd2h': [0.79],
#    'pci_20': [0.17],
#    'ifa': [14],
#    'pd': [0.25],
#    'pf': [0.26]},
#   'tiopf.csv': {'f1': [0.78],
#    'precision': [0.8],
#    'recall': [0.76],
#    'g-score': [0.0],
#    'd2h': [1.03],
#    'pci_20': [0.2],
#    'ifa': [0],
#    'pd': [0.76],
#    'pf': [1.0]},
#   'trafikanten.csv': {'f1': [0.47],
#    'precision': [0.31],
#    'recall': [1.0],
#    'g-score': [0.33],
#    'd2h': [0.91],
#    'pci_20': [0.16],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [0.91]},
#   'adeopensite.csv': {'f1': [0.84],
#    'precision': [0.95],
#    'recall': [0.75],
#    'g-score': [0.0],
#    'd2h': [1.03],
#    'pci_20': [0.2],
#    'ifa': [0],
#    'pd': [0.75],
#    'pf': [1.0]},
#   'glunatic.csv': {'f1': [0.14],
#    'precision': [1.0],
#    'recall': [0.08],
#    'g-score': [0.1],
#    'd2h': [0.92],
#    'pci_20': [0.18],
#    'ifa': [3],
#    'pd': [0.08],
#    'pf': [0.0]},
#   'odkit.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.21],
#    'ifa': [42],
#    'pd': [0.0],
#    'pf': [0.05]},
#   'ocd.csv': {'f1': [0.45],
#    'precision': [0.43],
#    'recall': [0.47],
#    'g-score': [0.49],
#    'd2h': [0.67],
#    'pci_20': [0.17],
#    'ifa': [3],
#    'pd': [0.47],
#    'pf': [0.41]},
#   'urlget.csv': {'f1': [0.67],
#    'precision': [0.79],
#    'recall': [0.58],
#    'g-score': [0.36],
#    'd2h': [0.95],
#    'pci_20': [0.33],
#    'ifa': [1],
#    'pd': [0.58],
#    'pf': [0.86]},
#   'signserver.csv': {'f1': [0.7],
#    'precision': [0.58],
#    'recall': [0.88],
#    'g-score': [0.82],
#    'd2h': [0.38],
#    'pci_20': [0.23],
#    'ifa': [6],
#    'pd': [0.88],
#    'pf': [0.36]},
#   'hhexen.csv': {'f1': [0.3],
#    'precision': [0.2],
#    'recall': [0.6],
#    'g-score': [0.43],
#    'd2h': [0.89],
#    'pci_20': [0.15],
#    'ifa': [6],
#    'pd': [0.6],
#    'pf': [0.8]},
#   'jforum.csv': {'f1': [0.73],
#    'precision': [0.8],
#    'recall': [0.67],
#    'g-score': [0.66],
#    'd2h': [0.5],
#    'pci_20': [0.19],
#    'ifa': [1],
#    'pd': [0.67],
#    'pf': [0.38]},
#   'buttress.csv': {'f1': [0.69],
#    'precision': [0.56],
#    'recall': [0.91],
#    'g-score': [0.82],
#    'd2h': [0.41],
#    'pci_20': [0.16],
#    'ifa': [1],
#    'pd': [0.91],
#    'pf': [0.4]},
#   'dataparksearch.csv': {'f1': [0.61],
#    'precision': [0.45],
#    'recall': [0.94],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.21],
#    'ifa': [0],
#    'pd': [0.94],
#    'pf': [1.0]},
#   'graph.csv': {'f1': [0.35],
#    'precision': [0.38],
#    'recall': [0.33],
#    'g-score': [0.36],
#    'd2h': [0.77],
#    'pci_20': [0.14],
#    'ifa': [1],
#    'pd': [0.33],
#    'pf': [0.38]},
#   'cupsfilter.csv': {'f1': [0.57],
#    'precision': [0.57],
#    'recall': [0.57],
#    'g-score': [0.54],
#    'd2h': [0.69],
#    'pci_20': [0.16],
#    'ifa': [0],
#    'pd': [0.57],
#    'pf': [0.55]},
#   'wfit.csv': {'f1': [0.58],
#    'precision': [0.5],
#    'recall': [0.7],
#    'g-score': [0.64],
#    'd2h': [0.6],
#    'pci_20': [0.23],
#    'ifa': [2],
#    'pd': [0.7],
#    'pf': [0.52]},
#   'rainbrurpg.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.11],
#    'ifa': [34],
#    'pd': [0.0],
#    'pf': [0.03]},
#   'mev-tm4.csv': {'f1': [0.45],
#    'precision': [0.39],
#    'recall': [0.53],
#    'g-score': [0.38],
#    'd2h': [0.95],
#    'pci_20': [0.15],
#    'ifa': [0],
#    'pd': [0.53],
#    'pf': [0.82]},
#   'commonjava.csv': {'f1': [0.07],
#    'precision': [0.04],
#    'recall': [1.0],
#    'g-score': [0.73],
#    'd2h': [0.65],
#    'pci_20': [0.17],
#    'ifa': [36],
#    'pd': [1.0],
#    'pf': [0.65]},
#   'aigfxlab.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.07],
#    'pci_20': [0.19],
#    'ifa': [46],
#    'pd': [0.0],
#    'pf': [0.39]},
#   'freevo.csv': {'f1': [0.33],
#    'precision': [1.0],
#    'recall': [0.2],
#    'g-score': [0.24],
#    'd2h': [0.8],
#    'pci_20': [0.14],
#    'ifa': [13],
#    'pd': [0.2],
#    'pf': [0.0]},
#   'quantum.csv': {'f1': [0.74],
#    'precision': [0.7],
#    'recall': [0.78],
#    'g-score': [0.78],
#    'd2h': [0.31],
#    'pci_20': [0.17],
#    'ifa': [2],
#    'pd': [0.78],
#    'pf': [0.21]},
#   'syscalltrack.csv': {'f1': [1.0],
#    'precision': [1.0],
#    'recall': [1.0],
#    'g-score': [1.0],
#    'd2h': [0.0],
#    'pci_20': [0.0],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [0.0]},
#   'ipcop.csv': {'f1': [0.57],
#    'precision': [0.5],
#    'recall': [0.67],
#    'g-score': [0.67],
#    'd2h': [0.45],
#    'pci_20': [0.16],
#    'ifa': [6],
#    'pd': [0.67],
#    'pf': [0.31]},
#   'open2x.csv': {'f1': [0.8],
#    'precision': [0.67],
#    'recall': [1.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.0],
#    'ifa': [1],
#    'pd': [1.0],
#    'pf': [1.0]},
#   'extremesweep.csv': {'f1': [0.73],
#    'precision': [0.75],
#    'recall': [0.71],
#    'g-score': [0.65],
#    'd2h': [0.58],
#    'pci_20': [0.12],
#    'ifa': [0],
#    'pd': [0.71],
#    'pf': [0.5]},
#   'jamocha.csv': {'f1': [0.25],
#    'precision': [0.2],
#    'recall': [0.33],
#    'g-score': [0.37],
#    'd2h': [0.73],
#    'pci_20': [0.12],
#    'ifa': [16],
#    'pd': [0.33],
#    'pf': [0.29]},
#   'javasimon.csv': {'f1': [0.55],
#    'precision': [0.5],
#    'recall': [0.6],
#    'g-score': [0.47],
#    'd2h': [0.85],
#    'pci_20': [0.11],
#    'ifa': [4],
#    'pd': [0.6],
#    'pf': [0.75]},
#   'r2dst.csv': {'f1': [1.0],
#    'precision': [1.0],
#    'recall': [1.0],
#    'g-score': [1.0],
#    'd2h': [0.0],
#    'pci_20': [0.0],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [0.0]},
#   'tiki.csv': {'f1': [0.74],
#    'precision': [0.63],
#    'recall': [0.89],
#    'g-score': [0.72],
#    'd2h': [0.6],
#    'pci_20': [0.14],
#    'ifa': [1],
#    'pd': [0.89],
#    'pf': [0.59]},
#   'netbpm.csv': {'f1': [0.77],
#    'precision': [0.8],
#    'recall': [0.75],
#    'g-score': [0.54],
#    'd2h': [0.79],
#    'pci_20': [0.45],
#    'ifa': [5],
#    'pd': [0.75],
#    'pf': [0.75]},
#   'ufraw.csv': {'f1': [0.76],
#    'precision': [0.73],
#    'recall': [0.8],
#    'g-score': [0.56],
#    'd2h': [0.78],
#    'pci_20': [0.14],
#    'ifa': [0],
#    'pd': [0.8],
#    'pf': [0.75]},
#   'tuxpaint.csv': {'f1': [0.75],
#    'precision': [0.75],
#    'recall': [0.75],
#    'g-score': [0.76],
#    'd2h': [0.3],
#    'pci_20': [0.1],
#    'ifa': [0],
#    'pd': [0.75],
#    'pf': [0.17]},
#   'surprise.csv': {'f1': [0.5],
#    'precision': [0.4],
#    'recall': [0.67],
#    'g-score': [0.5],
#    'd2h': [0.82],
#    'pci_20': [0.14],
#    'ifa': [2],
#    'pd': [0.67],
#    'pf': [0.75]},
#   'bayonne.csv': {'f1': [0.81],
#    'precision': [0.85],
#    'recall': [0.77],
#    'g-score': [0.75],
#    'd2h': [0.39],
#    'pci_20': [0.19],
#    'ifa': [0],
#    'pd': [0.77],
#    'pf': [0.31]},
#   'game-techs.csv': {'f1': [0.4],
#    'precision': [0.33],
#    'recall': [0.5],
#    'g-score': [0.45],
#    'd2h': [0.83],
#    'pci_20': [0.0],
#    'ifa': [0],
#    'pd': [0.5],
#    'pf': [0.67]},
#   'toycars.csv': {'f1': [0.81],
#    'precision': [0.68],
#    'recall': [1.0],
#    'g-score': [0.41],
#    'd2h': [0.88],
#    'pci_20': [0.17],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [0.88]},
#   'hl7-testharness.csv': {'f1': [0.87],
#    'precision': [1.0],
#    'recall': [0.77],
#    'g-score': [nan],
#    'd2h': [0.23],
#    'pci_20': [0.23],
#    'ifa': [0],
#    'pd': [0.77],
#    'pf': [nan]},
#   'sphinxsearch.csv': {'f1': [0.73],
#    'precision': [0.71],
#    'recall': [0.75],
#    'g-score': [0.68],
#    'd2h': [0.56],
#    'pci_20': [0.15],
#    'ifa': [0],
#    'pd': [0.75],
#    'pf': [0.5]},
#   'helianto.csv': {'f1': [0.74],
#    'precision': [0.59],
#    'recall': [1.0],
#    'g-score': [0.41],
#    'd2h': [0.88],
#    'pci_20': [0.17],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [0.88]},
#   'multiverse.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.03],
#    'pci_20': [0.33],
#    'ifa': [8],
#    'pd': [0.0],
#    'pf': [0.25]},
#   'qore.csv': {'f1': [0.7],
#    'precision': [0.84],
#    'recall': [0.59],
#    'g-score': [0.59],
#    'd2h': [0.59],
#    'pci_20': [0.18],
#    'ifa': [1],
#    'pd': [0.59],
#    'pf': [0.43]},
#   'opencvlibrary.csv': {'f1': [0.62],
#    'precision': [0.56],
#    'recall': [0.69],
#    'g-score': [0.55],
#    'd2h': [0.76],
#    'pci_20': [0.17],
#    'ifa': [0],
#    'pd': [0.69],
#    'pf': [0.7]},
#   'modelling4all.csv': {'f1': [0.82],
#    'precision': [0.71],
#    'recall': [0.97],
#    'g-score': [0.62],
#    'd2h': [0.75],
#    'pci_20': [0.19],
#    'ifa': [0],
#    'pd': [0.97],
#    'pf': [0.75]},
#   'jeepproject.csv': {'f1': [0.81],
#    'precision': [1.0],
#    'recall': [0.68],
#    'g-score': [nan],
#    'd2h': [0.32],
#    'pci_20': [0.34],
#    'ifa': [0],
#    'pd': [0.68],
#    'pf': [nan]},
#   'eclipse-imp.csv': {'f1': [0.3],
#    'precision': [0.18],
#    'recall': [1.0],
#    'g-score': [0.3],
#    'd2h': [0.92],
#    'pci_20': [0.2],
#    'ifa': [1],
#    'pd': [1.0],
#    'pf': [0.92]},
#   'maniadminplugin.csv': {'f1': [0.33],
#    'precision': [1.0],
#    'recall': [0.2],
#    'g-score': [0.24],
#    'd2h': [0.8],
#    'pci_20': [0.17],
#    'ifa': [3],
#    'pd': [0.2],
#    'pf': [0.0]},
#   'simgear.csv': {'f1': [0.63],
#    'precision': [0.67],
# ...
#    'g-score': [0.59],
#    'd2h': [0.54],
#    'pci_20': [0.17],
#    'ifa': [6],
#    'pd': [0.57],
#    'pf': [0.32]},
#   'libgf.csv': {'f1': [0.29],
#    'precision': [0.4],
#    'recall': [0.22],
#    'g-score': [0.26],
#    'd2h': [0.79],
#    'pci_20': [0.28],
#    'ifa': [1],
#    'pd': [0.22],
#    'pf': [0.15]},
#   'sobjc.csv': {'f1': [0.46],
#    'precision': [0.86],
#    'recall': [0.32],
#    'g-score': [0.37],
#    'd2h': [0.69],
#    'pci_20': [0.18],
#    'ifa': [10],
#    'pd': [0.32],
#    'pf': [0.07]},
#   'opendlm.csv': {'f1': [0.73],
#    'precision': [0.71],
#    'recall': [0.74],
#    'g-score': [0.7],
#    'd2h': [0.49],
#    'pci_20': [0.3],
#    'ifa': [1],
#    'pd': [0.74],
#    'pf': [0.42]},
#   'videoventure.csv': {'f1': [0.5],
#    'precision': [0.9],
#    'recall': [0.35],
#    'g-score': [0.39],
#    'd2h': [0.7],
#    'pci_20': [0.23],
#    'ifa': [16],
#    'pd': [0.35],
#    'pf': [0.25]},
#   'openoss.csv': {'f1': [0.31],
#    'precision': [0.67],
#    'recall': [0.2],
#    'g-score': [0.24],
#    'd2h': [0.8],
#    'pci_20': [0.03],
#    'ifa': [0],
#    'pd': [0.2],
#    'pf': [0.04]},
#   'woodward.csv': {'f1': [0.25],
#    'precision': [1.0],
#    'recall': [0.14],
#    'g-score': [0.17],
#    'd2h': [0.86],
#    'pci_20': [0.12],
#    'ifa': [0],
#    'pd': [0.14],
#    'pf': [0.0]},
#   'sage-sjq.csv': {'f1': [0.29],
#    'precision': [0.17],
#    'recall': [0.88],
#    'g-score': [0.41],
#    'd2h': [0.88],
#    'pci_20': [0.15],
#    'ifa': [1],
#    'pd': [0.88],
#    'pf': [0.87]},
#   'jchord.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [nan],
#    'd2h': [1.21],
#    'pci_20': [0.12],
#    'ifa': [24],
#    'pd': [nan],
#    'pf': [0.68]},
#   'k3d-bart.csv': {'f1': [0.08],
#    'precision': [0.05],
#    'recall': [0.2],
#    'g-score': [0.23],
#    'd2h': [0.96],
#    'pci_20': [0.16],
#    'ifa': [39],
#    'pd': [0.2],
#    'pf': [0.53]},
#   'growl.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.0],
#    'ifa': [5],
#    'pd': [0.0],
#    'pf': [0.0]},
#   'madwifi.csv': {'f1': [0.7],
#    'precision': [1.0],
#    'recall': [0.54],
#    'g-score': [0.59],
#    'd2h': [0.46],
#    'pci_20': [0.2],
#    'ifa': [0],
#    'pd': [0.54],
#    'pf': [0.0]},
#   'cosmoscroll.csv': {'f1': [0.35],
#    'precision': [0.6],
#    'recall': [0.25],
#    'g-score': [0.29],
#    'd2h': [0.76],
#    'pci_20': [0.19],
#    'ifa': [13],
#    'pd': [0.25],
#    'pf': [0.14]},
#   'aqbanking.csv': {'f1': [0.28],
#    'precision': [0.16],
#    'recall': [1.0],
#    'g-score': [0.21],
#    'd2h': [0.95],
#    'pci_20': [0.12],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [0.95]},
#   'languagetool.csv': {'f1': [0.74],
#    'precision': [0.65],
#    'recall': [0.87],
#    'g-score': [0.83],
#    'd2h': [0.32],
#    'pci_20': [0.15],
#    'ifa': [3],
#    'pd': [0.87],
#    'pf': [0.29]},
#   'meadow.csv': {'f1': [0.67],
#    'precision': [0.52],
#    'recall': [0.92],
#    'g-score': [0.49],
#    'd2h': [0.84],
#    'pci_20': [0.17],
#    'ifa': [3],
#    'pd': [0.92],
#    'pf': [0.83]},
#   'openldap-ha.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [nan],
#    'd2h': [1.41],
#    'pci_20': [0.11],
#    'ifa': [8],
#    'pd': [0.0],
#    'pf': [1.0]},
#   'google-api-adwords-java.csv': {'f1': [0.31],
#    'precision': [0.67],
#    'recall': [0.2],
#    'g-score': [0.24],
#    'd2h': [0.81],
#    'pci_20': [0.18],
#    'ifa': [4],
#    'pd': [0.2],
#    'pf': [0.14]},
#   'gtktalog.csv': {'f1': [1.0],
#    'precision': [1.0],
#    'recall': [1.0],
#    'g-score': [1.0],
#    'd2h': [0.0],
#    'pci_20': [0.09],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [0.0]},
#   'android-geocast.csv': {'f1': [0.21],
#    'precision': [0.12],
#    'recall': [0.6],
#    'g-score': [0.45],
#    'd2h': [0.87],
#    'pci_20': [0.16],
#    'ifa': [11],
#    'pd': [0.6],
#    'pf': [0.78]},
#   'freeimage.csv': {'f1': [0.5],
#    'precision': [0.6],
#    'recall': [0.43],
#    'g-score': [0.46],
#    'd2h': [0.7],
#    'pci_20': [0.17],
#    'ifa': [0],
#    'pd': [0.43],
#    'pf': [0.4]},
#   'ahuman.csv': {'f1': [0.61],
#    'precision': [0.5],
#    'recall': [0.78],
#    'g-score': [0.63],
#    'd2h': [0.67],
#    'pci_20': [0.2],
#    'ifa': [0],
#    'pd': [0.78],
#    'pf': [0.64]},
#   'ecls.csv': {'f1': [0.71],
#    'precision': [0.83],
#    'recall': [0.62],
#    'g-score': [0.59],
#    'd2h': [0.62],
#    'pci_20': [0.1],
#    'ifa': [0],
#    'pd': [0.62],
#    'pf': [0.5]},
#   'yacsf.csv': {'f1': [0.46],
#    'precision': [0.44],
#    'recall': [0.47],
#    'g-score': [0.49],
#    'd2h': [0.67],
#    'pci_20': [0.2],
#    'ifa': [3],
#    'pd': [0.47],
#    'pf': [0.42]},
#   'pd-gem.csv': {'f1': [0.4],
#    'precision': [1.0],
#    'recall': [0.25],
#    'g-score': [0.29],
#    'd2h': [0.75],
#    'pci_20': [0.13],
#    'ifa': [2],
#    'pd': [0.25],
#    'pf': [0.0]},
#   'cvstampusc.csv': {'f1': [0.58],
#    'precision': [0.41],
#    'recall': [1.0],
#    'g-score': [0.45],
#    'd2h': [0.86],
#    'pci_20': [0.14],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [0.86]},
#   'hcsoftware.csv': {'f1': [0.67],
#    'precision': [0.57],
#    'recall': [0.8],
#    'g-score': [0.71],
#    'd2h': [0.54],
#    'pci_20': [0.18],
#    'ifa': [2],
#    'pd': [0.8],
#    'pf': [0.5]},
#   'dwd.csv': {'f1': [0.8],
#    'precision': [0.67],
#    'recall': [1.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.11],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [1.0]},
#   'pasdoc.csv': {'f1': [0.91],
#    'precision': [0.91],
#    'recall': [0.91],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.17],
#    'ifa': [0],
#    'pd': [0.91],
#    'pf': [1.0]},
#   'isits.csv': {'f1': [0.67],
#    'precision': [0.6],
#    'recall': [0.75],
#    'g-score': [0.6],
#    'd2h': [0.71],
#    'pci_20': [0.18],
#    'ifa': [0],
#    'pd': [0.75],
#    'pf': [0.67]},
#   'bigbluebutton.csv': {'f1': [0.67],
#    'precision': [0.5],
#    'recall': [1.0],
#    'g-score': [0.91],
#    'd2h': [0.33],
#    'pci_20': [0.0],
#    'ifa': [3],
#    'pd': [1.0],
#    'pf': [0.33]},
#   'lx-viewer.csv': {'f1': [0.33],
#    'precision': [0.33],
#    'recall': [0.33],
#    'g-score': [0.33],
#    'd2h': [0.94],
#    'pci_20': [0.17],
#    'ifa': [1],
#    'pd': [0.33],
#    'pf': [0.67]},
#   'tmv-cpp.csv': {'f1': [0.88],
#    'precision': [1.0],
#    'recall': [0.78],
#    'g-score': [0.82],
#    'd2h': [0.22],
#    'pci_20': [0.1],
#    'ifa': [0],
#    'pd': [0.78],
#    'pf': [0.0]},
#   'gate.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.13],
#    'pci_20': [0.12],
#    'ifa': [23],
#    'pd': [0.0],
#    'pf': [0.52]},
#   'embedded-control-library.csv': {'f1': [0.39],
#    'precision': [0.24],
#    'recall': [1.0],
#    'g-score': [0.83],
#    'd2h': [0.5],
#    'pci_20': [0.27],
#    'ifa': [1],
#    'pd': [1.0],
#    'pf': [0.5]},
#   'solidbase.csv': {'f1': [0.55],
#    'precision': [0.6],
#    'recall': [0.5],
#    'g-score': [0.53],
#    'd2h': [0.59],
#    'pci_20': [0.12],
#    'ifa': [2],
#    'pd': [0.5],
#    'pf': [0.31]},
#   'lbmmb.csv': {'f1': [0.53],
#    'precision': [0.43],
#    'recall': [0.67],
#    'g-score': [0.55],
#    'd2h': [0.76],
#    'pci_20': [0.18],
#    'ifa': [1],
#    'pd': [0.67],
#    'pf': [0.68]},
#   'scalaris.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.25],
#    'pci_20': [0.0],
#    'ifa': [4],
#    'pd': [0.0],
#    'pf': [0.75]},
#   'makecontroller.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [nan],
#    'd2h': [1.04],
#    'pci_20': [0.21],
#    'ifa': [13],
#    'pd': [nan],
#    'pf': [0.29]},
#   'gpu.csv': {'f1': [0.47],
#    'precision': [0.33],
#    'recall': [0.8],
#    'g-score': [0.62],
#    'd2h': [0.7],
#    'pci_20': [0.18],
#    'ifa': [2],
#    'pd': [0.8],
#    'pf': [0.67]},
#   'tinyos.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.38],
#    'ifa': [7],
#    'pd': [0.0],
#    'pf': [0.0]},
#   'esup-helpdesk.csv': {'f1': [0.21],
#    'precision': [0.12],
#    'recall': [1.0],
#    'g-score': [0.51],
#    'd2h': [0.83],
#    'pci_20': [0.2],
#    'ifa': [11],
#    'pd': [1.0],
#    'pf': [0.83]},
#   'javfish.csv': {'f1': [0.88],
#    'precision': [0.92],
#    'recall': [0.85],
#    'g-score': [0.75],
#    'd2h': [0.52],
#    'pci_20': [0.2],
#    'ifa': [1],
#    'pd': [0.85],
#    'pf': [0.5]},
#   'europa-pso.csv': {'f1': [0.78],
#    'precision': [0.86],
#    'recall': [0.72],
#    'g-score': [0.62],
#    'd2h': [0.66],
#    'pci_20': [0.2],
#    'ifa': [0],
#    'pd': [0.72],
#    'pf': [0.6]},
#   'andromda.csv': {'f1': [0.43],
#    'precision': [0.33],
#    'recall': [0.6],
#    'g-score': [0.36],
#    'd2h': [0.95],
#    'pci_20': [0.17],
#    'ifa': [5],
#    'pd': [0.6],
#    'pf': [0.86]},
#   'flac.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.18],
#    'pci_20': [0.33],
#    'ifa': [35],
#    'pd': [0.0],
#    'pf': [0.63]},
#   'ominos.csv': {'f1': [0.36],
#    'precision': [0.83],
#    'recall': [0.23],
#    'g-score': [0.27],
#    'd2h': [0.79],
#    'pci_20': [0.14],
#    'ifa': [13],
#    'pd': [0.23],
#    'pf': [0.17]},
#   'valgrind.csv': {'f1': [0.75],
#    'precision': [1.0],
#    'recall': [0.61],
#    'g-score': [0.66],
#    'd2h': [0.39],
#    'pci_20': [0.16],
#    'ifa': [0],
#    'pd': [0.61],
#    'pf': [0.0]},
#   'jchempaint.csv': {'f1': [0.56],
#    'precision': [0.5],
#    'recall': [0.62],
#    'g-score': [0.55],
#    'd2h': [0.73],
#    'pci_20': [0.06],
#    'ifa': [1],
#    'pd': [0.62],
#    'pf': [0.62]},
#   'forgotten.csv': {'f1': [0.25],
#    'precision': [0.15],
#    'recall': [0.75],
#    'g-score': [0.71],
#    'd2h': [0.48],
#    'pci_20': [0.2],
#    'ifa': [21],
#    'pd': [0.75],
#    'pf': [0.41]},
#   'xdrawchem.csv': {'f1': [0.62],
#    'precision': [0.45],
#    'recall': [1.0],
#    'g-score': [0.45],
#    'd2h': [0.86],
#    'pci_20': [0.17],
#    'ifa': [2],
#    'pd': [1.0],
#    'pf': [0.86]},
#   'python.csv': {'f1': [0.76],
#    'precision': [0.92],
#    'recall': [0.65],
#    'g-score': [0.68],
#    'd2h': [0.41],
#    'pci_20': [0.25],
#    'ifa': [4],
#    'pd': [0.65],
#    'pf': [0.2]},
#   'ci-factory.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.17],
#    'ifa': [5],
#    'pd': [0.0],
#    'pf': [0.0]},
#   'frodo-wii.csv': {'f1': [0.67],
#    'precision': [0.55],
#    'recall': [0.86],
#    'g-score': [0.62],
#    'd2h': [0.73],
#    'pci_20': [0.21],
#    'ifa': [0],
#    'pd': [0.86],
#    'pf': [0.71]},
#   'peptool.csv': {'f1': [0.25],
#    'precision': [0.22],
#    'recall': [0.29],
#    'g-score': [0.33],
#    'd2h': [0.78],
#    'pci_20': [0.21],
#    'ifa': [13],
#    'pd': [0.29],
#    'pf': [0.32]},
#   'proper.csv': {'f1': [0.2],
#    'precision': [0.13],
#    'recall': [0.43],
#    'g-score': [0.44],
#    'd2h': [0.75],
#    'pci_20': [0.21],
#    'ifa': [9],
#    'pd': [0.43],
#    'pf': [0.49]},
#   'vdr-mediamvp.csv': {'f1': [0.32],
#    'precision': [0.25],
#    'recall': [0.46],
#    'g-score': [0.39],
#    'd2h': [0.92],
#    'pci_20': [0.16],
#    'ifa': [0],
#    'pd': [0.46],
#    'pf': [0.75]},
#   'cif.csv': {'f1': [0.44],
#    'precision': [0.33],
#    'recall': [0.67],
#    'g-score': [0.66],
#    'd2h': [0.51],
#    'pci_20': [0.19],
#    'ifa': [7],
#    'pd': [0.67],
#    'pf': [0.38]},
#   'luntbuild.csv': {'f1': [0.54],
#    'precision': [0.48],
#    'recall': [0.62],
#    'g-score': [0.6],
#    'd2h': [0.61],
#    'pci_20': [0.18],
#    'ifa': [3],
#    'pd': [0.62],
#    'pf': [0.48]},
#   'jrecruiter.csv': {'f1': [0.6],
#    'precision': [0.44],
#    'recall': [0.94],
#    'g-score': [0.63],
#    'd2h': [0.73],
#    'pci_20': [0.14],
#    'ifa': [1],
#    'pd': [0.94],
#    'pf': [0.73]},
#   'cozilyworks.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [nan],
#    'd2h': [1.41],
#    'pci_20': [0.0],
#    'ifa': [0],
#    'pd': [nan],
#    'pf': [1.0]},
#   'openh323gk.csv': {'f1': [0.69],
#    'precision': [0.85],
#    'recall': [0.58],
#    'g-score': [0.62],
#    'd2h': [0.43],
#    'pci_20': [0.15],
#    'ifa': [0],
#    'pd': [0.58],
#    'pf': [0.1]},
#   'kt-dms.csv': {'f1': [0.5],
#    'precision': [0.33],
#    'recall': [1.0],
#    'g-score': [0.91],
#    'd2h': [0.33],
#    'pci_20': [0.0],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [0.33]},
#   'arabica.csv': {'f1': [0.77],
#    'precision': [0.92],
#    'recall': [0.67],
#    'g-score': [0.71],
#    'd2h': [0.34],
#    'pci_20': [0.32],
#    'ifa': [14],
#    'pd': [0.67],
#    'pf': [0.05]},
#   'libcam.csv': {'f1': [0.77],
#    'precision': [0.71],
#    'recall': [0.83],
#    'g-score': [0.51],
#    'd2h': [0.82],
#    'pci_20': [0.24],
#    'ifa': [2],
#    'pd': [0.83],
#    'pf': [0.8]},
#   'aapje.csv': {'f1': [0.76],
#    'precision': [0.93],
#    'recall': [0.64],
#    'g-score': [0.66],
#    'd2h': [0.44],
#    'pci_20': [0.19],
#    'ifa': [0],
#    'pd': [0.64],
#    'pf': [0.25]},
#   'hello-world-projects.csv': {'f1': [0.71],
#    'precision': [0.71],
#    'recall': [0.71],
#    'g-score': [0.58],
#    'd2h': [0.73],
#    'pci_20': [0.1],
#    'ifa': [0],
#    'pd': [0.71],
#    'pf': [0.67]},
#   'fds-smv.csv': {'f1': [0.78],
#    'precision': [0.67],
#    'recall': [0.93],
#    'g-score': [0.79],
#    'd2h': [0.5],
#    'pci_20': [0.21],
#    'ifa': [5],
#    'pd': [0.93],
#    'pf': [0.5]},
#   'osa-net.csv': {'f1': [0.89],
#    'precision': [0.92],
#    'recall': [0.86],
#    'g-score': [0.75],
#    'd2h': [0.52],
#    'pci_20': [0.19],
#    'ifa': [0],
#    'pd': [0.86],
#    'pf': [0.5]},
#   'dyuproject.csv': {'f1': [0.5],
#    'precision': [0.33],
#    'recall': [1.0],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [0.0],
#    'ifa': [2],
#    'pd': [1.0],
#    'pf': [1.0]},
#   'spock.csv': {'f1': [0.46],
#    'precision': [0.39],
#    'recall': [0.56],
#    'g-score': [0.55],
#    'd2h': [0.64],
#    'pci_20': [0.15],
#    'ifa': [2],
#    'pd': [0.56],
#    'pf': [0.47]},
#   'minime.csv': {'f1': [0.77],
#    'precision': [0.67],
#    'recall': [0.92],
#    'g-score': [0.6],
#    'd2h': [0.75],
#    'pci_20': [0.14],
#    'ifa': [0],
#    'pd': [0.92],
#    'pf': [0.75]},
#   'amsn.csv': {'f1': [0.33],
#    'precision': [0.2],
#    'recall': [1.0],
#    'g-score': [0.56],
#    'd2h': [0.8],
#    'pci_20': [0.17],
#    'ifa': [3],
#    'pd': [1.0],
#    'pf': [0.8]},
#   'intamap.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [nan],
#    'd2h': [1.25],
#    'pci_20': [0.17],
#    'ifa': [11],
#    'pd': [nan],
#    'pf': [0.75]},
#   'scms-project.csv': {'f1': [0.73],
#    'precision': [0.86],
#    'recall': [0.64],
#    'g-score': [0.61],
#    'd2h': [0.61],
#    'pci_20': [0.21],
#    'ifa': [2],
#    'pd': [0.64],
#    'pf': [0.5]},
#   'ispyb.csv': {'f1': [0.12],
#    'precision': [0.07],
#    'recall': [0.5],
#    'g-score': [0.31],
#    'd2h': [1.01],
#    'pci_20': [0.17],
#    'ifa': [14],
#    'pd': [0.5],
#    'pf': [0.88]},
#   'commitmonitor.csv': {'f1': [0.88],
#    'precision': [1.0],
#    'recall': [0.79],
#    'g-score': [nan],
#    'd2h': [0.21],
#    'pci_20': [0.21],
#    'ifa': [0],
#    'pd': [0.79],
#    'pf': [nan]},
#   'bsframework.csv': {'f1': [0.58],
#    'precision': [0.56],
#    'recall': [0.6],
#    'g-score': [0.63],
#    'd2h': [0.47],
#    'pci_20': [0.14],
#    'ifa': [5],
#    'pd': [0.6],
#    'pf': [0.24]},
#   'swingstates.csv': {'f1': [0.72],
#    'precision': [0.56],
#    'recall': [1.0],
#    'g-score': [0.41],
#    'd2h': [0.88],
#    'pci_20': [0.24],
#    'ifa': [0],
#    'pd': [1.0],
#    'pf': [0.88]},
#   'mvpmc.csv': {'f1': [0.59],
#    'precision': [0.52],
#    'recall': [0.68],
#    'g-score': [0.46],
#    'd2h': [0.86],
#    'pci_20': [0.24],
#    'ifa': [1],
#    'pd': [0.68],
#    'pf': [0.8]},
#   'ijbswa.csv': {'f1': [0.63],
#    'precision': [0.5],
#    'recall': [0.86],
#    'g-score': [0.58],
#    'd2h': [0.76],
#    'pci_20': [0.13],
#    'ifa': [0],
#    'pd': [0.86],
#    'pf': [0.75]},
#   'kicq.csv': {'f1': [0.42],
#    'precision': [0.29],
#    'recall': [0.71],
#    'g-score': [0.58],
#    'd2h': [0.73],
#    'pci_20': [0.16],
#    'ifa': [1],
#    'pd': [0.71],
#    'pf': [0.67]},
#   'ustockwcs.csv': {'f1': [0.94],
#    'precision': [0.94],
#    'recall': [0.94],
#    'g-score': [0.69],
#    'd2h': [0.67],
#    'pci_20': [0.15],
#    'ifa': [0],
#    'pd': [0.94],
#    'pf': [0.67]},
#   'ceps.csv': {'f1': [0.67],
#    'precision': [1.0],
#    'recall': [0.5],
#    'g-score': [nan],
#    'd2h': [0.5],
#    'pci_20': [0.0],
#    'ifa': [0],
#    'pd': [0.5],
#    'pf': [nan]},
#   'jactr.csv': {'f1': [0.94],
#    'precision': [1.0],
#    'recall': [0.88],
#    'g-score': [nan],
#    'd2h': [0.12],
#    'pci_20': [0.24],
#    'ifa': [0],
#    'pd': [0.88],
#    'pf': [nan]},
#   'pugs.csv': {'f1': [0.0],
#    'precision': [0.0],
#    'recall': [0.0],
#    'g-score': [nan],
#    'd2h': [1.0],
#    'pci_20': [0.0],
#    'ifa': [0],
#    'pd': [0.0],
#    'pf': [nan]}}}

# %%
with open('data/1385/711/1385_LR_default_bellwether_20.pkl', 'wb') as handle:
    pickle.dump(final_score, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
df = pd.read_pickle('data/1385/711/1385_LR_default_bellwether_20.pkl')
results_f1 = {}
results_precision = {}
results_recall = {}
results_g = {}
results_d2h = {}
results_pci_20 = {}
results_ifa = {}
results_pd = {}
results_pf = {}
for s_project in df.keys():
    if s_project not in results_f1.keys():
        results_f1[s_project] = {}
        results_precision[s_project] = {}
        results_recall[s_project] = {}
        results_g[s_project] = {}
        results_d2h[s_project] = {}
        results_pci_20[s_project] = {}
        results_ifa[s_project] = {}
        results_pd[s_project] = {}
        results_pf[s_project] = {}
    for d_projects in df[s_project].keys():
        results_f1[s_project][d_projects] = np.median(df[s_project][d_projects]['f1'])
        results_precision[s_project][d_projects] = np.median(df[s_project][d_projects]['precision'])
        results_recall[s_project][d_projects] = np.median(df[s_project][d_projects]['recall'])
        results_g[s_project][d_projects] = np.median(df[s_project][d_projects]['g-score'])
        results_d2h[s_project][d_projects] = np.median(df[s_project][d_projects]['d2h'])
        results_pci_20[s_project][d_projects] = np.median(df[s_project][d_projects]['pci_20'])
        results_ifa[s_project][d_projects] = np.median(df[s_project][d_projects]['ifa'])
        results_pd[s_project][d_projects] = np.median(df[s_project][d_projects]['pd'])
        results_pf[s_project][d_projects] = np.median(df[s_project][d_projects]['pf'])

# %%
results_f1_df = pd.DataFrame.from_dict(results_f1, orient='index')
results_precision_df = pd.DataFrame.from_dict(results_precision, orient='index')
results_recall_df = pd.DataFrame.from_dict(results_recall, orient='index')
results_g_df = pd.DataFrame.from_dict(results_g, orient='index')
results_d2h_df = pd.DataFrame.from_dict(results_d2h, orient='index')
results_pci_20_df = pd.DataFrame.from_dict(results_pci_20, orient='index')
results_ifa_df = pd.DataFrame.from_dict(results_ifa, orient='index')
results_pd_df = pd.DataFrame.from_dict(results_pd, orient='index')
results_pf_df = pd.DataFrame.from_dict(results_pf, orient='index')

# %%
results_f1_df.to_csv('data/1385/711/1385_LR_bellwether_f1.csv')
results_precision_df.to_csv('data/1385/711/1385_LR_bellwether_precision.csv')
results_recall_df.to_csv('data/1385/711/1385_LR_bellwether_recall.csv')
results_g_df.to_csv('data/1385/711/1385_LR_bellwether_g.csv')
results_d2h_df.to_csv('data/1385/711/1385_LR_bellwether_d2h.csv')
results_pci_20_df.to_csv('data/1385/711/1385_LR_bellwether_pci_20.csv')
results_ifa_df.to_csv('data/1385/711/1385_LR_bellwether_ifa.csv')
results_pd_df.to_csv('data/1385/711/1385_LR_bellwether_pd.csv')
results_pf_df.to_csv('data/1385/711/1385_LR_bellwether_pf.csv')
