# %%
import pandas as pd
import numpy as np
import math
import pickle
import collections

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold

import platform
from os import listdir
from os.path import isfile, join
from glob import glob
from pathlib import Path
import sys
import os
import copy
import traceback
from pathlib import Path
import timeit


import matplotlib.pyplot as plt

import SMOTE
import feature_selector
import DE
import CFS
import birch
import metrics.abcd
import birch_bellwether

import metrices
import measures

import sys
import traceback
import warnings
warnings.filterwarnings("ignore")

# %%
data_source = '/Users/suvodeepmajumder/Documents/AI4SE/bellwether_comminity/data/1385/original/rawMetrics.csv'
df = pd.read_csv(data_source)
unique_projects = df.Project.unique()
project_file = []
for project in unique_projects:
    _df = df[df['Project'] == project]
    if(_df.shape[0] <= 50):
        continue
    project_file.append([project,_df.File.unique().shape[0],_df.PL.unique()[0],_df.TLOC.unique().shape[0]])
project_file_df = pd.DataFrame(project_file,columns = ['project','num_files','lang','LOC'])
project_file_df.groupby(['lang']).count()

# %%
df = pd.read_csv(data_source)

# %%
unique_projects = df.Project.unique()

# %%
project_file = []
for project in unique_projects:
    _df = df[df['Project'] == project]
    if(_df.shape[0] <= 50):
        continue
    project_file.append([project,_df.File.unique().shape[0],_df.PL.unique()[0],_df.TLOC.unique().shape[0]])

# %%
project_file_df = pd.DataFrame(project_file,columns = ['project','num_files','lang','LOC'])

# %%
project_file_df.to_csv('/Users/suvodeepmajumder/Documents/AI4SE/bellwether_comminity/data/1385/original/summary.csv')

# %%
project_file_df.groupby(['lang']).count()
# Out:
#         project  num_files
# lang
# c           116        116
# cpp         241        241
# cs           42         42
# java        290        290
# pascal        6          6

# %%
df
# Out:
#        Host  Vcs            Project  \
# 0        gc   hg               aff4
# 1        gc   hg               aff4
# 2        gc   hg               aff4
# 3        gc   hg               aff4
# 4        gc   hg               aff4
# 5        gc   hg               aff4
# 6        gc   hg               aff4
# 7        gc   hg               aff4
# 8        gc   hg               aff4
# 9        gc   hg               aff4
# 10       gc   hg               aff4
# 11       gc   hg               aff4
# 12       gc   hg               aff4
# 13       gc   hg               aff4
# 14       gc   hg               aff4
# 15       gc   hg               aff4
# 16       gc   hg               aff4
# 17       gc   hg               aff4
# 18       gc   hg               aff4
# 19       gc   hg               aff4
# 20       gc   hg               aff4
# 21       gc   hg               aff4
# 22       gc   hg               aff4
# 23       gc   hg  android-scripting
# 24       gc   hg  android-scripting
# 25       gc   hg  android-scripting
# 26       gc   hg  android-scripting
# 27       gc   hg  android-scripting
# 28       gc   hg  android-scripting
# 29       gc   hg  android-scripting
# ...     ...  ...                ...
# 136131   sf  svn             zoolib
# 136132   sf  svn             zoolib
# 136133   sf  svn             zoolib
# 136134   sf  svn             zoolib
# 136135   sf  svn             zoolib
# 136136   sf  svn             zoolib
# 136137   sf  svn             zoolib
# 136138   sf  svn             zoolib
# 136139   sf  svn             zoolib
# 136140   sf  svn             zoolib
# 136141   sf  svn             zoolib
# 136142   sf  svn             zoolib
# 136143   sf  svn             zoolib
# 136144   sf  svn             zoolib
# 136145   sf  svn             zoolib
# 136146   sf  svn             zoolib
# 136147   sf  svn             zoolib
# 136148   sf  svn             zoolib
# 136149   sf  svn             zoolib
# 136150   sf  svn             zoolib
# 136151   sf  svn             zoolib
# 136152   sf  svn             zoolib
# 136153   sf  svn             zoolib
# 136154   sf  svn             zoolib
# 136155   sf  svn             zoolib
# 136156   sf  svn             zoolib
# 136157   sf  svn             zoolib
# 136158   sf  svn             zoolib
# 136159   sf  svn             zoolib
# 136160   sf  svn             zoolib
#
#                                                      File  Buggy    PL  \
# 0                                          include/aff4.h  buggy     c
# 1                                include/aff4_constants.h  buggy     c
# 2                                       include/aff4_io.h  buggy     c
# 3                                  include/aff4_objects.h  buggy     c
# 4                                      include/aff4_rdf.h  buggy     c
# 5                            include/aff4_rdf_serialise.h  clean     c
# 6                                 include/aff4_resolver.h  clean     c
# 7                                    include/aff4_utils.h  clean     c
# 8                                         include/class.h  buggy     c
# 9                                     include/ewfvolume.h  clean     c
# 10                                      include/exports.h  buggy     c
# 11                                         include/misc.h  clean     c
# 12                                       include/talloc.h  clean     c
# 13                                          lib/encrypt.c  buggy     c
# 14                                        lib/ewfvolume.c  buggy     c
# 15                                            lib/image.c  buggy     c
# 16                                              lib/map.c  buggy     c
# 17                                             lib/misc.c  buggy     c
# 18                                              lib/rdf.c  buggy     c
# 19                                         lib/resolver.c  buggy     c
# 20                                              lib/zip.c  buggy     c
# 21                                     tools/aff4imager.c  buggy     c
# 22                                         tools/affuse.c  clean     c
# 23      android/AndroidScriptingEnvironment/jni/com_go...  clean  java
# 24      android/AndroidScriptingEnvironment/src/com/go...  clean  java
# 25      android/AndroidScriptingEnvironment/src/com/go...  clean  java
# 26      android/AndroidScriptingEnvironment/src/com/go...  clean  java
# 27      android/AndroidScriptingEnvironment/src/com/go...  clean  java
# 28      android/AndroidScriptingEnvironment/src/com/go...  buggy  java
# 29      android/AndroidScriptingEnvironment/src/com/go...  buggy  java
# ...                                                   ...    ...   ...
# 136131  /zoolib/trunk/zoolib/source/cxx/zoolib/ZWinCOM...  clean   cpp
# 136132   /zoolib/trunk/zoolib/source/cxx/zoolib/ZWinCOM.h  clean   cpp
# 136133  /zoolib/trunk/zoolib/source/cxx/zoolib/ZWinCOM...  clean   cpp
# 136134  /zoolib/trunk/zoolib/source/cxx/zoolib/ZWinSer...  clean   cpp
# 136135  /zoolib/trunk/zoolib/source/cxx/zoolib/ZWinSer...  clean   cpp
# 136136   /zoolib/trunk/zoolib/source/cxx/zoolib/ZXLib.cpp  clean   cpp
# 136137  /zoolib/trunk/zoolib/source/cxx/zoolib/ZXServe...  clean   cpp
# 136138    /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad.cpp  buggy   cpp
# 136139      /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad.h  buggy   cpp
# 136140  /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_Be...  clean   cpp
# 136141  /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_Be...  clean   cpp
# 136142  /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_CF...  buggy   cpp
# 136143  /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_CF...  buggy   cpp
# 136144  /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_FS...  clean   cpp
# 136145  /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_JS...  buggy   cpp
# 136146  /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_JS...  clean   cpp
# 136147  /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_ML...  buggy   cpp
# 136148   /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_ML.h  clean   cpp
# 136149  /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_St...  buggy   cpp
# 136150  /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_Std.h  buggy   cpp
# 136151  /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_XM...  clean   cpp
# 136152  /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_XM...  clean   cpp
# 136153  /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_Zo...  buggy   cpp
# 136154  /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_Zo...  buggy   cpp
# 136155  /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_Zo...  clean   cpp
# 136156  /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_Zo...  clean   cpp
# 136157  /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_Zo...  buggy   cpp
# 136158  /zoolib/trunk/zoolib/source/cxx/zoolib/ZYad_Zo...  clean   cpp
# 136159  /zoolib/trunk/zoolib/source/cxx/zoolib/zconfigl.h  clean   cpp
# 136160  /zoolib/trunk/zoolib_samples/BlackBerry/BBDaem...  clean   cpp
#
#        IssueTracking   TLOC  TNF   TNC  ...  NFix  avg_AddedLOC  max_AddedLOC  \
# 0          IssueTrue   7484   27   332  ...     0      2.625000            13
# 1          IssueTrue   7484   27   332  ...     3      2.562500             9
# 2          IssueTrue   7484   27   332  ...     2      5.642857            34
# 3          IssueTrue   7484   27   332  ...     1     10.470588            43
# 4          IssueTrue   7484   27   332  ...     1      3.133333            13
# 5          IssueTrue   7484   27   332  ...     1      1.250000             4
# 6          IssueTrue   7484   27   332  ...     5      5.428571            39
# 7          IssueTrue   7484   27   332  ...     1      7.500000            26
# 8          IssueTrue   7484   27   332  ...     4      4.666667            21
# 9          IssueTrue   7484   27   332  ...     1     11.666667            22
# 10         IssueTrue   7484   27   332  ...     0      0.000000             0
# 11         IssueTrue   7484   27   332  ...     1      4.428571            14
# 12         IssueTrue   7484   27   332  ...     1      2.000000             2
# 13         IssueTrue   7484   27   332  ...     0     46.000000           200
# 14         IssueTrue   7484   27   332  ...     2     40.500000           185
# 15         IssueTrue   7484   27   332  ...     2      9.000000            56
# 16         IssueTrue   7484   27   332  ...     7     25.466667           199
# 17         IssueTrue   7484   27   332  ...     2      2.461538             9
# 18         IssueTrue   7484   27   332  ...     5     30.542857           575
# 19         IssueTrue   7484   27   332  ...     7     31.306122           265
# 20         IssueTrue   7484   27   332  ...     6     18.180000           108
# 21         IssueTrue   7484   27   332  ...     2     12.058824            76
# 22         IssueTrue   7484   27   332  ...     1     13.454545            79
# 23         IssueTrue   4797   42   244  ...     1     14.333333            43
# 24         IssueTrue   4797   42   244  ...     0      2.000000             2
# 25         IssueTrue   4797   42   244  ...     2      4.481481            42
# 26         IssueTrue   4797   42   244  ...     1      0.500000             1
# 27         IssueTrue   4797   42   244  ...     0      2.000000             7
# 28         IssueTrue   4797   42   244  ...     0      6.333333            15
# 29         IssueTrue   4797   42   244  ...     2      8.666667            43
# ...              ...    ...  ...   ...  ...   ...           ...           ...
# 136131    IssueFalse  79398  423  5901  ...     0      1.000000             1
# 136132    IssueFalse  79398  423  5901  ...     0     40.750000           131
# 136133    IssueFalse  79398  423  5901  ...     0      0.000000             0
# 136134    IssueFalse  79398  423  5901  ...     0      2.000000             2
# 136135    IssueFalse  79398  423  5901  ...     0      4.000000             4
# 136136    IssueFalse  79398  423  5901  ...     0      2.000000             2
# 136137    IssueFalse  79398  423  5901  ...     0      2.000000             2
# 136138    IssueFalse  79398  423  5901  ...     3     14.785714           120
# 136139    IssueFalse  79398  423  5901  ...     0     10.750000            32
# 136140    IssueFalse  79398  423  5901  ...     0      0.333333             1
# 136141    IssueFalse  79398  423  5901  ...     0      0.000000             0
# 136142    IssueFalse  79398  423  5901  ...     2      8.866667            68
# 136143    IssueFalse  79398  423  5901  ...     0      4.000000            19
# 136144    IssueFalse  79398  423  5901  ...     0      0.000000             0
# 136145    IssueFalse  79398  423  5901  ...     0     51.500000           294
# 136146    IssueFalse  79398  423  5901  ...     0     17.400000            64
# 136147    IssueFalse  79398  423  5901  ...     0      7.571429            31
# 136148    IssueFalse  79398  423  5901  ...     0      2.000000             4
# 136149    IssueFalse  79398  423  5901  ...     0     18.600000            79
# 136150    IssueFalse  79398  423  5901  ...     0      6.833333            41
# 136151    IssueFalse  79398  423  5901  ...     0      8.000000            36
# 136152    IssueFalse  79398  423  5901  ...     0      4.125000            22
# 136153    IssueFalse  79398  423  5901  ...     0     19.916667           133
# 136154    IssueFalse  79398  423  5901  ...     0      7.090909            33
# 136155    IssueFalse  79398  423  5901  ...     1      5.750000            51
# 136156    IssueFalse  79398  423  5901  ...     0      7.000000            17
# 136157    IssueFalse  79398  423  5901  ...     0     30.454545           154
# 136158    IssueFalse  79398  423  5901  ...     0      7.444444            56
# 136159    IssueFalse  79398  423  5901  ...     0      7.666667            14
# 136160    IssueFalse  79398  423  5901  ...     0     14.800000            63
#
#         total_AddedLOC  avg_DeletedLOC  max_DeletedLOC  total_DeletedLOC  \
# 0                   21        0.500000               3                 4
# 1                   41        0.125000               1                 2
# 2                   79        0.071429               1                 1
# 3                  178        5.529412              31                94
# 4                   47        0.733333               9                11
# 5                   10        0.250000               1                 2
# 6                  152        4.607143              60               129
# 7                   60        1.375000               5                11
# 8                   70        1.600000              21                24
# 9                   35        0.333333               1                 1
# 10                   0        0.000000               0                 0
# 11                  31        0.142857               1                 1
# 12                   2        0.000000               0                 0
# 13                 276       40.333333             189               242
# 14                 243        0.166667               1                 1
# 15                 171        6.263158              71               119
# 16                 764        6.933333              64               208
# 17                  32        0.153846               1                 2
# 18                1069        6.285714              51               220
# 19                1534       19.775510             245               969
# 20                 909       11.560000             158               578
# 21                 205       10.294118             111               175
# 22                 148       13.545455              51               149
# 23                  43       20.666667              56                62
# 24                   2       16.000000              16                16
# 25                 121       28.962963             708               782
# 26                   1        3.500000               6                 7
# 27                   8        2.500000              10                10
# 28                  19        6.666667              19                20
# 29                 104        4.750000              39                57
# ...                ...             ...             ...               ...
# 136131               1        0.000000               0                 0
# 136132             163        7.000000              21                28
# 136133               0        2.000000               2                 2
# 136134               4        0.000000               0                 0
# 136135               4        0.000000               0                 0
# 136136               2        0.000000               0                 0
# 136137               2        0.000000               0                 0
# 136138             207       19.357143             139               271
# 136139              86       16.875000              43               135
# 136140               1       39.333333             116               118
# 136141               0       36.000000              72                72
# 136142             133        6.666667              51               100
# 136143              44        4.272727              16                47
# 136144               0        0.000000               0                 0
# 136145             412       33.750000             195               270
# 136146              87       17.000000              83                85
# 136147              53        7.142857              47                50
# 136148              10        9.400000              47                47
# 136149              93       30.200000              68               151
# 136150              41       13.500000              39                81
# 136151              80       11.600000              78               116
# 136152              33        8.375000              55                67
# 136153             239       12.083333             100               145
# 136154              78        4.727273              22                52
# 136155              69       23.666667             215               284
# 136156              21        0.333333               1                 1
# 136157             335       41.909091             190               461
# 136158              67        9.666667              55                87
# 136159              46        0.666667               4                 4
# 136160              74        0.000000               0                 0
#
#         avg_ModifiedLOC  max_ModifiedLOC  total_ModifiedLOC
# 0              0.500000                2                  4
# 1              0.312500                1                  5
# 2              1.571429                3                 22
# 3              1.941176                7                 33
# 4              2.066667                5                 31
# 5              1.000000                2                  8
# 6              2.464286               14                 69
# 7              4.375000               19                 35
# 8              1.666667                6                 25
# 9              0.000000                0                  0
# 10             2.000000                2                  2
# 11             0.571429                3                  4
# 12             1.000000                1                  1
# 13            34.333333              152                206
# 14             2.333333                5                 14
# 15             8.263158               49                157
# 16            11.300000              102                339
# 17             0.769231                2                 10
# 18             9.171429               46                321
# 19            14.612245              136                716
# 20            16.380000              247                819
# 21            11.235294               49                191
# 22             5.727273               33                 63
# 23             8.333333               15                 25
# 24            24.000000               24                 24
# 25            31.074074              723                839
# 26             7.500000               10                 15
# 27             2.250000                5                  9
# 28             7.000000               18                 21
# 29             2.500000               11                 30
# ...                 ...              ...                ...
# 136131         0.000000                0                  0
# 136132         0.750000                1                  3
# 136133         0.000000                0                  0
# 136134         0.500000                1                  1
# 136135         0.000000                0                  0
# 136136         1.000000                1                  1
# 136137         1.000000                1                  1
# 136138         3.428571               12                 48
# 136139         3.250000                6                 26
# 136140         8.000000               18                 24
# 136141         5.000000                8                 10
# 136142         6.200000               24                 93
# 136143         4.545455               11                 50
# 136144         9.000000                9                  9
# 136145        11.125000               42                 89
# 136146         4.400000               16                 22
# 136147         4.571429               20                 32
# 136148         3.000000                7                 15
# 136149         3.000000               13                 15
# 136150         3.500000                8                 21
# 136151         7.100000               28                 71
# 136152         3.750000               10                 30
# 136153         6.333333               22                 76
# 136154         3.181818               10                 35
# 136155        12.750000               97                153
# 136156         1.333333                3                  4
# 136157        12.090909               30                133
# 136158         3.555556               10                 32
# 136159         2.166667                5                 13
# 136160         3.600000               10                 18
#
# [136161 rows x 73 columns]
