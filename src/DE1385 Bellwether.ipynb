# %%
import pandas as pd
import numpy as np
import math
import pickle

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold

import platform
from os import listdir
from os.path import isfile, join
from glob import glob
from pathlib import Path
import sys
import os
import copy
import traceback



import matplotlib.pyplot as plt

import SMOTE
import feature_selector
import DE
import CFS
import metrics.abcd

import metrices
import measures

import sys
import traceback
import warnings
warnings.filterwarnings("ignore")

# %%
data_source1 = '/Users/suvodeepmajumder/Documents/AI4SE/bellwether_comminity/data/1385/converted'
if platform.system() == 'Darwin' or platform.system() == 'Linux':
    _dir = data_source1 + '/'
else:
    _dir = data_source1 + '\\'
projects = [f for f in listdir(_dir) if isfile(join(_dir, f))]

# %%
def prepare_data(path):
    df = pd.read_csv(path)
    df = df.drop(labels = ['Host','Vcs','Project','File','PL','IssueTracking'],axis=1)
    df = df.dropna()
    df = df[['TLOC', 'TNF', 'TNC', 'TND', 'LOC', 'CL', 'NStmt', 'NFunc',
       'RCC', 'MNL', 'avg_WMC', 'max_WMC', 'total_WMC', 'avg_DIT', 'max_DIT',
       'total_DIT', 'avg_RFC', 'max_RFC', 'total_RFC', 'avg_NOC', 'max_NOC',
       'total_NOC', 'avg_CBO', 'max_CBO', 'total_CBO', 'avg_DIT.1',
       'max_DIT.1', 'total_DIT.1', 'avg_NIV', 'max_NIV', 'total_NIV',
       'avg_NIM', 'max_NIM', 'total_NIM', 'avg_NOM', 'max_NOM', 'total_NOM',
       'avg_NPBM', 'max_NPBM', 'total_NPBM', 'avg_NPM', 'max_NPM', 'total_NPM',
       'avg_NPRM', 'max_NPRM', 'total_NPRM', 'avg_CC', 'max_CC', 'total_CC',
       'avg_FANIN', 'max_FANIN', 'total_FANIN', 'avg_FANOUT', 'max_FANOUT',
       'total_FANOUT', 'NRev', 'NFix', 'avg_AddedLOC', 'max_AddedLOC',
       'total_AddedLOC', 'avg_DeletedLOC', 'max_DeletedLOC',
       'total_DeletedLOC', 'avg_ModifiedLOC', 'max_ModifiedLOC',
       'total_ModifiedLOC','Buggy']]
    return df

def get_features(df):
    fs = feature_selector.featureSelector()
    df,_feature_nums,features = fs.cfs_bfs(df)
    return df,features

def apply_cfs(df):
    y = df.Buggy.values
    X = df.drop(labels = ['Buggy'],axis = 1)
    X = X.values
    selected_cols = CFS.cfs(X,y)
    cols = df.columns[[selected_cols]].tolist()
    cols.append('Buggy')
    return df[cols],cols
    
def apply_smote(df):
    cols = df.columns
    smt = SMOTE.smote(df)
    df = smt.run()
    df.columns = cols
    return df

def tune_learner(learner, train_X, train_Y, tune_X, tune_Y, goal,loc=None,target_class=None):
    if not target_class:
        target_class = goal
    clf = learner(train_X, train_Y, tune_X, tune_Y, goal,loc)
    tuner = DE.DE_Tune_ML(clf, clf.get_param(), goal, target_class)
    return tuner.Tune()

# %%
class DE_Learners(object):
    def __init__(self, clf, train_X, train_Y, test_X, test_Y, goal,loc):
        """

        :param clf: classifier, SVM, etc...
        :param train_X: training data, independent variables.
        :param train_Y: training labels, dependent variables.
        :param predict_X: testing data, independent variables.
        :param predict_Y: testingd labels, dependent variables.
        :param goal: the objective of your tuning, F, recision,....
        """
        self.train_X = train_X
        self.train_Y = train_Y
        self.test_X = test_X
        self.test_Y = test_Y
        self.loc = loc
        self.goal = goal
        self.param_distribution = self.get_param()
        self.learner = clf
        self.confusion = None
        self.params = None
        
    def apply_smote(self,df,neighbours,r,up_to_num,auto):
        cols = df.columns
        smt = SMOTE.smote(df,neighbor = neighbours,r = r,up_to_num=up_to_num,auto=auto)
        df = smt.run()
        df.columns = cols
        return df

    def learn(self,F, **kwargs):
        """
        :param F: a dict, holds all scores, can be used during debugging
        :param kwargs: a dict, all the parameters need to set after tuning.
        :return: F, scores.
        """
        self.scores = {self.goal: [0.0]}
        try:   
            neighbours = kwargs.pop('neighbours')
            r = kwargs.pop('r')
            up_to_num = kwargs.pop('up_to_num')
            self.learner.set_params(**kwargs)
            _df = pd.concat([self.train_X, self.train_Y], axis = 1)
            _df = self.apply_smote(_df,neighbours,r,up_to_num,True)
            y_train = _df.Buggy
            X_train = _df.drop(labels = ['Buggy'],axis = 1)
            predict_result = []
            clf = self.learner.fit(X_train, y_train)
            predict_result = clf.predict(self.test_X)
            self.abcd = metrices.measures(self.test_Y,predict_result,self.loc)
            self.scores = self._Abcd(self.abcd,F)
            self.params = kwargs
        except Exception as e:
            #print(e)
            a = 10
        return self.scores
    
    def _Abcd(self,abcd , F):
        """

        :param predicted: predicted results(labels)
        :param actual: actual results(labels)
        :param F: previously got scores
        :return: updated scores.
        """
        if self.goal in ['f1','precision','recall','g-score','d2h','ifa','pci_20']:
            F['f1'] = [abcd.calculate_f1_score()]
            F['precision'] = [abcd.calculate_precision()]
            F['recall'] = [abcd.calculate_recall()]
            F['g-score'] = [abcd.get_g_score()]
            F['d2h'] = [abcd.calculate_d2h()]
            F['pci_20'] = [abcd.get_pci_20()]
            F['ifa'] = [abcd.get_ifa()]
            return F
        else:
            print("wronging goal")
            return F

    def predict(self,test_X):
        return self.learner.predict(test_X)

# %%
class SK_LR(DE_Learners):
    def __init__(self, train_x, train_y, predict_x, predict_y, goal,loc=None):
        clf = LogisticRegression()
        super(SK_LR, self).__init__(clf, train_x, train_y, predict_x, predict_y,goal,loc)

    def get_param(self):
        tunelst = {"penalty": ['l1', 'l2','elasticnet','none'],
                   "multi_class": ['ovr', 'multinomial','auto'],
                   "C": [1.0,200.0],
                   "dual": [True, False],
                   "fit_intercept": [True, False],
                   "intercept_scaling": [1.0,100.0],
                   "class_weight": ["balanced", 'none'],
                   "solver": ['newton-cg','lbfgs','liblinear','sag', 'saga'],
                   "warm_start": [True, False],
                   "max_iter": [100,600],
                   "neighbours": [5,21],
                   "r":[1,6],
                   "up_to_num": [1,4000]}
        return tunelst

# %%
final_score = {}
count = 0
for s_project in projects[0:10]:
    try:
        s_path = '/Users/suvodeepmajumder/Documents/AI4SE/bellwether_comminity/data/1385/converted/' + s_project
        print(s_project)
        df = prepare_data(s_path)
        if df.shape[0] < 50:
            continue
        else:
            count+=1
        df.reset_index(drop=True,inplace=True)
        d = {'buggy': True, 'clean': False}
        df['Buggy'] = df['Buggy'].map(d)
        #df,selected_cols = apply_cfs(df) # applying cfs above the loop
        y = df.Buggy
        X = df.drop(labels = ['Buggy'],axis = 1)
        kf = StratifiedKFold(n_splits = 5)
        goal = 'f1'
        learner = [SK_LR][0]
        F = {}
        score = {}
        for i in range(5):
            for train_index, tune_index in kf.split(X, y):
                X_train, X_tune = X.iloc[train_index], X.iloc[tune_index]
                y_train, y_tune = y[train_index], y[tune_index]
                _df = pd.concat([X_train,y_train], axis = 1) #applying DE inside loop
                _df,selected_cols = apply_cfs(_df)
                y_train = _df.Buggy
                X_train = _df.drop(labels = ['Buggy'],axis = 1)
                _df_tune = pd.concat([X_tune,y_tune], axis = 1)
                _df_tune_loc = _df_tune.LOC
                _df_tune = _df_tune[selected_cols]
                y_tune = _df_tune.Buggy
                X_tune = _df_tune.drop(labels = ['Buggy'],axis = 1)
                params, evaluation = tune_learner(learner, X_train, y_train,  X_tune,y_tune, goal,_df_tune_loc)  
                destination_projects = copy.deepcopy(projects)
                destination_projects.remove(s_project)
                for d_project in destination_projects:
                    try:
                        d_path = '/Users/suvodeepmajumder/Documents/AI4SE/bellwether_comminity/data/1385/converted/' + d_project
                        test_df = prepare_data(d_path)
                        if dest_df.shape[0] < 50:
                            continue
                        test_df.reset_index(drop=True,inplace=True)
                        d = {'buggy': True, 'clean': False}
                        test_df['Buggy'] = test_df['Buggy'].map(d)
                        df_test_loc = test_df.LOC
                        test_df = test_df[selected_cols]
                        test_y = test_df.Buggy
                        test_X = test_df.drop(labels = ['Buggy'],axis = 1)
                        clf = learner(X_train, y_train,  test_X,test_y, goal,df_test_loc)
                        F = clf.learn(F,**params)
                        _F = copy.deepcopy(F)
                        if 'f1' not in score.keys():
                            score[d_project] = _F
                        else:
                            score[d_project]['f1'].append(F['f1'][0])
                            score[d_project]['precision'].append(F['precision'][0])
                            score[d_project]['recall'].append(F['recall'][0])
                            score[d_project]['g-score'].append(F['g-score'][0])
                            score[d_project]['d2h'].append(F['d2h'][0])
                            score[d_project]['pci_20'].append(F['pci_20'][0])
                            score[d_project]['ifa'].append(F['ifa'][0])
                            score[d_project]['pd'].append(F['pd'][0])
                            score[d_project]['pf'].append(F['pf'][0])
                    except Exception as e:
                        print("Exception at test",s_project,d_project,e)
                        continue
            final_score[s_project] = score 
    except Exception as e:
        print("Exception at train",s_project,d_project,e)
        continue
# Out:
# bzbyte.csv
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test bzbyte.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# lcdata.csv
# llcon.csv
# freedom-erp.csv
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test freedom-erp.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# gpsee.csv
# twostep.csv
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv pde.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv eclipse.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv lucene.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv equinox.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# Exception at test twostep.csv mylyn.csv "['Host' 'Vcs' 'File' 'PL' 'IssueTracking'] not found in axis"
# tauruss.csv
# makumba.csv
# openi.csv
# pure-lang.csv

# %%
final_score
# Out:
# {'bzbyte.csv': {'lcdata.csv': {'f1': [0.33],
#    'precision': [0.25],
#    'recall': [0.5],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [87],
#    'ifa': [7]},
#   'llcon.csv': {'f1': [0.55],
#    'precision': [0.49],
#    'recall': [0.62],
#    'g-score': [0.0],
#    'd2h': [1.01],
#    'pci_20': [97],
#    'ifa': [0]},
#   'freedom-erp.csv': {'f1': [0.68],
#    'precision': [0.68],
#    'recall': [0.68],
#    'g-score': [0.72],
#    'd2h': [0.51],
#    'pci_20': [99],
#    'ifa': [8]},
#   'gpsee.csv': {'f1': [0.29],
#    'precision': [0.45],
#    'recall': [0.38],
#    'g-score': [0.34],
#    'd2h': [0.92],
#    'pci_20': [97],
#    'ifa': [2]},
#   'twostep.csv': {'f1': [0.24],
#    'precision': [0.45],
#    'recall': [0.37],
#    'g-score': [0.17],
#    'd2h': [0.96],
#    'pci_20': [98],
#    'ifa': [1]},
#   'tauruss.csv': {'f1': [0.0]},
#   'makumba.csv': {'f1': [0.45],
#    'precision': [0.59],
#    'recall': [0.46],
#    'g-score': [0.36],
#    'd2h': [0.73],
#    'pci_20': [97],
#    'ifa': [6]},
#   'openi.csv': {'f1': [0.52],
#    'precision': [0.52],
#    'recall': [0.53],
#    'g-score': [0.56],
#    'd2h': [0.75],
#    'pci_20': [97],
#    'ifa': [2]},
#   'pure-lang.csv': {'f1': [0.44],
#    'precision': [0.56],
#    'recall': [0.45],
#    'g-score': [0.56],
#    'd2h': [0.75],
#    'pci_20': [95],
#    'ifa': [0]},
#   'roguelike.csv': {'f1': [0.34],
#    'precision': [0.76],
#    'recall': [0.22],
#    'g-score': [0.0],
#    'd2h': [1.26],
#    'pci_20': [94],
#    'ifa': [17]},
#   'iaml.csv': {'f1': [0.39],
#    'precision': [0.38],
#    'recall': [0.39],
#    'g-score': [0.42],
#    'd2h': [0.9],
#    'pci_20': [99],
#    'ifa': [0]},
#   'wiquery.csv': {'f1': [0.0]},
#   'etics.csv': {'f1': [0.66],
#    'precision': [0.73],
#    'recall': [0.64],
#    'g-score': [0.62],
#    'd2h': [0.52],
#    'pci_20': [98],
#    'ifa': [0]},
#   'neoengine.csv': {'f1': [0.34],
#    'precision': [0.5],
#    'recall': [0.4],
#    'g-score': [0.43],
#    'd2h': [0.87],
#    'pci_20': [99],
#    'ifa': [5]},
#   'owasp-esapi-java.csv': {'f1': [0.26],
#    'precision': [0.81],
#    'recall': [0.35],
#    'g-score': [0.38],
#    'd2h': [0.89],
#    'pci_20': [96],
#    'ifa': [5]},
#   'voot.csv': {'f1': [0.37],
#    'precision': [0.76],
#    'recall': [0.51],
#    'g-score': [0.21],
#    'd2h': [0.95],
#    'pci_20': [97],
#    'ifa': [0]},
#   'nsis.csv': {'f1': [0.55],
#    'precision': [0.86],
#    'recall': [0.44],
#    'g-score': [0.45],
#    'd2h': [0.71],
#    'pci_20': [98],
#    'ifa': [3]},
#   'vdsf.csv': {'f1': [0.1],
#    'precision': [0.66],
#    'recall': [0.11],
#    'g-score': [0.2],
#    'd2h': [0.97],
#    'pci_20': [99],
#    'ifa': [4]},
#   'airhead-research.csv': {'f1': [0.8],
#    'precision': [0.82],
#    'recall': [0.78],
#    'g-score': [0.51],
#    'd2h': [0.82],
#    'pci_20': [97],
#    'ifa': [1]},
#   'monetdb.csv': {'f1': [0.49],
#    'precision': [0.58],
#    'recall': [0.48],
#    'g-score': [0.57],
#    'd2h': [0.7],
#    'pci_20': [99],
#    'ifa': [1]},
#   'x10.csv': {'f1': [0.4],
#    'precision': [0.85],
#    'recall': [0.4],
#    'g-score': [0.62],
#    'd2h': [0.75],
#    'pci_20': [80],
#    'ifa': [1]},
#   'wmii.csv': {'f1': [0.66],
#    'precision': [0.83],
#    'recall': [0.62],
#    'g-score': [0.61],
#    'd2h': [0.46],
#    'pci_20': [97],
#    'ifa': [3]},
#   'bungeni-editor.csv': {'f1': [0.36],
#    'precision': [0.8],
#    'recall': [0.42],
#    'g-score': [0.51],
#    'd2h': [0.83],
#    'pci_20': [96],
#    'ifa': [6]},
#   'openejb.csv': {'f1': [0.13],
#    'precision': [0.94],
#    'recall': [0.13],
#    'g-score': [0.27],
#    'd2h': [0.93],
#    'pci_20': [96],
#    'ifa': [24]},
#   'gogglesmm.csv': {'f1': [0.37],
#    'precision': [0.48],
#    'recall': [0.41],
#    'g-score': [0.49],
#    'd2h': [0.84],
#    'pci_20': [97],
#    'ifa': [3]},
#   'workhub2.csv': {'f1': [0.51],
#    'precision': [0.64],
#    'recall': [0.44],
#    'g-score': [0.33],
#    'd2h': [0.99],
#    'pci_20': [97],
#    'ifa': [4]},
#   'amygdala.csv': {'f1': [0.59],
#    'precision': [0.61],
#    'recall': [0.6],
#    'g-score': [0.66],
#    'd2h': [0.64],
#    'pci_20': [98],
#    'ifa': [0]},
#   'mozzie.csv': {'f1': [0.0]},
#   'ikvm.csv': {'f1': [0.48],
#    'precision': [0.56],
#    'recall': [0.5],
#    'g-score': [0.59],
#    'd2h': [0.74],
#    'pci_20': [98],
#    'ifa': [2]},
#   'gild.csv': {'f1': [0.53],
#    'precision': [0.44],
#    'recall': [0.67],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [66],
#    'ifa': [0]},
#   'jicarilla.csv': {'f1': [0.36],
#    'precision': [0.76],
#    'recall': [0.5],
#    'g-score': [0.21],
#    'd2h': [0.95],
#    'pci_20': [98],
#    'ifa': [21]},
#   'arcanea-project.csv': {'f1': [0.72],
#    'precision': [0.83],
#    'recall': [0.75],
#    'g-score': [0.78],
#    'd2h': [0.58],
#    'pci_20': [97],
#    'ifa': [0]},
#   'vito.csv': {'f1': [0.46],
#    'precision': [0.6],
#    'recall': [0.48],
#    'g-score': [0.59],
#    'd2h': [0.74],
#    'pci_20': [96],
#    'ifa': [0]},
#   'middle-man.csv': {'f1': [0.45],
#    'precision': [0.53],
#    'recall': [0.47],
#    'g-score': [0.56],
#    'd2h': [0.75],
#    'pci_20': [97],
#    'ifa': [3]},
#   'pernband.csv': {'f1': [0.51],
#    'precision': [0.55],
#    'recall': [0.5],
#    'g-score': [0.49],
#    'd2h': [0.7],
#    'pci_20': [97],
#    'ifa': [5]},
#   'aquachat.csv': {'f1': [0.17],
#    'precision': [0.58],
#    'recall': [0.19],
#    'g-score': [0.3],
#    'd2h': [0.94],
#    'pci_20': [96],
#    'ifa': [10]},
#   'tgl.csv': {'f1': [0.46],
#    'precision': [0.45],
#    'recall': [0.46],
#    'g-score': [0.49],
#    'd2h': [0.79],
#    'pci_20': [95],
#    'ifa': [12]},
#   'guitoo.csv': {'f1': [0.78],
#    'precision': [0.86],
#    'recall': [0.79],
#    'g-score': [0.67],
#    'd2h': [0.38],
#    'pci_20': [92],
#    'ifa': [0]},
#   'vrmoo.csv': {'f1': [0.38],
#    'precision': [0.76],
#    'recall': [0.39],
#    'g-score': [0.58],
#    'd2h': [0.77],
#    'pci_20': [97],
#    'ifa': [4]},
#   'j4fry.csv': {'f1': [0.47],
#    'precision': [0.58],
#    'recall': [0.46],
#    'g-score': [0.58],
#    'd2h': [0.71],
#    'pci_20': [96],
#    'ifa': [7]},
#   'metacosm.csv': {'f1': [0.6],
#    'precision': [0.61],
#    'recall': [0.6],
#    'g-score': [0.64],
#    'd2h': [0.56],
#    'pci_20': [98],
#    'ifa': [2]},
#   'mplayer-ce.csv': {'f1': [0.28],
#    'precision': [0.2],
#    'recall': [0.45],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [99],
#    'ifa': [2]},
#   'moviesandbox.csv': {'f1': [0.48],
#    'precision': [0.49],
#    'recall': [0.52],
#    'g-score': [0.52],
#    'd2h': [0.81],
#    'pci_20': [98],
#    'ifa': [0]},
#   'uwom.csv': {'f1': [0.15],
#    'precision': [0.45],
#    'recall': [0.22],
#    'g-score': [0.23],
#    'd2h': [0.96],
#    'pci_20': [99],
#    'ifa': [92]},
#   'geotools.csv': {'f1': [0.38],
#    'precision': [0.65],
#    'recall': [0.4],
#    'g-score': [0.55],
#    'd2h': [0.78],
#    'pci_20': [99],
#    'ifa': [1]},
#   'jrdf.csv': {'f1': [0.17],
#    'precision': [0.68],
#    'recall': [0.24],
#    'g-score': [0.27],
#    'd2h': [0.93],
#    'pci_20': [98],
#    'ifa': [20]},
#   'chatforte.csv': {'f1': [0.43],
#    'precision': [0.69],
#    'recall': [0.44],
#    'g-score': [0.61],
#    'd2h': [0.74],
#    'pci_20': [96],
#    'ifa': [2]},
#   'ng4j.csv': {'f1': [0.27],
#    'precision': [0.82],
#    'recall': [0.34],
#    'g-score': [0.41],
#    'd2h': [0.88],
#    'pci_20': [98],
#    'ifa': [10]},
#   'bloodycore.csv': {'f1': [0.63],
#    'precision': [0.77],
#    'recall': [0.57],
#    'g-score': [0.56],
#    'd2h': [0.62],
#    'pci_20': [99],
#    'ifa': [10]},
#   'allacrost.csv': {'f1': [0.46],
#    'precision': [0.66],
#    'recall': [0.48],
#    'g-score': [0.62],
#    'd2h': [0.72],
#    'pci_20': [97],
#    'ifa': [2]},
#   'jahshakafx.csv': {'f1': [0.32],
#    'precision': [0.43],
#    'recall': [0.32],
#    'g-score': [0.41],
#    'd2h': [0.91],
#    'pci_20': [99],
#    'ifa': [109]},
#   'jstock.csv': {'f1': [0.12],
#    'precision': [0.82],
#    'recall': [0.25],
#    'g-score': [0.09],
#    'd2h': [0.98],
#    'pci_20': [98],
#    'ifa': [15]},
#   'nassp.csv': {'f1': [0.39],
#    'precision': [0.73],
#    'recall': [0.38],
#    'g-score': [0.58],
#    'd2h': [0.76],
#    'pci_20': [98],
#    'ifa': [7]},
#   'phission.csv': {'f1': [0.57],
#    'precision': [0.58],
#    'recall': [0.58],
#    'g-score': [0.63],
#    'd2h': [0.63],
#    'pci_20': [94],
#    'ifa': [0]},
#   'soar.csv': {'f1': [0.5],
#    'precision': [0.5],
#    'recall': [0.52],
#    'g-score': [0.54],
#    'd2h': [0.78],
#    'pci_20': [98],
#    'ifa': [1]},
#   'xbplayer.csv': {'f1': [0.33],
#    'precision': [0.67],
#    'recall': [0.4],
#    'g-score': [0.46],
#    'd2h': [0.85],
#    'pci_20': [99],
#    'ifa': [5]},
#   'scite-ru.csv': {'f1': [0.45],
#    'precision': [0.73],
#    'recall': [0.47],
#    'g-score': [0.63],
#    'd2h': [0.72],
#    'pci_20': [98],
#    'ifa': [38]},
#   'mixxx.csv': {'f1': [0.46],
#    'precision': [0.5],
#    'recall': [0.45],
#    'g-score': [0.44],
#    'd2h': [0.76],
#    'pci_20': [90],
#    'ifa': [5]},
#   'toop.csv': {'f1': [0.89],
#    'precision': [0.92],
#    'recall': [0.91],
#    'g-score': [0.56],
#    'd2h': [0.8],
#    'pci_20': [97],
#    'ifa': [0]},
#   'mobicents.csv': {'f1': [0.52],
#    'precision': [0.52],
#    'recall': [0.52],
#    'g-score': [0.56],
#    'd2h': [0.69],
#    'pci_20': [99],
#    'ifa': [0]},
#   'openwebbuilder.csv': {'f1': [0.61],
#    'precision': [0.61],
#    'recall': [0.61],
#    'g-score': [0.55],
#    'd2h': [0.57],
#    'pci_20': [97],
#    'ifa': [4]},
#   'google-secure-data-connector.csv': {'f1': [0.63],
#    'precision': [0.74],
#    'recall': [0.56],
#    'g-score': [0.0],
#    'd2h': [1.07],
#    'pci_20': [94],
#    'ifa': [1]},
#   'opencollada.csv': {'f1': [0.48],
#    'precision': [0.77],
#    'recall': [0.48],
#    'g-score': [0.67],
#    'd2h': [0.67],
#    'pci_20': [97],
#    'ifa': [0]},
#   'jcache.csv': {'f1': [0.48],
#    'precision': [0.63],
#    'recall': [0.53],
#    'g-score': [0.56],
#    'd2h': [0.79],
#    'pci_20': [98],
#    'ifa': [3]},
#   'flylegacy.csv': {'f1': [0.6],
#    'precision': [0.6],
#    'recall': [0.6],
#    'g-score': [0.51],
#    'd2h': [0.82],
#    'pci_20': [98],
#    'ifa': [0]},
#   'mcmc-jags.csv': {'f1': [0.54],
#    'precision': [0.64],
#    'recall': [0.51],
#    'g-score': [0.57],
#    'd2h': [0.66],
#    'pci_20': [98],
#    'ifa': [12]},
#   'mcore3d.csv': {'f1': [0.43],
#    'precision': [0.63],
#    'recall': [0.45],
#    'g-score': [0.31],
#    'd2h': [0.75],
#    'pci_20': [99],
#    'ifa': [9]},
#   'gdis.csv': {'f1': [0.74],
#    'precision': [0.73],
#    'recall': [0.76],
#    'g-score': [0.56],
#    'd2h': [0.78],
#    'pci_20': [98],
#    'ifa': [1]},
#   'gtad.csv': {'f1': [0.68],
#    'precision': [0.97],
#    'recall': [0.55],
#    'g-score': [0.85],
#    'd2h': [0.46],
#    'pci_20': [98],
#    'ifa': [6]},
#   'liferea.csv': {'f1': [0.7],
#    'precision': [0.72],
#    'recall': [0.77],
#    'g-score': [0.1],
#    'd2h': [0.92],
#    'pci_20': [98],
#    'ifa': [33]},
#   'nova.csv': {'f1': [0.66],
#    'precision': [0.75],
#    'recall': [0.63],
#    'g-score': [0.67],
#    'd2h': [0.49],
#    'pci_20': [98],
#    'ifa': [26]},
#   'spinn3r-client.csv': {'f1': [0.44],
#    'precision': [0.43],
#    'recall': [0.5],
#    'g-score': [0.33],
#    'd2h': [0.93],
#    'pci_20': [95],
#    'ifa': [0]},
#   'fleet-simulator.csv': {'f1': [0.81],
#    'precision': [0.92],
#    'recall': [0.77],
#    'g-score': [0.78],
#    'd2h': [0.26],
#    'pci_20': [98],
#    'ifa': [0]},
#   'japano.csv': {'f1': [0.83],
#    'precision': [0.87],
#    'recall': [0.79],
#    'g-score': [0.36],
#    'd2h': [0.9],
#    'pci_20': [99],
#    'ifa': [6]},
#   'rocket-gwt.csv': {'f1': [0.73],
#    'precision': [0.81],
#    'recall': [0.7],
#    'g-score': [0.74],
#    'd2h': [0.4],
#    'pci_20': [95],
#    'ifa': [0]},
#   'facecart.csv': {'f1': [0.43],
#    'precision': [0.53],
#    'recall': [0.42],
#    'g-score': [0.52],
#    'd2h': [0.78],
#    'pci_20': [96],
#    'ifa': [2]},
#   'swecr.csv': {'f1': [0.47],
#    'precision': [0.8],
#    'recall': [0.38],
#    'g-score': [0.53],
#    'd2h': [0.76],
#    'pci_20': [97],
#    'ifa': [10]},
#   'apophenia.csv': {'f1': [0.66],
#    'precision': [0.96],
#    'recall': [0.55],
#    'g-score': [0.58],
#    'd2h': [0.48],
#    'pci_20': [95],
#    'ifa': [0]},
#   'nemerle.csv': {'f1': [0.6],
#    'precision': [0.55],
#    'recall': [0.67],
#    'g-score': [0.0],
#    'd2h': [1.01],
#    'pci_20': [91],
#    'ifa': [0]},
#   'qmcpack.csv': {'f1': [0.28],
#    'precision': [0.59],
#    'recall': [0.36],
#    'g-score': [0.37],
#    'd2h': [0.89],
#    'pci_20': [98],
#    'ifa': [5]},
#   'android-scripting.csv': {'f1': [0.33],
#    'precision': [0.81],
#    'recall': [0.38],
#    'g-score': [0.49],
#    'd2h': [0.84],
#    'pci_20': [97],
#    'ifa': [5]},
#   'gnukeda.csv': {'f1': [0.57],
#    'precision': [0.62],
#    'recall': [0.58],
#    'g-score': [0.45],
#    'd2h': [0.63],
#    'pci_20': [98],
#    'ifa': [0]},
#   'jaffa.csv': {'f1': [0.45],
#    'precision': [0.59],
#    'recall': [0.41],
#    'g-score': [0.47],
#    'd2h': [0.79],
#    'pci_20': [94],
#    'ifa': [10]},
#   'powerfolder-.csv': {'f1': [0.22],
#    'precision': [0.59],
#    'recall': [0.32],
#    'g-score': [0.27],
#    'd2h': [0.93],
#    'pci_20': [99],
#    'ifa': [0]},
#   'javapalm.csv': {'f1': [0.35],
#    'precision': [0.55],
#    'recall': [0.38],
#    'g-score': [0.5],
#    'd2h': [0.82],
#    'pci_20': [97],
#    'ifa': [14]},
#   'jparsec.csv': {'f1': [0.31],
#    'precision': [0.52],
#    'recall': [0.41],
#    'g-score': [0.32],
#    'd2h': [0.92],
#    'pci_20': [99],
#    'ifa': [0]},
#   'webswell.csv': {'f1': [0.4],
#    'precision': [0.47],
#    'recall': [0.4],
#    'g-score': [0.48],
#    'd2h': [0.82],
#    'pci_20': [96],
#    'ifa': [5]},
#   'm-m-m.csv': {'f1': [0.51],
#    'precision': [0.65],
#    'recall': [0.44],
#    'g-score': [0.38],
#    'd2h': [0.95],
#    'pci_20': [98],
#    'ifa': [2]},
#   'adonthell.csv': {'f1': [0.43],
#    'precision': [0.5],
#    'recall': [0.55],
#    'g-score': [0.24],
#    'd2h': [0.94],
#    'pci_20': [99],
#    'ifa': [0]},
#   'uml.csv': {'f1': [0.6],
#    'precision': [0.6],
#    'recall': [0.6],
#    'g-score': [0.0],
#    'd2h': [1.03],
#    'pci_20': [95],
#    'ifa': [0]},
#   'gauche.csv': {'f1': [0.41],
#    'precision': [0.67],
#    'recall': [0.41],
#    'g-score': [0.58],
#    'd2h': [0.75],
#    'pci_20': [97],
#    'ifa': [14]},
#   'route-me.csv': {'f1': [0.34],
#    'precision': [0.28],
#    'recall': [0.45],
#    'g-score': [0.0],
#    'd2h': [1.02],
#    'pci_20': [95],
#    'ifa': [0]},
#   'k3d.csv': {'f1': [0.67],
#    'precision': [0.77],
#    'recall': [0.62],
#    'g-score': [0.46],
#    'd2h': [0.67],
#    'pci_20': [99],
#    'ifa': [0]},
#   'fmri-dmt.csv': {'f1': [0.37],
#    'precision': [0.92],
#    'recall': [0.31],
#    'g-score': [0.61],
#    'd2h': [0.76],
#    'pci_20': [98],
#    'ifa': [0]},
#   'amanda.csv': {'f1': [0.63],
#    'precision': [0.63],
#    'recall': [0.63],
#    'g-score': [0.54],
#    'd2h': [0.56],
#    'pci_20': [99],
#    'ifa': [4]},
#   'jaql.csv': {'f1': [0.45],
#    'precision': [0.54],
#    'recall': [0.46],
#    'g-score': [0.56],
#    'd2h': [0.75],
#    'pci_20': [99],
#    'ifa': [5]},
#   'jacareto.csv': {'f1': [0.57],
#    'precision': [0.89],
#    'recall': [0.44],
#    'g-score': [0.49],
#    'd2h': [0.75],
#    'pci_20': [97],
#    'ifa': [11]},
#   'gridbusbroker.csv': {'f1': [0.48],
#    'precision': [0.6],
#    'recall': [0.48],
#    'g-score': [0.59],
#    'd2h': [0.7],
#    'pci_20': [97],
#    'ifa': [4]},
#   'vars-redux.csv': {'f1': [0.54],
#    'precision': [0.64],
#    'recall': [0.56],
#    'g-score': [0.66],
#    'd2h': [0.66],
#    'pci_20': [99],
#    'ifa': [1]},
#   'plog4u.csv': {'f1': [0.02],
#    'precision': [0.99],
#    'recall': [0.02],
#    'g-score': [0.05],
#    'd2h': [0.99],
#    'pci_20': [99],
#    'ifa': [62]},
#   'unistat.csv': {'f1': [0.37],
#    'precision': [0.92],
#    'recall': [0.31],
#    'g-score': [0.61],
#    'd2h': [0.76],
#    'pci_20': [96],
#    'ifa': [4]},
#   'megameknet.csv': {'f1': [0.55],
#    'precision': [0.76],
#    'recall': [0.52],
#    'g-score': [0.69],
#    'd2h': [0.59],
#    'pci_20': [99],
#    'ifa': [0]},
#   'freedots.csv': {'f1': [0.02],
#    'precision': [0.01],
#    'recall': [0.11],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [88],
#    'ifa': [5]},
#   'zxtune.csv': {'f1': [0.69],
#    'precision': [0.76],
#    'recall': [0.65],
#    'g-score': [0.65],
#    'd2h': [0.52],
#    'pci_20': [96],
#    'ifa': [0]},
#   'autoopencas.csv': {'f1': [0.57],
#    'precision': [0.67],
#    'recall': [0.54],
#    'g-score': [0.61],
#    'd2h': [0.61],
#    'pci_20': [99],
#    'ifa': [52]},
#   'rails.csv': {'f1': [0.74],
#    'precision': [0.74],
#    'recall': [0.75],
#    'g-score': [0.76],
#    'd2h': [0.52],
#    'pci_20': [91],
#    'ifa': [1]},
#   'arianne.csv': {'f1': [0.49],
#    'precision': [0.53],
#    'recall': [0.52],
#    'g-score': [0.56],
#    'd2h': [0.76],
#    'pci_20': [99],
#    'ifa': [0]},
#   'sumatrapdf.csv': {'f1': [0.62],
#    'precision': [0.68],
#    'recall': [0.62],
#    'g-score': [0.69],
#    'd2h': [0.52],
#    'pci_20': [98],
#    'ifa': [7]},
#   'powerfolder.csv': {'f1': [0.32],
#    'precision': [0.96],
#    'recall': [0.23],
#    'g-score': [0.56],
#    'd2h': [0.8],
#    'pci_20': [99],
#    'ifa': [11]},
#   'replicatorg.csv': {'f1': [0.6],
#    'precision': [0.84],
#    'recall': [0.59],
#    'g-score': [0.8],
#    'd2h': [0.55],
#    'pci_20': [97],
#    'ifa': [0]},
#   'openxava.csv': {'f1': [0.05],
#    'precision': [0.61],
#    'recall': [0.11],
#    'g-score': [0.09],
#    'd2h': [0.99],
#    'pci_20': [99],
#    'ifa': [10]},
#   'moviejukebox.csv': {'f1': [0.8],
#    'precision': [0.8],
#    'recall': [0.8],
#    'g-score': [0.53],
#    'd2h': [0.81],
#    'pci_20': [97],
#    'ifa': [0]},
#   'somap.csv': {'f1': [0.77],
#    'precision': [0.87],
#    'recall': [0.71],
#    'g-score': [0.59],
#    'd2h': [0.72],
#    'pci_20': [98],
#    'ifa': [0]},
#   'elateportal.csv': {'f1': [0.9],
#    'precision': [0.93],
#    'recall': [0.92],
#    'g-score': [0.71],
#    'd2h': [0.67],
#    'pci_20': [98],
#    'ifa': [3]},
#   'wifidog.csv': {'f1': [0.57],
#    'precision': [0.6],
#    'recall': [0.56],
#    'g-score': [0.56],
#    'd2h': [0.71],
#    'pci_20': [94],
#    'ifa': [3]},
#   'grok.csv': {'f1': [0.57],
#    'precision': [0.58],
#    'recall': [0.57],
#    'g-score': [0.6],
#    'd2h': [0.6],
#    'pci_20': [97],
#    'ifa': [0]},
#   'google-guice.csv': {'f1': [0.76],
#    'precision': [0.79],
#    'recall': [0.73],
#    'g-score': [0.0],
#    'd2h': [1.02],
#    'pci_20': [96],
#    'ifa': [0]},
#   'beepmp.csv': {'f1': [0.71],
#    'precision': [0.74],
#    'recall': [0.7],
#    'g-score': [0.7],
#    'd2h': [0.48],
#    'pci_20': [95],
#    'ifa': [2]},
#   'lcfizvtop.csv': {'f1': [0.44],
#    'precision': [0.68],
#    'recall': [0.39],
#    'g-score': [0.54],
#    'd2h': [0.76],
#    'pci_20': [98],
#    'ifa': [26]},
#   'arm-webradio.csv': {'f1': [0.11],
#    'precision': [0.07],
#    'recall': [0.27],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [99],
#    'ifa': [0]},
#   'geogebra.csv': {'f1': [0.34],
#    'precision': [0.75],
#    'recall': [0.36],
#    'g-score': [0.53],
#    'd2h': [0.81],
#    'pci_20': [99],
#    'ifa': [0]},
#   'jrds.csv': {'f1': [0.43],
#    'precision': [0.64],
#    'recall': [0.48],
#    'g-score': [0.57],
#    'd2h': [0.77],
#    'pci_20': [97],
#    'ifa': [6]},
#   'dvd-create.csv': {'f1': [0.58],
#    'precision': [0.84],
#    'recall': [0.54],
#    'g-score': [0.5],
#    'd2h': [0.56],
#    'pci_20': [98],
#    'ifa': [5]},
#   'blackholespam.csv': {'f1': [0.44],
#    'precision': [0.47],
#    'recall': [0.43],
#    'g-score': [0.41],
#    'd2h': [0.82],
#    'pci_20': [92],
#    'ifa': [1]},
#   'mockcpp.csv': {'f1': [0.08],
#    'precision': [0.05],
#    'recall': [0.23],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [95],
#    'ifa': [5]},
#   'xinity.csv': {'f1': [0.51],
#    'precision': [0.52],
#    'recall': [0.51],
#    'g-score': [0.52],
#    'd2h': [0.72],
#    'pci_20': [98],
#    'ifa': [7]},
#   'tdt.csv': {'f1': [0.16],
#    'precision': [0.64],
#    'recall': [0.09],
#    'g-score': [0.0],
#    'd2h': [1.35],
#    'pci_20': [95],
#    'ifa': [21]},
#   'mosesdecoder.csv': {'f1': [0.48],
#    'precision': [0.82],
#    'recall': [0.5],
#    'g-score': [0.68],
#    'd2h': [0.7],
#    'pci_20': [92],
#    'ifa': [0]},
#   'jython.csv': {'f1': [0.13],
#    'precision': [0.41],
#    'recall': [0.12],
#    'g-score': [0.21],
#    'd2h': [1.12],
#    'pci_20': [99],
#    'ifa': [102]},
#   'freemarker.csv': {'f1': [0.32],
#    'precision': [0.59],
#    'recall': [0.37],
#    'g-score': [0.47],
#    'd2h': [0.84],
#    'pci_20': [97],
#    'ifa': [0]},
#   'gnupdate.csv': {'f1': [0.74],
#    'precision': [0.74],
#    'recall': [0.75],
#    'g-score': [0.29],
#    'd2h': [0.76],
#    'pci_20': [99],
#    'ifa': [9]},
#   'gstreamer.csv': {'f1': [0.65],
#    'precision': [0.65],
#    'recall': [0.66],
#    'g-score': [0.69],
#    'd2h': [0.53],
#    'pci_20': [99],
#    'ifa': [0]},
#   'cs-javaphp.csv': {'f1': [0.49],
#    'precision': [0.53],
#    'recall': [0.55],
#    'g-score': [0.51],
#    'd2h': [0.82],
#    'pci_20': [90],
#    'ifa': [1]},
#   'plearn.csv': {'f1': [0.5],
#    'precision': [0.66],
#    'recall': [0.49],
#    'g-score': [0.63],
#    'd2h': [0.67],
#    'pci_20': [99],
#    'ifa': [0]},
#   'aost.csv': {'f1': [0.29],
#    'precision': [0.38],
#    'recall': [0.23],
#    'g-score': [0.0],
#    'd2h': [1.22],
#    'pci_20': [92],
#    'ifa': [12]},
#   'gpac.csv': {'f1': [0.53],
#    'precision': [0.59],
#    'recall': [0.58],
#    'g-score': [0.56],
#    'd2h': [0.78],
#    'pci_20': [99],
#    'ifa': [1]},
#   'aten.csv': {'f1': [0.82],
#    'precision': [0.99],
#    'recall': [0.71],
#    'g-score': [0.0],
#    'd2h': [1.04],
#    'pci_20': [99],
#    'ifa': [2]},
#   'bitpeddler.csv': {'f1': [0.31],
#    'precision': [0.76],
#    'recall': [0.29],
#    'g-score': [0.5],
#    'd2h': [0.82],
#    'pci_20': [97],
#    'ifa': [2]},
#   'reportmaster.csv': {'f1': [0.71],
#    'precision': [0.83],
#    'recall': [0.68],
#    'g-score': [0.82],
#    'd2h': [0.39],
#    'pci_20': [97],
#    'ifa': [0]},
#   'systats.csv': {'f1': [0.75],
#    'precision': [0.74],
#    'recall': [0.76],
#    'g-score': [0.48],
#    'd2h': [0.58],
#    'pci_20': [96],
#    'ifa': [2]},
#   'quark.csv': {'f1': [0.73],
#    'precision': [0.74],
#    'recall': [0.72],
#    'g-score': [0.43],
#    'd2h': [0.64],
#    'pci_20': [98],
#    'ifa': [2]},
#   'xemeiah.csv': {'f1': [0.35],
#    'precision': [0.41],
#    'recall': [0.43],
#    'g-score': [0.33],
#    'd2h': [0.92],
#    'pci_20': [99],
#    'ifa': [2]},
#   'unflobtactical.csv': {'f1': [0.56],
#    'precision': [0.58],
#    'recall': [0.56],
#    'g-score': [0.52],
#    'd2h': [0.62],
#    'pci_20': [98],
#    'ifa': [4]},
#   'irad.csv': {'f1': [0.7],
#    'precision': [0.62],
#    'recall': [0.79],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [97],
#    'ifa': [37]},
#   'robocup-msl.csv': {'f1': [0.33],
#    'precision': [0.25],
#    'recall': [0.5],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [50],
#    'ifa': [1]},
#   'web-cat.csv': {'f1': [0.33],
#    'precision': [0.77],
#    'recall': [0.44],
#    'g-score': [0.36],
#    'd2h': [0.9],
#    'pci_20': [98],
#    'ifa': [1]},
#   'biodwh.csv': {'f1': [0.45],
#    'precision': [0.81],
#    'recall': [0.4],
#    'g-score': [0.63],
#    'd2h': [0.7],
#    'pci_20': [98],
#    'ifa': [3]},
#   'buddata-ebxml-registry.csv': {'f1': [0.65],
#    'precision': [0.9],
#    'recall': [0.54],
#    'g-score': [0.53],
#    'd2h': [0.68],
#    'pci_20': [98],
#    'ifa': [3]},
#   'crisscross.csv': {'f1': [0.64],
#    'precision': [0.78],
#    'recall': [0.6],
#    'g-score': [0.65],
#    'd2h': [0.54],
#    'pci_20': [99],
#    'ifa': [0]},
#   'ofbiz.csv': {'f1': [0.59],
#    'precision': [0.58],
#    'recall': [0.62],
#    'g-score': [0.56],
#    'd2h': [0.78],
#    'pci_20': [99],
#    'ifa': [0]},
#   'hawkscope.csv': {'f1': [0.42],
#    'precision': [0.33],
#    'recall': [0.57],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [97],
#    'ifa': [0]},
#   'openstreaming.csv': {'f1': [0.36],
#    'precision': [0.46],
#    'recall': [0.33],
#    'g-score': [0.38],
#    'd2h': [0.92],
#    'pci_20': [94],
#    'ifa': [13]},
#   'mptvseries.csv': {'f1': [0.42],
#    'precision': [0.41],
#    'recall': [0.42],
#    'g-score': [0.24],
#    'd2h': [0.91],
#    'pci_20': [98],
#    'ifa': [27]},
#   'clisp.csv': {'f1': [0.42],
#    'precision': [0.33],
#    'recall': [0.57],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [85],
#    'ifa': [0]},
#   'freelords.csv': {'f1': [0.68],
#    'precision': [0.67],
#    'recall': [0.68],
#    'g-score': [0.64],
#    'd2h': [0.67],
#    'pci_20': [99],
#    'ifa': [0]},
#   'delphilhlplib.csv': {'f1': [0.6],
#    'precision': [0.74],
#    'recall': [0.58],
#    'g-score': [0.55],
#    'd2h': [0.54],
#    'pci_20': [98],
#    'ifa': [1]},
#   'wow-qrsk.csv': {'f1': [0.47],
#    'precision': [0.73],
#    'recall': [0.43],
#    'g-score': [0.61],
#    'd2h': [0.69],
#    'pci_20': [99],
#    'ifa': [93]},
#   'les-indemodables.csv': {'f1': [0.7],
#    'precision': [0.7],
#    'recall': [0.71],
#    'g-score': [0.58],
#    'd2h': [0.5],
#    'pci_20': [99],
#    'ifa': [0]},
#   'runuomondains.csv': {'f1': [0.8],
#    'precision': [0.83],
#    'recall': [0.78],
#    'g-score': [0.43],
#    'd2h': [0.65],
#    'pci_20': [98],
#    'ifa': [1]},
#   'ncut.csv': {'f1': [1.0],
#    'precision': [1.0],
#    'recall': [1.0],
#    'g-score': [1.0],
#    'd2h': [0.0],
#    'pci_20': [50],
#    'ifa': [1]},
#   'japi.csv': {'f1': [0.5],
#    'precision': [0.53],
#    'recall': [0.5],
#    'g-score': [0.56],
#    'd2h': [0.7],
#    'pci_20': [91],
#    'ifa': [0]},
#   'ontomorphtab.csv': {'f1': [0.54],
#    'precision': [0.54],
#    'recall': [0.57],
#    'g-score': [0.53],
#    'd2h': [0.8],
#    'pci_20': [98],
#    'ifa': [5]},
#   'avisynth2.csv': {'f1': [0.62],
#    'precision': [0.96],
#    'recall': [0.49],
#    'g-score': [0.82],
#    'd2h': [0.53],
#    'pci_20': [98],
#    'ifa': [23]},
#   'libarchive.csv': {'f1': [0.56],
#    'precision': [0.58],
#    'recall': [0.56],
#    'g-score': [0.6],
#    'd2h': [0.62],
#    'pci_20': [99],
#    'ifa': [2]},
#   'opengrads.csv': {'f1': [0.11],
#    'precision': [0.9],
#    'recall': [0.16],
#    'g-score': [0.21],
#    'd2h': [0.95],
#    'pci_20': [97],
#    'ifa': [18]},
#   'capcode.csv': {'f1': [0.55],
#    'precision': [0.81],
#    'recall': [0.48],
#    'g-score': [0.66],
#    'd2h': [0.62],
#    'pci_20': [98],
#    'ifa': [2]},
#   'openmeetings.csv': {'f1': [0.78],
#    'precision': [0.83],
#    'recall': [0.76],
#    'g-score': [0.59],
#    'd2h': [0.5],
#    'pci_20': [99],
#    'ifa': [25]},
#   'silvertree.csv': {'f1': [0.33],
#    'precision': [0.42],
#    'recall': [0.4],
#    'g-score': [0.35],
#    'd2h': [0.91],
#    'pci_20': [98],
#    'ifa': [2]},
#   'hibernate.csv': {'f1': [0.25],
#    'precision': [0.68],
#    'recall': [0.34],
#    'g-score': [0.35],
#    'd2h': [0.9],
#    'pci_20': [99],
#    'ifa': [26]},
#   'processing.csv': {'f1': [0.7],
#    'precision': [0.89],
#    'recall': [0.6],
#    'g-score': [0.58],
#    'd2h': [0.64],
#    'pci_20': [96],
#    'ifa': [0]},
#   'haggle.csv': {'f1': [0.59],
#    'precision': [0.63],
#    'recall': [0.58],
#    'g-score': [0.56],
#    'd2h': [0.58],
#    'pci_20': [99],
#    'ifa': [0]},
#   'opensim4opencog.csv': {'f1': [0.4],
#    'precision': [0.79],
#    'recall': [0.34],
#    'g-score': [0.56],
#    'd2h': [0.77],
#    'pci_20': [99],
#    'ifa': [9]},
#   'jasa.csv': {'f1': [0.31],
#    'precision': [0.76],
#    'recall': [0.47],
#    'g-score': [0.09],
#    'd2h': [0.97],
#    'pci_20': [98],
#    'ifa': [19]},
#   'jpaul.csv': {'f1': [0.27],
#    'precision': [0.52],
#    'recall': [0.33],
#    'g-score': [0.38],
#    'd2h': [0.9],
#    'pci_20': [98],
#    'ifa': [0]},
#   'neudist.csv': {'f1': [0.02],
#    'precision': [0.01],
#    'recall': [0.11],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [96],
#    'ifa': [1]},
#   'nano.csv': {'f1': [0.37],
#    'precision': [0.49],
#    'recall': [0.4],
#    'g-score': [0.49],
#    'd2h': [0.84],
#    'pci_20': [96],
#    'ifa': [1]},
#   'openmsx.csv': {'f1': [0.51],
#    'precision': [0.53],
#    'recall': [0.51],
#    'g-score': [0.51],
#    'd2h': [0.69],
#    'pci_20': [99],
#    'ifa': [1]},
#   'toped.csv': {'f1': [0.71],
#    'precision': [0.7],
#    'recall': [0.72],
#    'g-score': [0.0],
#    'd2h': [1.01],
#    'pci_20': [98],
#    'ifa': [0]},
#   'mwengine.csv': {'f1': [0.6],
#    'precision': [0.86],
#    'recall': [0.51],
#    'g-score': [0.67],
#    'd2h': [0.57],
#    'pci_20': [97],
#    'ifa': [22]},
#   'simplewebservices.csv': {'f1': [0.49],
#    'precision': [0.55],
#    'recall': [0.5],
#    'g-score': [0.59],
#    'd2h': [0.71],
#    'pci_20': [99],
#    'ifa': [0]},
#   'protomol.csv': {'f1': [0.43],
#    'precision': [0.67],
#    'recall': [0.32],
#    'g-score': [0.0],
#    'd2h': [1.19],
#    'pci_20': [96],
#    'ifa': [27]},
#   'mvnforum.csv': {'f1': [0.66],
#    'precision': [0.68],
#    'recall': [0.65],
#    'g-score': [0.58],
#    'd2h': [0.55],
#    'pci_20': [98],
#    'ifa': [8]},
#   'reaper3d.csv': {'f1': [0.37],
#    'precision': [0.83],
#    'recall': [0.28],
#    'g-score': [0.48],
#    'd2h': [0.84],
#    'pci_20': [99],
#    'ifa': [66]},
#   'vcgviewer.csv': {'f1': [0.76],
#    'precision': [0.77],
#    'recall': [0.77],
#    'g-score': [0.64],
#    'd2h': [0.42],
#    'pci_20': [92],
#    'ifa': [0]},
#   'grailrtls.csv': {'f1': [0.67],
#    'precision': [0.75],
#    'recall': [0.68],
#    'g-score': [0.55],
#    'd2h': [0.51],
#    'pci_20': [96],
#    'ifa': [7]},
#   'simulationcraft.csv': {'f1': [0.0]},
#   'growl-for-windows.csv': {'f1': [0.62],
#    'precision': [0.63],
#    'recall': [0.67],
#    'g-score': [0.55],
#    'd2h': [0.79],
#    'pci_20': [98],
#    'ifa': [2]},
#   'projectts.csv': {'f1': [0.5],
#    'precision': [0.5],
#    'recall': [0.53],
#    'g-score': [0.51],
#    'd2h': [0.81],
#    'pci_20': [98],
#    'ifa': [10]},
#   'bfin-test-proj.csv': {'f1': [0.48],
#    'precision': [0.7],
#    'recall': [0.42],
#    'g-score': [0.52],
#    'd2h': [0.74],
#    'pci_20': [97],
#    'ifa': [16]},
#   'mvdsv.csv': {'f1': [0.68],
#    'precision': [0.88],
#    'recall': [0.59],
#    'g-score': [0.65],
#    'd2h': [0.53],
#    'pci_20': [98],
#    'ifa': [48]},
#   'fritzing.csv': {'f1': [0.46],
#    'precision': [0.49],
#    'recall': [0.48],
#    'g-score': [0.54],
#    'd2h': [0.77],
#    'pci_20': [99],
#    'ifa': [0]},
#   'jlibrary.csv': {'f1': [0.45],
#    'precision': [0.72],
#    'recall': [0.36],
#    'g-score': [0.39],
#    'd2h': [0.88],
#    'pci_20': [97],
#    'ifa': [7]},
#   'jsbsim.csv': {'f1': [0.4],
#    'precision': [0.67],
#    'recall': [0.46],
#    'g-score': [0.52],
#    'd2h': [0.81],
#    'pci_20': [97],
#    'ifa': [0]},
#   'wsmt.csv': {'f1': [0.38],
#    'precision': [0.29],
#    'recall': [0.54],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [98],
#    'ifa': [0]},
#   'swtfox.csv': {'f1': [0.39],
#    'precision': [0.42],
#    'recall': [0.38],
#    'g-score': [0.4],
#    'd2h': [0.86],
#    'pci_20': [99],
#    'ifa': [0]},
#   'loserjabber.csv': {'f1': [0.59],
#    'precision': [0.52],
#    'recall': [0.68],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [95],
#    'ifa': [0]},
#   'nextobjects.csv': {'f1': [0.71],
#    'precision': [0.71],
#    'recall': [0.71],
#    'g-score': [0.0],
#    'd2h': [1.01],
#    'pci_20': [85],
#    'ifa': [6]},
#   'pcsx2.csv': {'f1': [0.62],
#    'precision': [0.63],
#    'recall': [0.61],
#    'g-score': [0.63],
#    'd2h': [0.6],
#    'pci_20': [99],
#    'ifa': [0]},
#   'tinycad.csv': {'f1': [0.7],
#    'precision': [0.84],
#    'recall': [0.62],
#    'g-score': [0.37],
#    'd2h': [0.76],
#    'pci_20': [97],
#    'ifa': [9]},
#   'linux-mips.csv': {'f1': [0.19],
#    'precision': [0.13],
#    'recall': [0.33],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [96],
#    'ifa': [9]},
#   'pokersource.csv': {'f1': [0.42],
#    'precision': [0.51],
#    'recall': [0.52],
#    'g-score': [0.1],
#    'd2h': [0.92],
#    'pci_20': [96],
#    'ifa': [15]},
#   'bdwgc.csv': {'f1': [0.56],
#    'precision': [0.91],
#    'recall': [0.48],
#    'g-score': [0.48],
#    'd2h': [0.58],
#    'pci_20': [96],
#    'ifa': [1]},
#   'octave.csv': {'f1': [0.55],
#    'precision': [0.75],
#    'recall': [0.5],
#    'g-score': [0.62],
#    'd2h': [0.63],
#    'pci_20': [99],
#    'ifa': [0]},
#   'mule.csv': {'f1': [0.57],
#    'precision': [0.62],
#    'recall': [0.63],
#    'g-score': [0.52],
#    'd2h': [0.81],
#    'pci_20': [99],
#    'ifa': [1]},
#   'lamp.csv': {'f1': [0.24],
#    'precision': [0.91],
#    'recall': [0.22],
#    'g-score': [0.45],
#    'd2h': [0.86],
#    'pci_20': [99],
#    'ifa': [3]},
#   'macaulay2.csv': {'f1': [0.28],
#    'precision': [0.45],
#    'recall': [0.39],
#    'g-score': [0.24],
#    'd2h': [0.95],
#    'pci_20': [96],
#    'ifa': [2]},
#   'm-a-d-n-e-s-s.csv': {'f1': [0.48],
#    'precision': [0.65],
#    'recall': [0.47],
#    'g-score': [0.62],
#    'd2h': [0.69],
#    'pci_20': [98],
#    'ifa': [5]},
#   'moneymanagerex.csv': {'f1': [0.07],
#    'precision': [0.04],
#    'recall': [0.2],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [80],
#    'ifa': [4]},
#   'google-gears.csv': {'f1': [0.55],
#    'precision': [0.74],
#    'recall': [0.53],
#    'g-score': [0.48],
#    'd2h': [0.59],
#    'pci_20': [99],
#    'ifa': [8]},
#   'wxerlang.csv': {'f1': [0.61],
#    'precision': [0.69],
#    'recall': [0.62],
#    'g-score': [0.49],
#    'd2h': [0.57],
#    'pci_20': [93],
#    'ifa': [1]},
#   'syllable.csv': {'f1': [0.13],
#    'precision': [0.08],
#    'recall': [0.29],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [85],
#    'ifa': [0]},
#   'opentac2.csv': {'f1': [0.32],
#    'precision': [0.33],
#    'recall': [0.33],
#    'g-score': [0.38],
#    'd2h': [0.94],
#    'pci_20': [96],
#    'ifa': [2]},
#   'geoserver.csv': {'f1': [0.33],
#    'precision': [0.47],
#    'recall': [0.33],
#    'g-score': [0.45],
#    'd2h': [0.88],
#    'pci_20': [95],
#    'ifa': [2]},
#   'encog-cs.csv': {'f1': [0.58],
#    'precision': [0.59],
#    'recall': [0.57],
#    'g-score': [0.52],
#    'd2h': [0.63],
#    'pci_20': [99],
#    'ifa': [4]},
#   'ceps.csv': {'f1': [0.0]},
#   'awemud.csv': {'f1': [0.71],
#    'precision': [0.72],
#    'recall': [0.69],
#    'g-score': [0.7],
#    'd2h': [0.48],
#    'pci_20': [99],
#    'ifa': [6]},
#   'carbonkernel.csv': {'f1': [0.5],
#    'precision': [0.83],
#    'recall': [0.5],
#    'g-score': [0.71],
#    'd2h': [0.67],
#    'pci_20': [75],
#    'ifa': [1]},
#   'tycho.csv': {'f1': [0.54],
#    'precision': [0.54],
#    'recall': [0.54],
#    'g-score': [0.55],
#    'd2h': [0.66],
#    'pci_20': [98],
#    'ifa': [0]},
#   'pmsqueak.csv': {'f1': [0.69],
#    'precision': [0.65],
#    'recall': [0.73],
#    'g-score': [0.0],
#    'd2h': [1.01],
#    'pci_20': [96],
#    'ifa': [0]},
#   'tmva.csv': {'f1': [0.58],
#    'precision': [0.61],
#    'recall': [0.56],
#    'g-score': [0.55],
#    'd2h': [0.72],
#    'pci_20': [99],
#    'ifa': [2]},
#   'gebr.csv': {'f1': [0.55],
#    'precision': [0.56],
#    'recall': [0.54],
#    'g-score': [0.5],
#    'd2h': [0.82],
#    'pci_20': [99],
#    'ifa': [0]},
#   'dryad.csv': {'f1': [0.57],
#    'precision': [0.76],
#    'recall': [0.45],
#    'g-score': [0.0],
#    'd2h': [1.12],
#    'pci_20': [90],
#    'ifa': [10]},
#   'tinymux.csv': {'f1': [0.64],
#    'precision': [0.56],
#    'recall': [0.75],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [75],
#    'ifa': [0]},
#   'rocrail.csv': {'f1': [0.45],
#    'precision': [0.76],
#    'recall': [0.43],
#    'g-score': [0.63],
#    'd2h': [0.7],
#    'pci_20': [99],
#    'ifa': [3]},
#   'aqsis.csv': {'f1': [0.18],
#    'precision': [0.13],
#    'recall': [0.25],
#    'g-score': [0.0],
#    'd2h': [1.09],
#    'pci_20': [93],
#    'ifa': [2]},
#   'trackit.csv': {'f1': [0.5],
#    'precision': [0.49],
#    'recall': [0.52],
#    'g-score': [0.48],
#    'd2h': [0.84],
#    'pci_20': [98],
#    'ifa': [2]},
#   'ossbuild.csv': {'f1': [0.71],
#    'precision': [0.75],
#    'recall': [0.68],
#    'g-score': [0.11],
#    'd2h': [0.94],
#    'pci_20': [99],
#    'ifa': [55]},
#   'foursquared.csv': {'f1': [0.53],
#    'precision': [0.64],
#    'recall': [0.53],
#    'g-score': [0.64],
#    'd2h': [0.64],
#    'pci_20': [98],
#    'ifa': [0]},
#   'iky.csv': {'f1': [0.48],
#    'precision': [0.39],
#    'recall': [0.62],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [97],
#    'ifa': [7]},
#   'mindquarry-desktop.csv': {'f1': [0.33],
#    'precision': [0.4],
#    'recall': [0.41],
#    'g-score': [0.35],
#    'd2h': [0.91],
#    'pci_20': [96],
#    'ifa': [0]},
#   'pentahoanalysistool.csv': {'f1': [0.42],
#    'precision': [0.65],
#    'recall': [0.44],
#    'g-score': [0.57],
#    'd2h': [0.76],
#    'pci_20': [98],
#    'ifa': [0]},
#   'wockets.csv': {'f1': [0.65],
#    'precision': [0.67],
#    'recall': [0.63],
#    'g-score': [0.6],
#    'd2h': [0.69],
#    'pci_20': [97],
#    'ifa': [1]},
#   'extprosys.csv': {'f1': [0.41],
#    'precision': [0.55],
#    'recall': [0.4],
#    'g-score': [0.51],
#    'd2h': [0.79],
#    'pci_20': [99],
#    'ifa': [1]},
#   'villonanny.csv': {'f1': [0.51],
#    'precision': [0.57],
#    'recall': [0.52],
#    'g-score': [0.6],
#    'd2h': [0.67],
#    'pci_20': [96],
#    'ifa': [0]},
#   'zumastor.csv': {'f1': [0.6],
#    'precision': [0.65],
#    'recall': [0.6],
#    'g-score': [0.54],
#    'd2h': [0.56],
#    'pci_20': [90],
#    'ifa': [3]},
#   'unigrok.csv': {'f1': [0.36],
#    'precision': [0.41],
#    'recall': [0.48],
#    'g-score': [0.2],
#    'd2h': [0.96],
#    'pci_20': [97],
#    'ifa': [7]},
#   'utgb.csv': {'f1': [0.39],
#    'precision': [0.4],
#    'recall': [0.48],
#    'g-score': [0.23],
#    'd2h': [0.95],
#    'pci_20': [98],
#    'ifa': [4]},
#   'sitestarter.csv': {'f1': [0.46],
#    'precision': [0.47],
#    'recall': [0.47],
#    'g-score': [0.39],
#    'd2h': [0.77],
#    'pci_20': [97],
#    'ifa': [10]},
#   'jmri.csv': {'f1': [0.41],
#    'precision': [0.49],
#    'recall': [0.47],
#    'g-score': [0.44],
#    'd2h': [0.86],
#    'pci_20': [99],
#    'ifa': [0]},
#   'molybdenum.csv': {'f1': [0.0]},
#   'bluemusic.csv': {'f1': [0.26],
#    'precision': [0.18],
#    'recall': [0.43],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [85],
#    'ifa': [1]},
#   'virtuoso.csv': {'f1': [0.51],
#    'precision': [0.71],
#    'recall': [0.48],
#    'g-score': [0.63],
#    'd2h': [0.65],
#    'pci_20': [99],
#    'ifa': [1]},
#   'google-collections.csv': {'f1': [0.94],
#    'precision': [0.97],
#    'recall': [0.93],
#    'g-score': [0.8],
#    'd2h': [0.5],
#    'pci_20': [98],
#    'ifa': [1]},
#   'jphototagger.csv': {'f1': [0.4],
#    'precision': [0.96],
#    'recall': [0.26],
#    'g-score': [0.0],
#    'd2h': [1.24],
#    'pci_20': [99],
#    'ifa': [221]},
#   'qmmp.csv': {'f1': [0.36],
#    'precision': [0.37],
#    'recall': [0.42],
#    'g-score': [0.37],
#    'd2h': [0.92],
#    'pci_20': [99],
#    'ifa': [8]},
#   'mnemisis.csv': {'f1': [0.67],
#    'precision': [0.67],
#    'recall': [0.67],
#    'g-score': [0.68],
#    'd2h': [0.56],
#    'pci_20': [83],
#    'ifa': [0]},
#   'exordium.csv': {'f1': [0.57],
#    'precision': [0.63],
#    'recall': [0.55],
#    'g-score': [0.45],
#    'd2h': [0.71],
#    'pci_20': [98],
#    'ifa': [27]},
#   'bigdata.csv': {'f1': [0.63],
#    'precision': [0.78],
#    'recall': [0.56],
#    'g-score': [0.52],
#    'd2h': [0.75],
#    'pci_20': [99],
#    'ifa': [1]},
#   'rvdesignpattern.csv': {'f1': [0.2],
#    'precision': [0.14],
#    'recall': [0.38],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [87],
#    'ifa': [0]},
#   'k3b.csv': {'f1': [0.53],
#    'precision': [0.59],
#    'recall': [0.51],
#    'g-score': [0.52],
#    'd2h': [0.7],
#    'pci_20': [98],
#    'ifa': [1]},
#   'unigelaber.csv': {'f1': [0.49],
#    'precision': [0.49],
#    'recall': [0.5],
#    'g-score': [0.53],
#    'd2h': [0.78],
#    'pci_20': [96],
#    'ifa': [3]},
#   'myfaces.csv': {'f1': [0.14],
#    'precision': [0.68],
#    'recall': [0.18],
#    'g-score': [0.27],
#    'd2h': [0.94],
#    'pci_20': [99],
#    'ifa': [0]},
#   'google-web-toolkit.csv': {'f1': [0.5],
#    'precision': [0.51],
#    'recall': [0.55],
#    'g-score': [0.45],
#    'd2h': [0.85],
#    'pci_20': [99],
#    'ifa': [0]},
#   'codewave.csv': {'f1': [0.6],
#    'precision': [0.6],
#    'recall': [0.59],
#    'g-score': [0.6],
#    'd2h': [0.57],
#    'pci_20': [97],
#    'ifa': [13]},
#   'glsof.csv': {'f1': [0.41],
#    'precision': [0.57],
#    'recall': [0.48],
#    'g-score': [0.48],
#    'd2h': [0.84],
#    'pci_20': [97],
#    'ifa': [7]},
#   'microemulator.csv': {'f1': [0.36],
#    'precision': [0.55],
#    'recall': [0.38],
#    'g-score': [0.51],
#    'd2h': [0.82],
#    'pci_20': [97],
#    'ifa': [0]},
#   'genecys.csv': {'f1': [0.67],
#    'precision': [0.79],
#    'recall': [0.61],
#    'g-score': [0.58],
#    'd2h': [0.67],
#    'pci_20': [98],
#    'ifa': [1]},
#   'werx.csv': {'f1': [0.48],
#    'precision': [0.97],
#    'recall': [0.33],
#    'g-score': [0.36],
#    'd2h': [0.72],
#    'pci_20': [99],
#    'ifa': [0]},
#   'taverna.csv': {'f1': [0.46],
#    'precision': [0.52],
#    'recall': [0.45],
#    'g-score': [0.5],
#    'd2h': [0.76],
#    'pci_20': [98],
#    'ifa': [0]},
#   'nsclspectcl.csv': {'f1': [0.25],
#    'precision': [0.28],
#    'recall': [0.25],
#    'g-score': [0.29],
#    'd2h': [1.04],
#    'pci_20': [87],
#    'ifa': [2]},
#   'jsidplay2.csv': {'f1': [0.7],
#    'precision': [0.73],
#    'recall': [0.76],
#    'g-score': [0.46],
#    'd2h': [0.85],
#    'pci_20': [98],
#    'ifa': [0]},
#   'any23.csv': {'f1': [0.71],
#    'precision': [0.87],
#    'recall': [0.61],
#    'g-score': [0.0],
#    'd2h': [1.06],
#    'pci_20': [97],
#    'ifa': [0]},
#   'fltk.csv': {'f1': [0.6],
#    'precision': [0.59],
#    'recall': [0.6],
#    'g-score': [0.63],
#    'd2h': [0.61],
#    'pci_20': [99],
#    'ifa': [12]},
#   'tradelink.csv': {'f1': [0.34],
#    'precision': [0.69],
#    'recall': [0.33],
#    'g-score': [0.52],
#    'd2h': [0.81],
#    'pci_20': [98],
#    'ifa': [3]},
#   'textgrounder.csv': {'f1': [0.34],
#    'precision': [0.36],
#    'recall': [0.33],
#    'g-score': [0.34],
#    'd2h': [0.97],
#    'pci_20': [95],
#    'ifa': [4]},
#   'jmlspecs.csv': {'f1': [0.11],
#    'precision': [0.91],
#    'recall': [0.14],
#    'g-score': [0.21],
#    'd2h': [0.95],
#    'pci_20': [95],
#    'ifa': [0]},
#   'gfs.csv': {'f1': [0.62],
#    'precision': [0.68],
#    'recall': [0.62],
#    'g-score': [0.71],
#    'd2h': [0.54],
#    'pci_20': [96],
#    'ifa': [0]},
#   'bripper.csv': {'f1': [0.63],
#    'precision': [0.69],
#    'recall': [0.58],
#    'g-score': [0.42],
#    'd2h': [0.9],
#    'pci_20': [97],
#    'ifa': [2]},
#   'anyconfig.csv': {'f1': [0.76],
#    'precision': [0.79],
#    'recall': [0.74],
#    'g-score': [0.29],
#    'd2h': [0.77],
#    'pci_20': [96],
#    'ifa': [11]},
#   'irrlicht.csv': {'f1': [0.63],
#    'precision': [0.69],
#    'recall': [0.6],
#    'g-score': [0.6],
#    'd2h': [0.63],
#    'pci_20': [99],
#    'ifa': [0]},
#   'jguard.csv': {'f1': [0.56],
#    'precision': [0.66],
#    'recall': [0.56],
#    'g-score': [0.67],
#    'd2h': [0.6],
#    'pci_20': [98],
#    'ifa': [1]},
#   'jitterbit.csv': {'f1': [0.34],
#    'precision': [0.64],
#    'recall': [0.37],
#    'g-score': [0.5],
#    'd2h': [0.82],
#    'pci_20': [99],
#    'ifa': [0]},
#   'eid-mw.csv': {'f1': [0.57],
#    'precision': [0.9],
#    'recall': [0.5],
#    'g-score': [0.79],
#    'd2h': [0.57],
#    'pci_20': [87],
#    'ifa': [2]},
#   'etherboot.csv': {'f1': [0.41],
#    'precision': [0.64],
#    'recall': [0.41],
#    'g-score': [0.57],
#    'd2h': [0.76],
#    'pci_20': [98],
#    'ifa': [8]},
#   'customwars.csv': {'f1': [0.2],
#    'precision': [0.8],
#    'recall': [0.23],
#    'g-score': [0.37],
#    'd2h': [0.9],
#    'pci_20': [99],
#    'ifa': [16]},
#   'hugin.csv': {'f1': [0.28],
#    'precision': [0.28],
#    'recall': [0.27],
#    'g-score': [0.19],
#    'd2h': [1.06],
#    'pci_20': [97],
#    'ifa': [8]},
#   'boost-log.csv': {'f1': [0.45],
#    'precision': [0.59],
#    'recall': [0.38],
#    'g-score': [0.16],
#    'd2h': [1.03],
#    'pci_20': [97],
#    'ifa': [26]},
#   'ast.csv': {'f1': [0.48],
#    'precision': [0.66],
#    'recall': [0.48],
#    'g-score': [0.64],
#    'd2h': [0.68],
#    'pci_20': [96],
#    'ifa': [0]},
#   'webdriver.csv': {'f1': [0.53],
#    'precision': [0.56],
#    'recall': [0.54],
#    'g-score': [0.61],
#    'd2h': [0.67],
#    'pci_20': [98],
#    'ifa': [11]},
#   'farsight.csv': {'f1': [0.36],
#    'precision': [0.38],
#    'recall': [0.38],
#    'g-score': [0.43],
#    'd2h': [0.89],
#    'pci_20': [93],
#    'ifa': [1]},
#   'mediate.csv': {'f1': [0.49],
#    'precision': [0.59],
#    'recall': [0.52],
#    'g-score': [0.32],
#    'd2h': [0.74],
#    'pci_20': [98],
#    'ifa': [3]},
#   'plee-the-bear.csv': {'f1': [0.52],
#    'precision': [0.91],
#    'recall': [0.4],
#    'g-score': [0.63],
#    'd2h': [0.67],
#    'pci_20': [99],
#    'ifa': [1]},
#   'levent.csv': {'f1': [0.57],
#    'precision': [0.58],
#    'recall': [0.56],
#    'g-score': [0.56],
#    'd2h': [0.69],
#    'pci_20': [98],
#    'ifa': [1]},
#   'mia.csv': {'f1': [0.42],
#    'precision': [0.8],
#    'recall': [0.33],
#    'g-score': [0.48],
#    'd2h': [0.83],
#    'pci_20': [99],
#    'ifa': [3]},
#   'transdroid.csv': {'f1': [0.43],
#    'precision': [0.52],
#    'recall': [0.54],
#    'g-score': [0.3],
#    'd2h': [0.92],
#    'pci_20': [96],
#    'ifa': [1]},
#   'actiongame.csv': {'f1': [0.66],
#    'precision': [0.7],
#    'recall': [0.64],
#    'g-score': [0.58],
#    'd2h': [0.73],
#    'pci_20': [97],
#    'ifa': [6]},
#   'unladen-swallow.csv': {'f1': [0.56],
#    'precision': [0.87],
#    'recall': [0.49],
#    'g-score': [0.73],
#    'd2h': [0.58],
#    'pci_20': [99],
#    'ifa': [9]},
#   'apertium.csv': {'f1': [0.6],
#    'precision': [0.65],
#    'recall': [0.58],
#    'g-score': [0.59],
#    'd2h': [0.59],
#    'pci_20': [98],
#    'ifa': [8]},
#   'vapor.csv': {'f1': [0.53],
#    'precision': [0.68],
#    'recall': [0.51],
#    'g-score': [0.64],
#    'd2h': [0.63],
#    'pci_20': [98],
#    'ifa': [5]},
#   'gcsaleve.csv': {'f1': [0.88],
#    'precision': [0.88],
#    'recall': [0.88],
#    'g-score': [0.38],
#    'd2h': [0.67],
#    'pci_20': [96],
#    'ifa': [31]},
#   'welly.csv': {'f1': [0.4],
#    'precision': [0.35],
#    'recall': [0.45],
#    'g-score': [0.0],
#    'd2h': [1.04],
#    'pci_20': [90],
#    'ifa': [10]},
#   'xstore.csv': {'f1': [0.66],
#    'precision': [0.66],
#    'recall': [0.66],
#    'g-score': [0.65],
#    'd2h': [0.49],
#    'pci_20': [98],
#    'ifa': [8]},
#   'scintilla.csv': {'f1': [0.5],
#    'precision': [0.64],
#    'recall': [0.5],
#    'g-score': [0.63],
#    'd2h': [0.67],
#    'pci_20': [97],
#    'ifa': [3]},
#   'libfreedom.csv': {'f1': [0.21],
#    'precision': [0.15],
#    'recall': [0.33],
#    'g-score': [0.0],
#    'd2h': [1.02],
#    'pci_20': [95],
#    'ifa': [0]},
#   'amrc.csv': {'f1': [0.35],
#    'precision': [0.68],
#    'recall': [0.34],
#    'g-score': [0.53],
#    'd2h': [0.8],
#    'pci_20': [97],
#    'ifa': [1]},
#   'qcad2.csv': {'f1': [0.58],
#    'precision': [0.62],
#    'recall': [0.57],
#    'g-score': [0.58],
#    'd2h': [0.6],
#    'pci_20': [99],
#    'ifa': [1]},
#   'fluent-nhibernate.csv': {'f1': [0.55],
#    'precision': [0.91],
#    'recall': [0.46],
#    'g-score': [0.75],
#    'd2h': [0.59],
#    'pci_20': [99],
#    'ifa': [3]},
#   'gwtchismes.csv': {'f1': [0.71],
#    'precision': [0.71],
#    'recall': [0.71],
#    'g-score': [0.0],
#    'd2h': [1.01],
#    'pci_20': [92],
#    'ifa': [1]},
#   'bonkenc.csv': {'f1': [0.55],
#    'precision': [0.55],
#    'recall': [0.55],
#    'g-score': [0.57],
#    'd2h': [0.68],
#    'pci_20': [95],
#    'ifa': [2]},
#   'ghostscript.csv': {'f1': [0.63],
#    'precision': [0.72],
#    'recall': [0.6],
#    'g-score': [0.6],
#    'd2h': [0.57],
#    'pci_20': [97],
#    'ifa': [0]},
#   'sdscsyslog.csv': {'f1': [0.83],
#    'precision': [0.85],
#    'recall': [0.81],
#    'g-score': [0.0],
#    'd2h': [1.01],
#    'pci_20': [96],
#    'ifa': [1]},
#   'wxlua.csv': {'f1': [0.85],
#    'precision': [0.85],
#    'recall': [0.85],
#    'g-score': [0.39],
#    'd2h': [0.88],
#    'pci_20': [98],
#    'ifa': [1]},
#   'ivef-sdk.csv': {'f1': [0.57],
#    'precision': [0.55],
#    'recall': [0.67],
#    'g-score': [0.13],
#    'd2h': [0.97],
#    'pci_20': [98],
#    'ifa': [30]},
#   'ayam.csv': {'f1': [0.44],
#    'precision': [0.88],
#    'recall': [0.41],
#    'g-score': [0.68],
#    'd2h': [0.7],
#    'pci_20': [96],
#    'ifa': [4]},
#   'modplug.csv': {'f1': [0.74],
#    'precision': [0.73],
#    'recall': [0.75],
#    'g-score': [0.74],
#    'd2h': [0.56],
#    'pci_20': [98],
#    'ifa': [0]},
#   'ksi.csv': {'f1': [0.53],
#    'precision': [0.69],
#    'recall': [0.5],
#    'g-score': [0.46],
#    'd2h': [0.64],
#    'pci_20': [97],
#    'ifa': [7]},
#   'wpdev.csv': {'f1': [0.9],
#    'precision': [0.97],
#    'recall': [0.84],
#    'g-score': [0.0],
#    'd2h': [1.01],
#    'pci_20': [99],
#    'ifa': [0]},
#   'dxengine.csv': {'f1': [0.34],
#    'precision': [0.45],
#    'recall': [0.36],
#    'g-score': [0.46],
#    'd2h': [0.87],
#    'pci_20': [98],
#    'ifa': [0]},
#   'jmonkeyengine.csv': {'f1': [0.59],
#    'precision': [0.75],
#    'recall': [0.57],
#    'g-score': [0.72],
#    'd2h': [0.55],
#    'pci_20': [98],
#    'ifa': [1]},
#   'jahshaka.csv': {'f1': [0.39],
#    'precision': [0.86],
#    'recall': [0.38],
#    'g-score': [0.61],
#    'd2h': [0.76],
#    'pci_20': [98],
#    'ifa': [24]},
#   'kisdnmon.csv': {'f1': [0.29],
#    'precision': [0.75],
#    'recall': [0.2],
#    'g-score': [0.29],
#    'd2h': [1.05],
#    'pci_20': [97],
#    'ifa': [36]},
#   'nutch.csv': {'f1': [0.46],
#    'precision': [0.69],
#    'recall': [0.51],
#    'g-score': [0.59],
#    'd2h': [0.76],
#    'pci_20': [97],
#    'ifa': [0]},
#   'mimosa.csv': {'f1': [0.7],
#    'precision': [0.76],
#    'recall': [0.71],
#    'g-score': [0.8],
#    'd2h': [0.48],
#    'pci_20': [98],
#    'ifa': [0]},
#   'mclient-mume.csv': {'f1': [0.5],
#    'precision': [0.59],
#    'recall': [0.56],
#    'g-score': [0.52],
#    'd2h': [0.82],
#    'pci_20': [98],
#    'ifa': [3]},
#   'jikesrvm.csv': {'f1': [0.47],
#    'precision': [0.48],
#    'recall': [0.47],
#    'g-score': [0.45],
#    'd2h': [0.75],
#    'pci_20': [97],
#    'ifa': [0]},
#   'audela.csv': {'f1': [0.29],
#    'precision': [0.79],
#    'recall': [0.23],
#    'g-score': [0.45],
#    'd2h': [0.88],
#    'pci_20': [97],
#    'ifa': [0]},
#   'echongl.csv': {'f1': [0.38],
#    'precision': [0.45],
#    'recall': [0.34],
#    'g-score': [0.34],
#    'd2h': [0.98],
#    'pci_20': [99],
#    'ifa': [1]},
#   'jactr.csv': {'f1': [0.0]},
#   'azureus.csv': {'f1': [0.5],
#    'precision': [0.77],
#    'recall': [0.49],
#    'g-score': [0.69],
#    'd2h': [0.66],
#    'pci_20': [99],
#    'ifa': [3]},
#   'ooccollider.csv': {'f1': [0.68],
#    'precision': [0.71],
#    'recall': [0.66],
#    'g-score': [0.53],
#    'd2h': [0.58],
#    'pci_20': [97],
# ...
#    'precision': [0.86],
#    'recall': [0.57],
#    'g-score': [0.8],
#    'd2h': [0.55],
#    'pci_20': [92],
#    'ifa': [4]},
#   'e-bio-flow.csv': {'f1': [0.64],
#    'precision': [0.65],
#    'recall': [0.63],
#    'g-score': [0.61],
#    'd2h': [0.53],
#    'pci_20': [98],
#    'ifa': [3]},
#   'planetfall.csv': {'f1': [0.85],
#    'precision': [0.95],
#    'recall': [0.81],
#    'g-score': [0.82],
#    'd2h': [0.21],
#    'pci_20': [96],
#    'ifa': [0]},
#   'ulti-swat.csv': {'f1': [0.76],
#    'precision': [0.77],
#    'recall': [0.76],
#    'g-score': [0.81],
#    'd2h': [0.37],
#    'pci_20': [96],
#    'ifa': [0]},
#   'stuproa-cims.csv': {'f1': [0.56],
#    'precision': [0.6],
#    'recall': [0.54],
#    'g-score': [0.43],
#    'd2h': [0.73],
#    'pci_20': [99],
#    'ifa': [10]},
#   'rsyslog.csv': {'f1': [0.64],
#    'precision': [0.65],
#    'recall': [0.64],
#    'g-score': [0.6],
#    'd2h': [0.51],
#    'pci_20': [98],
#    'ifa': [6]},
#   'xqilla.csv': {'f1': [0.67],
#    'precision': [0.98],
#    'recall': [0.53],
#    'g-score': [0.84],
#    'd2h': [0.48],
#    'pci_20': [99],
#    'ifa': [49]},
#   'opennode2.csv': {'f1': [0.53],
#    'precision': [0.51],
#    'recall': [0.57],
#    'g-score': [0.41],
#    'd2h': [0.88],
#    'pci_20': [97],
#    'ifa': [14]},
#   'lportal.csv': {'f1': [0.76],
#    'precision': [0.94],
#    'recall': [0.66],
#    'g-score': [0.64],
#    'd2h': [0.5],
#    'pci_20': [99],
#    'ifa': [1]},
#   'doomlegacy.csv': {'f1': [0.62],
#    'precision': [0.6],
#    'recall': [0.65],
#    'g-score': [0.38],
#    'd2h': [0.9],
#    'pci_20': [99],
#    'ifa': [0]},
#   'freenet.csv': {'f1': [0.6],
#    'precision': [0.64],
#    'recall': [0.59],
#    'g-score': [0.57],
#    'd2h': [0.57],
#    'pci_20': [99],
#    'ifa': [5]},
#   'sidekar.csv': {'f1': [0.64],
#    'precision': [0.67],
#    'recall': [0.64],
#    'g-score': [0.62],
#    'd2h': [0.5],
#    'pci_20': [99],
#    'ifa': [1]},
#   'wishmaster.csv': {'f1': [0.35],
#    'precision': [0.71],
#    'recall': [0.33],
#    'g-score': [0.53],
#    'd2h': [0.8],
#    'pci_20': [98],
#    'ifa': [2]},
#   'ejbtool.csv': {'f1': [0.42],
#    'precision': [0.52],
#    'recall': [0.4],
#    'g-score': [0.38],
#    'd2h': [0.81],
#    'pci_20': [97],
#    'ifa': [1]},
#   'pgui.csv': {'f1': [0.21],
#    'precision': [0.66],
#    'recall': [0.31],
#    'g-score': [0.27],
#    'd2h': [0.94],
#    'pci_20': [99],
#    'ifa': [22]},
#   'aztec.csv': {'f1': [0.81],
#    'precision': [0.86],
#    'recall': [0.77],
#    'g-score': [0.2],
#    'd2h': [0.85],
#    'pci_20': [99],
#    'ifa': [42]},
#   'joustsim.csv': {'f1': [0.6],
#    'precision': [0.8],
#    'recall': [0.54],
#    'g-score': [0.67],
#    'd2h': [0.57],
#    'pci_20': [98],
#    'ifa': [18]},
#   'zsnes.csv': {'f1': [0.45],
#    'precision': [0.7],
#    'recall': [0.49],
#    'g-score': [0.6],
#    'd2h': [0.75],
#    'pci_20': [97],
#    'ifa': [1]},
#   'oorexx.csv': {'f1': [0.58],
#    'precision': [0.59],
#    'recall': [0.57],
#    'g-score': [0.57],
#    'd2h': [0.6],
#    'pci_20': [98],
#    'ifa': [8]},
#   'cadcdev.csv': {'f1': [0.78],
#    'precision': [0.8],
#    'recall': [0.77],
#    'g-score': [0.69],
#    'd2h': [0.39],
#    'pci_20': [92],
#    'ifa': [7]},
#   'maidsafe-dht.csv': {'f1': [0.64],
#    'precision': [0.76],
#    'recall': [0.59],
#    'g-score': [0.63],
#    'd2h': [0.55],
#    'pci_20': [98],
#    'ifa': [17]},
#   'coldemoplayer.csv': {'f1': [0.49],
#    'precision': [0.5],
#    'recall': [0.5],
#    'g-score': [0.56],
#    'd2h': [0.75],
#    'pci_20': [83],
#    'ifa': [1]},
#   'mesh4x.csv': {'f1': [0.53],
#    'precision': [0.67],
#    'recall': [0.55],
#    'g-score': [0.66],
#    'd2h': [0.68],
#    'pci_20': [95],
#    'ifa': [4]},
#   'cubefs.csv': {'f1': [0.53],
#    'precision': [0.53],
#    'recall': [0.54],
#    'g-score': [0.47],
#    'd2h': [0.85],
#    'pci_20': [99],
#    'ifa': [1]},
#   'kmetronome.csv': {'f1': [0.65],
#    'precision': [0.65],
#    'recall': [0.65],
#    'g-score': [0.59],
#    'd2h': [0.53],
#    'pci_20': [97],
#    'ifa': [4]},
#   'dwengine.csv': {'f1': [0.78],
#    'precision': [0.85],
#    'recall': [0.8],
#    'g-score': [0.56],
#    'd2h': [0.5],
#    'pci_20': [90],
#    'ifa': [2]},
#   'rodin-b-sharp.csv': {'f1': [0.36],
#    'precision': [0.42],
#    'recall': [0.36],
#    'g-score': [0.44],
#    'd2h': [0.87],
#    'pci_20': [99],
#    'ifa': [0]},
#   'pi4soa.csv': {'f1': [0.0]},
#   'vstgui.csv': {'f1': [0.47],
#    'precision': [0.61],
#    'recall': [0.51],
#    'g-score': [0.28],
#    'd2h': [0.77],
#    'pci_20': [97],
#    'ifa': [24]},
#   'quickdc.csv': {'f1': [0.23],
#    'precision': [0.16],
#    'recall': [0.4],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [80],
#    'ifa': [0]},
#   'chaosrts.csv': {'f1': [0.7],
#    'precision': [0.81],
#    'recall': [0.65],
#    'g-score': [0.61],
#    'd2h': [0.66],
#    'pci_20': [99],
#    'ifa': [0]},
#   'kmsn.csv': {'f1': [0.51],
#    'precision': [0.5],
#    'recall': [0.54],
#    'g-score': [0.48],
#    'd2h': [0.84],
#    'pci_20': [92],
#    'ifa': [0]},
#   'xmemcached.csv': {'f1': [0.64],
#    'precision': [0.65],
#    'recall': [0.63],
#    'g-score': [0.43],
#    'd2h': [0.67],
#    'pci_20': [98],
#    'ifa': [2]},
#   'pure-data.csv': {'f1': [0.43],
#    'precision': [0.54],
#    'recall': [0.48],
#    'g-score': [0.51],
#    'd2h': [0.82],
#    'pci_20': [96],
#    'ifa': [2]},
#   'synergyspace.csv': {'f1': [0.63],
#    'precision': [0.68],
#    'recall': [0.6],
#    'g-score': [0.39],
#    'd2h': [0.73],
#    'pci_20': [99],
#    'ifa': [2]},
#   'psrchive.csv': {'f1': [0.41],
#    'precision': [0.74],
#    'recall': [0.36],
#    'g-score': [0.55],
#    'd2h': [0.76],
#    'pci_20': [98],
#    'ifa': [9]},
#   'xui.csv': {'f1': [0.51],
#    'precision': [0.72],
#    'recall': [0.47],
#    'g-score': [0.62],
#    'd2h': [0.66],
#    'pci_20': [97],
#    'ifa': [5]},
#   'lockss.csv': {'f1': [0.64],
#    'precision': [0.77],
#    'recall': [0.6],
#    'g-score': [0.66],
#    'd2h': [0.53],
#    'pci_20': [99],
#    'ifa': [2]},
#   'algebsql.csv': {'f1': [0.68],
#    'precision': [0.68],
#    'recall': [0.68],
#    'g-score': [0.65],
#    'd2h': [0.46],
#    'pci_20': [98],
#    'ifa': [13]},
#   'jbasic.csv': {'f1': [0.55],
#    'precision': [0.62],
#    'recall': [0.58],
#    'g-score': [0.64],
#    'd2h': [0.7],
#    'pci_20': [99],
#    'ifa': [0]},
#   'hsqldb.csv': {'f1': [0.52],
#    'precision': [0.82],
#    'recall': [0.45],
#    'g-score': [0.64],
#    'd2h': [0.64],
#    'pci_20': [96],
#    'ifa': [2]},
#   'all-plasm.csv': {'f1': [0.43],
#    'precision': [0.62],
#    'recall': [0.49],
#    'g-score': [0.53],
#    'd2h': [0.81],
#    'pci_20': [98],
#    'ifa': [0]},
#   'tubras.csv': {'f1': [0.61],
#    'precision': [0.68],
#    'recall': [0.61],
#    'g-score': [0.7],
#    'd2h': [0.54],
#    'pci_20': [97],
#    'ifa': [0]},
#   'retribengine.csv': {'f1': [0.34],
#    'precision': [0.7],
#    'recall': [0.35],
#    'g-score': [0.53],
#    'd2h': [0.8],
#    'pci_20': [96],
#    'ifa': [2]},
#   'jdivelog.csv': {'f1': [0.59],
#    'precision': [0.68],
#    'recall': [0.61],
#    'g-score': [0.71],
#    'd2h': [0.61],
#    'pci_20': [94],
#    'ifa': [0]},
#   'patterntesting.csv': {'f1': [0.64],
#    'precision': [0.72],
#    'recall': [0.69],
#    'g-score': [0.32],
#    'd2h': [0.73],
#    'pci_20': [98],
#    'ifa': [34]},
#   'linuxsh.csv': {'f1': [0.54],
#    'precision': [0.8],
#    'recall': [0.48],
#    'g-score': [0.69],
#    'd2h': [0.61],
#    'pci_20': [98],
#    'ifa': [16]},
#   'streamedmp.csv': {'f1': [1.0],
#    'precision': [1.0],
#    'recall': [1.0],
#    'g-score': [1.0],
#    'd2h': [0.0],
#    'pci_20': [87],
#    'ifa': [0]},
#   'ppcboot.csv': {'f1': [0.57],
#    'precision': [0.58],
#    'recall': [0.58],
#    'g-score': [0.63],
#    'd2h': [0.66],
#    'pci_20': [99],
#    'ifa': [0]},
#   'jasperreports.csv': {'f1': [0.7],
#    'precision': [0.93],
#    'recall': [0.58],
#    'g-score': [0.69],
#    'd2h': [0.5],
#    'pci_20': [99],
#    'ifa': [185]},
#   'opentnl.csv': {'f1': [0.49],
#    'precision': [0.54],
#    'recall': [0.48],
#    'g-score': [0.53],
#    'd2h': [0.72],
#    'pci_20': [97],
#    'ifa': [3]},
#   'icescrum.csv': {'f1': [0.5],
#    'precision': [0.52],
#    'recall': [0.49],
#    'g-score': [0.48],
#    'd2h': [0.73],
#    'pci_20': [98],
#    'ifa': [8]},
#   'pugs.csv': {'f1': [0.0]},
#   'kolmafia.csv': {'f1': [0.58],
#    'precision': [0.6],
#    'recall': [0.58],
#    'g-score': [0.51],
#    'd2h': [0.6],
#    'pci_20': [98],
#    'ifa': [1]},
#   'rhex.csv': {'f1': [0.5],
#    'precision': [0.87],
#    'recall': [0.44],
#    'g-score': [0.71],
#    'd2h': [0.64],
#    'pci_20': [98],
#    'ifa': [13]},
#   'amino.csv': {'f1': [0.52],
#    'precision': [0.51],
#    'recall': [0.52],
#    'g-score': [0.38],
#    'd2h': [0.74],
#    'pci_20': [97],
#    'ifa': [22]},
#   'blockbuster.csv': {'f1': [0.54],
#    'precision': [0.54],
#    'recall': [0.54],
#    'g-score': [0.56],
#    'd2h': [0.71],
#    'pci_20': [97],
#    'ifa': [0]},
#   'latexdraw.csv': {'f1': [0.57],
#    'precision': [0.57],
#    'recall': [0.57],
#    'g-score': [0.56],
#    'd2h': [0.62],
#    'pci_20': [95],
#    'ifa': [5]},
#   'reactos-mirror.csv': {'f1': [0.49],
#    'precision': [0.52],
#    'recall': [0.57],
#    'g-score': [0.13],
#    'd2h': [0.89],
#    'pci_20': [99],
#    'ifa': [43]},
#   'sbcl.csv': {'f1': [0.25],
#    'precision': [0.28],
#    'recall': [0.25],
#    'g-score': [0.29],
#    'd2h': [1.04],
#    'pci_20': [87],
#    'ifa': [5]},
#   'opendomo.csv': {'f1': [0.59],
#    'precision': [0.6],
#    'recall': [0.59],
#    'g-score': [0.58],
#    'd2h': [0.59],
#    'pci_20': [94],
#    'ifa': [2]},
#   'python-on-a-chip.csv': {'f1': [0.59],
#    'precision': [0.82],
#    'recall': [0.5],
#    'g-score': [0.51],
#    'd2h': [0.65],
#    'pci_20': [97],
#    'ifa': [1]},
#   'fugu.csv': {'f1': [0.68],
#    'precision': [0.8],
#    'recall': [0.58],
#    'g-score': [0.0],
#    'd2h': [1.06],
#    'pci_20': [91],
#    'ifa': [0]},
#   'qwired-suite.csv': {'f1': [0.67],
#    'precision': [0.68],
#    'recall': [0.67],
#    'g-score': [0.49],
#    'd2h': [0.6],
#    'pci_20': [98],
#    'ifa': [10]},
#   'quarkplayer.csv': {'f1': [0.82],
#    'precision': [0.86],
#    'recall': [0.78],
#    'g-score': [0.0],
#    'd2h': [1.01],
#    'pci_20': [99],
#    'ifa': [168]},
#   'cerber.csv': {'f1': [0.67],
#    'precision': [0.83],
#    'recall': [0.64],
#    'g-score': [0.62],
#    'd2h': [0.44],
#    'pci_20': [97],
#    'ifa': [0]},
#   'kreatecd.csv': {'f1': [0.55],
#    'precision': [0.57],
#    'recall': [0.57],
#    'g-score': [0.62],
#    'd2h': [0.65],
#    'pci_20': [98],
#    'ifa': [1]},
#   'l2j.csv': {'f1': [0.52],
#    'precision': [0.71],
#    'recall': [0.51],
#    'g-score': [0.44],
#    'd2h': [0.63],
#    'pci_20': [99],
#    'ifa': [4]},
#   'cumberland.csv': {'f1': [0.08],
#    'precision': [0.05],
#    'recall': [0.21],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [92],
#    'ifa': [3]},
#   'ajqtgui.csv': {'f1': [0.0]},
#   'bscwweasel.csv': {'f1': [0.64],
#    'precision': [0.86],
#    'recall': [0.57],
#    'g-score': [0.73],
#    'd2h': [0.5],
#    'pci_20': [99],
#    'ifa': [2]},
#   'quickfast.csv': {'f1': [0.66],
#    'precision': [0.7],
#    'recall': [0.66],
#    'g-score': [0.6],
#    'd2h': [0.48],
#    'pci_20': [98],
#    'ifa': [0]},
#   'mscore.csv': {'f1': [0.62],
#    'precision': [0.73],
#    'recall': [0.63],
#    'g-score': [0.5],
#    'd2h': [0.56],
#    'pci_20': [99],
#    'ifa': [4]},
#   'pmd.csv': {'f1': [0.67],
#    'precision': [0.67],
#    'recall': [0.67],
#    'g-score': [0.0],
#    'd2h': [1.02],
#    'pci_20': [83],
#    'ifa': [5]},
#   'open-ms.csv': {'f1': [0.44],
#    'precision': [0.71],
#    'recall': [0.41],
#    'g-score': [0.59],
#    'd2h': [0.72],
#    'pci_20': [99],
#    'ifa': [0]},
#   'subsonic.csv': {'f1': [0.52],
#    'precision': [0.65],
#    'recall': [0.45],
#    'g-score': [0.35],
#    'd2h': [0.84],
#    'pci_20': [96],
#    'ifa': [7]},
#   'olap-navigator.csv': {'f1': [0.48],
#    'precision': [0.64],
#    'recall': [0.48],
#    'g-score': [0.38],
#    'd2h': [0.69],
#    'pci_20': [98],
#    'ifa': [7]},
#   'qashweb.csv': {'f1': [0.5],
#    'precision': [0.52],
#    'recall': [0.51],
#    'g-score': [0.57],
#    'd2h': [0.72],
#    'pci_20': [97],
#    'ifa': [1]},
#   'findbugs.csv': {'f1': [0.51],
#    'precision': [0.54],
#    'recall': [0.51],
#    'g-score': [0.53],
#    'd2h': [0.69],
#    'pci_20': [98],
#    'ifa': [2]},
#   'lladd.csv': {'f1': [0.44],
#    'precision': [0.45],
#    'recall': [0.47],
#    'g-score': [0.5],
#    'd2h': [0.83],
#    'pci_20': [97],
#    'ifa': [1]},
#   'pytables.csv': {'f1': [0.59],
#    'precision': [0.81],
#    'recall': [0.62],
#    'g-score': [0.43],
#    'd2h': [0.62],
#    'pci_20': [92],
#    'ifa': [0]},
#   'irplus.csv': {'f1': [0.64],
#    'precision': [0.63],
#    'recall': [0.64],
#    'g-score': [0.52],
#    'd2h': [0.59],
#    'pci_20': [98],
#    'ifa': [24]},
#   'jmule.csv': {'f1': [0.59],
#    'precision': [0.6],
#    'recall': [0.6],
#    'g-score': [0.46],
#    'd2h': [0.63],
#    'pci_20': [98],
#    'ifa': [1]},
#   'yabause.csv': {'f1': [0.61],
#    'precision': [0.59],
#    'recall': [0.64],
#    'g-score': [0.43],
#    'd2h': [0.86],
#    'pci_20': [97],
#    'ifa': [0]},
#   'obo.csv': {'f1': [0.71],
#    'precision': [0.88],
#    'recall': [0.68],
#    'g-score': [0.88],
#    'd2h': [0.4],
#    'pci_20': [96],
#    'ifa': [4]},
#   'noxwizard.csv': {'f1': [0.61],
#    'precision': [0.79],
#    'recall': [0.5],
#    'g-score': [0.0],
#    'd2h': [1.1],
#    'pci_20': [91],
#    'ifa': [11]},
#   'rkward.csv': {'f1': [0.75],
#    'precision': [0.78],
#    'recall': [0.74],
#    'g-score': [0.74],
#    'd2h': [0.46],
#    'pci_20': [95],
#    'ifa': [1]},
#   'cing.csv': {'f1': [1.0],
#    'precision': [1.0],
#    'recall': [1.0],
#    'g-score': [1.0],
#    'd2h': [0.0],
#    'pci_20': [50],
#    'ifa': [0]},
#   'arcallians.csv': {'f1': [0.38],
#    'precision': [0.51],
#    'recall': [0.52],
#    'g-score': [0.09],
#    'd2h': [0.98],
#    'pci_20': [98],
#    'ifa': [0]},
#   'msnp-sharp.csv': {'f1': [0.57],
#    'precision': [0.57],
#    'recall': [0.57],
#    'g-score': [0.61],
#    'd2h': [0.62],
#    'pci_20': [97],
#    'ifa': [2]},
#   'xcf.csv': {'f1': [0.53],
#    'precision': [0.53],
#    'recall': [0.53],
#    'g-score': [0.51],
#    'd2h': [0.66],
#    'pci_20': [98],
#    'ifa': [1]},
#   'heekscad.csv': {'f1': [0.69],
#    'precision': [0.69],
#    'recall': [0.69],
#    'g-score': [0.72],
#    'd2h': [0.51],
#    'pci_20': [99],
#    'ifa': [1]},
#   'cities3d.csv': {'f1': [0.41],
#    'precision': [0.88],
#    'recall': [0.33],
#    'g-score': [0.6],
#    'd2h': [0.74],
#    'pci_20': [99],
#    'ifa': [2]},
#   'megasquirtavr.csv': {'f1': [0.76],
#    'precision': [0.78],
#    'recall': [0.81],
#    'g-score': [0.24],
#    'd2h': [0.8],
#    'pci_20': [98],
#    'ifa': [7]},
#   'ivataopenportal.csv': {'f1': [0.57],
#    'precision': [0.61],
#    'recall': [0.59],
#    'g-score': [0.43],
#    'd2h': [0.64],
#    'pci_20': [99],
#    'ifa': [5]},
#   'judy.csv': {'f1': [0.56],
#    'precision': [0.6],
#    'recall': [0.56],
#    'g-score': [0.61],
#    'd2h': [0.61],
#    'pci_20': [97],
#    'ifa': [0]},
#   'continuum-ide.csv': {'f1': [0.31],
#    'precision': [0.49],
#    'recall': [0.34],
#    'g-score': [0.45],
#    'd2h': [0.87],
#    'pci_20': [98],
#    'ifa': [2]},
#   'sablevm.csv': {'f1': [0.69],
#    'precision': [0.82],
#    'recall': [0.71],
#    'g-score': [0.8],
#    'd2h': [0.56],
#    'pci_20': [96],
#    'ifa': [14]},
#   'axiomengine.csv': {'f1': [0.45],
#    'precision': [0.96],
#    'recall': [0.33],
#    'g-score': [0.68],
#    'd2h': [0.7],
#    'pci_20': [95],
#    'ifa': [18]},
#   'libopenmetaverse.csv': {'f1': [0.52],
#    'precision': [0.52],
#    'recall': [0.52],
#    'g-score': [0.49],
#    'd2h': [0.68],
#    'pci_20': [98],
#    'ifa': [9]},
#   'rockbox.csv': {'f1': [0.72],
#    'precision': [0.72],
#    'recall': [0.73],
#    'g-score': [0.57],
#    'd2h': [0.5],
#    'pci_20': [98],
#    'ifa': [2]},
#   'openuss.csv': {'f1': [0.77],
#    'precision': [0.71],
#    'recall': [0.84],
#    'g-score': [0.0],
#    'd2h': [1.0],
#    'pci_20': [94],
#    'ifa': [18]},
#   'intact.csv': {'f1': [0.62],
#    'precision': [0.64],
#    'recall': [0.61],
#    'g-score': [0.5],
#    'd2h': [0.63],
#    'pci_20': [99],
#    'ifa': [3]},
#   'salasaga.csv': {'f1': [0.1],
#    'precision': [0.75],
#    'recall': [0.18],
#    'g-score': [0.17],
#    'd2h': [0.96],
#    'pci_20': [99],
#    'ifa': [1]},
#   'dbrefactor.csv': {'f1': [0.0]},
#   'znc.csv': {'f1': [0.62],
#    'precision': [0.63],
#    'recall': [0.63],
#    'g-score': [0.48],
#    'd2h': [0.6],
#    'pci_20': [97],
#    'ifa': [2]},
#   'posit-android.csv': {'f1': [0.18],
#    'precision': [0.44],
#    'recall': [0.11],
#    'g-score': [0.0],
#    'd2h': [1.33],
#    'pci_20': [88],
#    'ifa': [7]},
#   'triplea.csv': {'f1': [0.47],
#    'precision': [0.47],
#    'recall': [0.49],
#    'g-score': [0.49],
#    'd2h': [0.84],
#    'pci_20': [98],
#    'ifa': [1]},
#   ...}}

# %%
with open('data/1385_LR_DE_bellwether_100.pkl', 'wb') as handle:
    pickle.dump(final_score, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
df = pd.read_pickle('data/1385_LR_default_bellwether_100.pkl')
results_f1 = {}
results_precision = {}
results_recall = {}
results_g = {}
results_d2h = {}
results_pci_20 = {}
results_ifa = {}
results_pd = {}
results_pf = {}
for s_project in df.keys():
    if s_project not in results_f1.keys():
        results_f1[s_project] = {}
        results_precision[s_project] = {}
        results_recall[s_project] = {}
        results_g[s_project] = {}
        results_d2h[s_project] = {}
        results_pci_20[s_project] = {}
        results_ifa[s_project] = {}
        results_pd[s_project] = {}
        results_pf[s_project] = {}
    for d_projects in df[s_project].keys():
        results_f1[s_project][d_projects] = np.median(df[s_project][d_projects]['f1'])
        results_precision[s_project][d_projects] = np.median(df[s_project][d_projects]['precision'])
        results_recall[s_project][d_projects] = np.median(df[s_project][d_projects]['recall'])
        results_g[s_project][d_projects] = np.median(df[s_project][d_projects]['g-score'])
        results_d2h[s_project][d_projects] = np.median(df[s_project][d_projects]['d2h'])
        results_pci_20[s_project][d_projects] = np.median(df[s_project][d_projects]['pci_20'])
        results_ifa[s_project][d_projects] = np.median(df[s_project][d_projects]['ifa'])
        results_pd[s_project][d_projects] = np.median(df[s_project][d_projects]['pd'])
        results_pf[s_project][d_projects] = np.median(df[s_project][d_projects]['pf'])

# %%
results_f1_df = pd.DataFrame.from_dict(results_f1, orient='index')
results_precision_df = pd.DataFrame.from_dict(results_precision, orient='index')
results_recall_df = pd.DataFrame.from_dict(results_recall, orient='index')
results_g_df = pd.DataFrame.from_dict(results_g, orient='index')
results_d2h_df = pd.DataFrame.from_dict(results_d2h, orient='index')
results_pci_20_df = pd.DataFrame.from_dict(results_pci_20, orient='index')
results_ifa_df = pd.DataFrame.from_dict(results_ifa, orient='index')
results_pd_df = pd.DataFrame.from_dict(results_pd, orient='index')
results_pf_df = pd.DataFrame.from_dict(results_pf, orient='index')

# %%
results_f1_df.to_csv('data/1385/100/1385_LR_bellwether_f1.csv')
results_precision_df.to_csv('data/1385/100/1385_LR_bellwether_precision.csv')
results_recall_df.to_csv('data/1385/100/1385_LR_bellwether_recall.csv')
results_g_df.to_csv('data/1385/100/1385_LR_bellwether_g.csv')
results_d2h_df.to_csv('data/1385/100/1385_LR_bellwether_d2h.csv')
results_pci_20_df.to_csv('data/1385/100/1385_LR_bellwether_pci_20.csv')
results_ifa_df.to_csv('data/1385/100/1385_LR_bellwether_ifa.csv')
results_pd_df.to_csv('data/1385/100/1385_LR_bellwether_pd.csv')
results_pf_df.to_csv('data/1385/100/1385_LR_bellwether_pf.csv')

# %%
# Out:
#                      freedom-erp.csv  twostep.csv  iaml.csv  etics.csv  \
# adonthell.csv                   0.25         0.54      0.26       0.09
# amanda.csv                      0.33         0.20      0.44       0.23
# amygdala.csv                    0.43         0.20      0.42       0.09
# bloodycore.csv                  0.25         0.49      0.26       0.66
# bzbyte.csv                      0.25         0.20      0.26       0.13
# etics.csv                       0.43         0.62      0.53        NaN
# fleet-simulator.csv             0.25         0.33      0.26       0.50
# flylegacy.csv                   0.43         0.60      0.58       0.71
# fmri-dmt.csv                    0.25         0.33      0.31       0.55
# freedom-erp.csv                  NaN         0.20      0.42       0.09
# gdis.csv                        0.43         0.24      0.53       0.08
# geotools.csv                    0.25         0.20      0.51       0.09
# gnukeda.csv                     0.25         0.20      0.40       0.22
# gtad.csv                        0.25         0.62      0.26       0.32
# iaml.csv                        0.43         0.50       NaN       0.70
# ikvm.csv                        0.63         0.69      0.53       0.38
# jahshakafx.csv                  0.25         0.20      0.52       0.09
# japano.csv                      0.25         0.30      0.48       0.16
# jaql.csv                        0.25         0.20      0.34       0.46
# jcache.csv                      0.48         0.74      0.44       0.45
# jicarilla.csv                   0.25         0.49      0.26       0.66
# jparsec.csv                     0.25         0.86      0.27       0.76
# jrdf.csv                        0.25         0.64      0.26       0.80
# jstock.csv                      0.25         0.50      0.29       0.65
# k3d.csv                         0.25         0.30      0.38       0.34
# liferea.csv                     0.25         0.20      0.26       0.66
# m-m-m.csv                       0.25         0.30      0.26       0.30
# mcmc-jags.csv                   0.25         0.62      0.26       0.72
# mcore3d.csv                     0.41         0.20      0.43       0.09
# metacosm.csv                    0.25         0.49      0.26       0.66
# mobicents.csv                   0.68         0.20      0.42       0.09
# monetdb.csv                     0.57         0.20      0.41       0.09
# moviesandbox.csv                0.25         0.36      0.26       0.69
# mplayer-ce.csv                  0.25         0.49      0.26       0.66
# nassp.csv                       0.25         0.20      0.47       0.09
# neoengine.csv                   0.25         0.20      0.47       0.09
# ng4j.csv                        0.43         0.71      0.47       0.23
# nova.csv                        0.25         0.59      0.26       0.68
# nsis.csv                        0.43         0.48      0.42       0.38
# powerfolder-.csv                0.27         0.54      0.42       0.63
# qmcpack.csv                     0.25         0.19      0.26       0.09
# scite-ru.csv                    0.25         0.20      0.45       0.09
# soar.csv                        0.43         0.49      0.43       0.66
# twostep.csv                     0.43          NaN      0.42       0.72
# uwom.csv                        0.25         0.67      0.39       0.68
# vdsf.csv                        0.25         0.49      0.26       0.66
# xbplayer.csv                    0.25         0.23      0.43       0.09
#
#                      neoengine.csv  nsis.csv  vdsf.csv  monetdb.csv  \
# adonthell.csv                 0.48      0.01      0.87         0.55
# amanda.csv                    0.59      0.80      0.02         0.63
# amygdala.csv                  0.21      0.89      0.01         0.16
# bloodycore.csv                0.48      0.01      0.87         0.55
# bzbyte.csv                    0.48      0.88      0.87         0.55
# etics.csv                     0.60      0.42      0.10         0.16
# fleet-simulator.csv           0.48      0.28      0.87         0.55
# flylegacy.csv                 0.64      0.55      0.11         0.24
# fmri-dmt.csv                  0.48      0.13      0.87         0.55
# freedom-erp.csv               0.21      0.89      0.01         0.58
# gdis.csv                      0.20      0.76      0.01         0.24
# geotools.csv                  0.59      0.89      0.03         0.55
# gnukeda.csv                   0.52      0.88      0.87         0.55
# gtad.csv                      0.48      0.05      0.87         0.55
# iaml.csv                      0.64      0.23      0.63         0.16
# ikvm.csv                      0.36      0.83      0.76         0.64
# jahshakafx.csv                0.49      0.89      0.68         0.55
# japano.csv                    0.58      0.75      0.87         0.55
# jaql.csv                      0.48      0.80      0.87         0.55
# jcache.csv                    0.64      0.50      0.66         0.62
# jicarilla.csv                 0.48      0.01      0.87         0.55
# jparsec.csv                   0.48      0.01      0.87         0.55
# jrdf.csv                      0.48      0.01      0.87         0.55
# jstock.csv                    0.50      0.32      0.87         0.55
# k3d.csv                       0.68      0.56      0.83         0.56
# liferea.csv                   0.48      0.09      0.87         0.55
# m-m-m.csv                     0.48      0.01      0.87         0.55
# mcmc-jags.csv                 0.48      0.01      0.87         0.55
# mcore3d.csv                   0.23      0.87      0.56         0.60
# metacosm.csv                  0.48      0.01      0.87         0.55
# mobicents.csv                 0.21      0.89      0.01         0.15
# monetdb.csv                   0.21      0.89      0.01          NaN
# moviesandbox.csv              0.48      0.01      0.87         0.55
# mplayer-ce.csv                0.48      0.01      0.87         0.55
# nassp.csv                     0.66      0.64      0.76         0.55
# neoengine.csv                  NaN      0.89      0.74         0.55
# ng4j.csv                      0.21      0.88      0.01         0.16
# nova.csv                      0.48      0.05      0.87         0.55
# nsis.csv                      0.21       NaN      0.01         0.16
# powerfolder-.csv              0.57      0.27      0.87         0.70
# qmcpack.csv                   0.48      0.29      0.87         0.55
# scite-ru.csv                  0.58      0.88      0.72         0.59
# soar.csv                      0.51      0.01      0.80         0.16
# twostep.csv                   0.21      0.89      0.01         0.16
# uwom.csv                      0.68      0.48      0.88         0.56
# vdsf.csv                      0.48      0.01       NaN         0.55
# xbplayer.csv                  0.48      0.60      0.87         0.55
#
#                      amygdala.csv  ikvm.csv  ...  gnukeda.csv  \
# adonthell.csv                0.36      0.42  ...         0.28
# amanda.csv                   0.36      0.50  ...         0.56
# amygdala.csv                  NaN      0.25  ...         0.39
# bloodycore.csv               0.31      0.42  ...         0.28
# bzbyte.csv                   0.36      0.42  ...         0.33
# etics.csv                    0.48      0.25  ...         0.40
# fleet-simulator.csv          0.36      0.42  ...         0.28
# flylegacy.csv                0.65      0.28  ...         0.57
# fmri-dmt.csv                 0.34      0.42  ...         0.37
# freedom-erp.csv              0.36      0.24  ...         0.39
# gdis.csv                     0.49      0.26  ...         0.51
# geotools.csv                 0.36      0.47  ...         0.39
# gnukeda.csv                  0.36      0.41  ...          NaN
# gtad.csv                     0.36      0.42  ...         0.28
# iaml.csv                     0.40      0.28  ...         0.52
# ikvm.csv                     0.39       NaN  ...         0.37
# jahshakafx.csv               0.36      0.75  ...         0.46
# japano.csv                   0.56      0.44  ...         0.51
# jaql.csv                     0.36      0.42  ...         0.35
# jcache.csv                   0.53      0.63  ...         0.46
# jicarilla.csv                0.36      0.42  ...         0.28
# jparsec.csv                  0.44      0.42  ...         0.28
# jrdf.csv                     0.43      0.42  ...         0.28
# jstock.csv                   0.40      0.42  ...         0.39
# k3d.csv                      0.65      0.40  ...         0.54
# liferea.csv                  0.36      0.42  ...         0.28
# m-m-m.csv                    0.38      0.42  ...         0.28
# mcmc-jags.csv                0.63      0.42  ...         0.28
# mcore3d.csv                  0.36      0.50  ...         0.45
# metacosm.csv                 0.31      0.42  ...         0.28
# mobicents.csv                0.36      0.25  ...         0.39
# monetdb.csv                  0.36      0.25  ...         0.39
# moviesandbox.csv             0.44      0.42  ...         0.28
# mplayer-ce.csv               0.31      0.42  ...         0.28
# nassp.csv                    0.36      0.60  ...         0.58
# neoengine.csv                0.36      0.41  ...         0.60
# ng4j.csv                     0.51      0.25  ...         0.39
# nova.csv                     0.48      0.42  ...         0.34
# nsis.csv                     0.33      0.25  ...         0.38
# powerfolder-.csv             0.34      0.60  ...         0.52
# qmcpack.csv                  0.36      0.42  ...         0.28
# scite-ru.csv                 0.35      0.69  ...         0.61
# soar.csv                     0.31      0.29  ...         0.28
# twostep.csv                  0.52      0.25  ...         0.39
# uwom.csv                     0.60      0.40  ...         0.58
# vdsf.csv                     0.31      0.42  ...         0.28
# xbplayer.csv                 0.36      0.42  ...         0.50
#
#                      powerfolder-.csv  jparsec.csv  m-m-m.csv  adonthell.csv  \
# adonthell.csv                    0.58         0.22       0.76            NaN
# amanda.csv                       0.38         0.22       0.76           0.41
# amygdala.csv                     0.13         0.46       0.56           0.40
# bloodycore.csv                   0.58         0.46       0.05           0.27
# bzbyte.csv                       0.43         0.22       0.76           0.40
# etics.csv                        0.34         0.50       0.28           0.32
# fleet-simulator.csv              0.64         0.22       0.74           0.50
# flylegacy.csv                    0.36         0.35       0.54           0.45
# fmri-dmt.csv                     0.59         0.25       0.75           0.57
# freedom-erp.csv                  0.13         0.22       0.76           0.40
# gdis.csv                         0.13         0.24       0.75           0.45
# geotools.csv                     0.15         0.22       0.76           0.40
# gnukeda.csv                      0.29         0.22       0.76           0.40
# gtad.csv                         0.68         0.37       0.64           0.48
# iaml.csv                         0.38         0.55       0.05           0.35
# ikvm.csv                         0.20         0.52       0.64           0.54
# jahshakafx.csv                   0.15         0.22       0.76           0.40
# japano.csv                       0.30         0.22       0.74           0.44
# jaql.csv                         0.29         0.22       0.76           0.46
# jcache.csv                       0.55         0.65       0.38           0.49
# jicarilla.csv                    0.58         0.45       0.05           0.27
# jparsec.csv                      0.60          NaN       0.42           0.29
# jrdf.csv                         0.58         0.23       0.68           0.27
# jstock.csv                       0.69         0.51       0.43           0.60
# k3d.csv                          0.51         0.28       0.57           0.48
# liferea.csv                      0.74         0.23       0.75           0.49
# m-m-m.csv                        0.58         0.22        NaN           0.53
# mcmc-jags.csv                    0.53         0.35       0.45           0.37
# mcore3d.csv                      0.13         0.22       0.76           0.39
# metacosm.csv                     0.58         0.46       0.05           0.27
# mobicents.csv                    0.13         0.22       0.76           0.40
# monetdb.csv                      0.13         0.22       0.76           0.40
# moviesandbox.csv                 0.59         0.25       0.75           0.39
# mplayer-ce.csv                   0.58         0.46       0.05           0.27
# nassp.csv                        0.15         0.22       0.76           0.52
# neoengine.csv                    0.13         0.22       0.76           0.40
# ng4j.csv                         0.13         0.34       0.48           0.52
# nova.csv                         0.58         0.52       0.30           0.41
# nsis.csv                         0.52         0.48       0.05           0.48
# powerfolder-.csv                  NaN         0.39       0.53           0.32
# qmcpack.csv                      0.67         0.22       0.76           0.45
# scite-ru.csv                     0.15         0.22       0.76           0.44
# soar.csv                         0.60         0.46       0.05           0.27
# twostep.csv                      0.18         0.48       0.19           0.57
# uwom.csv                         0.45         0.29       0.66           0.49
# vdsf.csv                         0.58         0.46       0.05           0.27
# xbplayer.csv                     0.28         0.40       0.74           0.53
#
#                      k3d.csv  fmri-dmt.csv  amanda.csv  jaql.csv  bzbyte.csv
# adonthell.csv           0.79          0.88        0.37      0.46        0.56
# amanda.csv              0.79          0.20         NaN      0.33        0.71
# amygdala.csv            0.04          0.01        0.29      0.22        0.66
# bloodycore.csv          0.79          0.87        0.37      0.46        0.09
# bzbyte.csv              0.79          0.51        0.37      0.53         NaN
# etics.csv               0.04          0.54        0.38      0.63        0.62
# fleet-simulator.csv     0.79          0.65        0.37      0.46        0.52
# flylegacy.csv           0.39          0.58        0.40      0.35        0.64
# fmri-dmt.csv            0.79           NaN        0.37      0.44        0.16
# freedom-erp.csv         0.30          0.01        0.29      0.23        0.66
# gdis.csv                0.29          0.13        0.37      0.23        0.68
# geotools.csv            0.79          0.01        0.37      0.31        0.66
# gnukeda.csv             0.79          0.12        0.37      0.54        0.64
# gtad.csv                0.79          0.69        0.37      0.49        0.61
# iaml.csv                0.06          0.58        0.48      0.57        0.62
# ikvm.csv                0.53          0.60        0.41      0.45        0.58
# jahshakafx.csv          0.74          0.01        0.67      0.25        0.66
# japano.csv              0.79          0.40        0.39      0.42        0.66
# jaql.csv                0.79          0.29        0.37       NaN        0.67
# jcache.csv              0.65          0.59        0.55      0.60        0.65
# jicarilla.csv           0.79          0.87        0.37      0.46        0.09
# jparsec.csv             0.79          0.85        0.37      0.52        0.44
# jrdf.csv                0.79          0.87        0.37      0.46        0.09
# jstock.csv              0.79          0.81        0.37      0.56        0.35
# k3d.csv                  NaN          0.56        0.46      0.56        0.66
# liferea.csv             0.79          0.73        0.37      0.46        0.56
# m-m-m.csv               0.79          0.84        0.37      0.46        0.26
# mcmc-jags.csv           0.79          0.79        0.37      0.51        0.55
# mcore3d.csv             0.67          0.01        0.60      0.22        0.66
# metacosm.csv            0.79          0.87        0.37      0.46        0.09
# mobicents.csv           0.04          0.01        0.29      0.22        0.66
# monetdb.csv             0.10          0.01        0.33      0.22        0.66
# moviesandbox.csv        0.79          0.82        0.37      0.46        0.12
# mplayer-ce.csv          0.79          0.87        0.37      0.46        0.09
# nassp.csv               0.79          0.10        0.43      0.49        0.66
# neoengine.csv           0.79          0.01        0.37      0.29        0.66
# ng4j.csv                0.04          0.10        0.29      0.22        0.64
# nova.csv                0.79          0.85        0.37      0.47        0.15
# nsis.csv                0.04          0.47        0.29      0.30        0.67
# powerfolder-.csv        0.74          0.71        0.54      0.56        0.57
# qmcpack.csv             0.79          0.42        0.37      0.50        0.59
# scite-ru.csv            0.79          0.10        0.61      0.23        0.65
# soar.csv                0.04          0.87        0.29      0.45        0.09
# twostep.csv             0.04          0.20        0.29      0.22        0.66
# uwom.csv                0.82          0.40        0.56      0.64        0.65
# vdsf.csv                0.79          0.87        0.37      0.46        0.09
# xbplayer.csv            0.79          0.26        0.37      0.58        0.69
#
# [47 rows x 47 columns]
