# %%
import pandas as pd
import numpy as np
import math
import pickle

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold

import platform
from os import listdir
from os.path import isfile, join
from glob import glob
from pathlib import Path
import sys
import os
import copy
import traceback
from pathlib import Path


import matplotlib.pyplot as plt

import SMOTE
import feature_selector
import DE
import CFS
import birch
import metrics.abcd
import birch_bellwether_v2

import metrices
import measures

import sys
import traceback
import warnings
warnings.filterwarnings("ignore")

# %%
#get cluster wise data for summarzation using median
def find_bellwether(data_source1,data_store,path,fold):
    df_train = pd.read_pickle(data_source1 + '/train_data.pkl')
    test_data = pd.read_pickle(data_source1 + '/test_data.pkl')
    test_projects = test_data.index.values.tolist()
    #cluster,cluster_tree = build_BIRCH(df_train)
    cluster_ids = []
    cluster_structure = {}
    size = {}
    goals = ['recall','precision','pf','pci_20','ifa']
    for _ in range(1):
        count = 0
        count_not = 0
        count_yes = 0
        score = []
        score_med = []
        cluster_info = {}
        for _ in range(1):
            df = pd.read_csv(data_store + '/cdom_latest.csv')
            counts = {}
            med_count = []
            c_dom = df.wins.values.tolist()
            best_project = df.iloc[c_dom.index(max(c_dom)),0]
            for goal in goals:
                goal_df = pd.read_csv(data_store + '/bellwether_0_' + goal + '.csv')
                goal_df.drop(labels=['Unnamed: 0'],axis = 1, inplace = True)
                j = goal_df[goal_df['s_project'] == best_project].values[0][1:]
                if goal == 'pci_20':
                    value = sum(i >= 0.40 for i in j)
                elif goal != 'pf':
                    value = sum(i >= 0.66 for i in j)
                else:
                    value = sum(i <= 0.33 for i in j)
                counts[goal] = value
            score_med.append([0,
                              counts['recall'],
                              counts['precision'],
                              counts['pf'],
                              counts['pci_20'],
                              max(c_dom),
                              best_project])
        score_df = pd.DataFrame(score_med, columns = ['id','count_recall',
                                                      'count_precision','count_pf','count_pci_20',
                                                      'cdom_score','bellwether'])
        score_df = score_df.sort_values('id')
        score_df.to_csv(data_store + '/bellwether_cdom_0.csv')
        bell = birch_bellwether_v2.bellwether(path,df_train)
        final_score = bell.bellwether([best_project],test_projects)
        with open(data_store + '/cluster_0_performance.pkl', 'wb') as handle:
            pickle.dump(final_score, handle, protocol=pickle.HIGHEST_PROTOCOL) 
        result = {}
        for key in final_score.keys():
            for key2 in final_score[key].keys():
                for key3 in final_score[key][key2].keys():
                    if key3 not in result.keys():
                        result[key3] = {}                       
                    result[key3][key2] = np.median(final_score[key][key2][key3])
        for key in result.keys():
            result_df = pd.DataFrame.from_dict(result[key],orient='index',columns=[key])
            if not Path(data_store + '/results/').is_dir():
                os.makedirs(Path(data_store + '/results/'))
            result_df.to_csv(data_store + '/results/' + key + '.csv')

# %%
for fold in range(20):
    print(fold)
    path = '/Users/suvodeepmajumder/Documents/AI4SE/bellwether_comminity/data/1385/converted'
    data_source1 = '/Users/suvodeepmajumder/Documents/AI4SE/bellwether_comminity/src/data/1385/exp2/2/fold_' + str(fold)
    data_store = '/Users/suvodeepmajumder/Documents/AI4SE/bellwether_comminity/src/data/1385/exp5/fold_' + str(fold)
    find_bellwether(data_source1,data_store,path,fold)
# Out:
# 0
# ftm.csv
# dest ftm.csv guineu.csv
# dest ftm.csv campsoft.csv
# dest ftm.csv gtad.csv
# dest ftm.csv rhex.csv
# dest ftm.csv owlib.csv
# dest ftm.csv ktc.csv
# dest ftm.csv jedit.csv
# dest ftm.csv net-snmp.csv
# dest ftm.csv encog-java.csv
# dest ftm.csv umber.csv
# dest ftm.csv jahshakafx.csv
# dest ftm.csv jahshaka.csv
# dest ftm.csv selenium.csv
# dest ftm.csv paintown.csv
# dest ftm.csv h2database.csv
# dest ftm.csv x4x.csv
# dest ftm.csv elmo.csv
# dest ftm.csv jmoney.csv
# dest ftm.csv google-collections.csv
# dest ftm.csv baadengine.csv
# dest ftm.csv raven-monitoring.csv
# dest ftm.csv smbopensoft.csv
# dest ftm.csv xharbour.csv
# dest ftm.csv flylinkdc.csv
# dest ftm.csv reactos-mirror.csv
# dest ftm.csv qpe.csv
# dest ftm.csv xbrlapi.csv
# dest ftm.csv prelude.csv
# dest ftm.csv neoengine.csv
# dest ftm.csv atunes.csv
# dest ftm.csv avifile.csv
# dest ftm.csv lamp.csv
# dest ftm.csv logicmail.csv
# dest ftm.csv wgs-assembler.csv
# dest ftm.csv plearn.csv
# dest ftm.csv werx.csv
# dest ftm.csv plog4u.csv
# dest ftm.csv openwbem.csv
# dest ftm.csv qgo.csv
# dest ftm.csv jaql.csv
# dest ftm.csv kmatplot.csv
# dest ftm.csv pclasses.csv
# dest ftm.csv agilitybook.csv
# dest ftm.csv triplea.csv
# dest ftm.csv raygina.csv
# dest ftm.csv wpdev.csv
# dest ftm.csv owfs.csv
# dest ftm.csv olap-navigator.csv
# dest ftm.csv pokeglobal.csv
# dest ftm.csv nova.csv
# dest ftm.csv sauerbraten.csv
# dest ftm.csv graphmak.csv
# dest ftm.csv jgameai.csv
# dest ftm.csv gpsmid.csv
# dest ftm.csv empyrean.csv
# dest ftm.csv awemud.csv
# dest ftm.csv crisscross.csv
# dest ftm.csv re2c.csv
# dest ftm.csv tzod.csv
# dest ftm.csv octave.csv
# dest ftm.csv adaptagrams.csv
# dest ftm.csv open-media-library.csv
# dest ftm.csv vdsf.csv
# dest ftm.csv orc.csv
# dest ftm.csv lazarus-ccr.csv
# dest ftm.csv n2cms.csv
# dest ftm.csv forester-atv.csv
# dest ftm.csv mob-sen-plat.csv
# dest ftm.csv nh3d.csv
# dest ftm.csv amanda.csv
# 1
# ftm.csv
# dest ftm.csv rectracker.csv
# dest ftm.csv dynalloy.csv
# dest ftm.csv mpqc.csv
# dest ftm.csv thout.csv
# dest ftm.csv benojt.csv
# dest ftm.csv sabbu.csv
# dest ftm.csv unladen-swallow.csv
# dest ftm.csv powerfolder-.csv
# dest ftm.csv barracudamvc.csv
# dest ftm.csv nutz.csv
# dest ftm.csv apolloplayer.csv
# dest ftm.csv vxl.csv
# dest ftm.csv fbmanager.csv
# dest ftm.csv olsrd.csv
# dest ftm.csv jajuk.csv
# dest ftm.csv sqlpower-library.csv
# dest ftm.csv heekscad.csv
# dest ftm.csv zorannt.csv
# dest ftm.csv emftriple.csv
# dest ftm.csv gamestone.csv
# dest ftm.csv jicarilla.csv
# dest ftm.csv sevenupdate.csv
# dest ftm.csv nuttx.csv
# dest ftm.csv psrchive.csv
# dest ftm.csv jvcl.csv
# dest ftm.csv kdenlive.csv
# dest ftm.csv hatari.csv
# dest ftm.csv maidsafe-dht.csv
# dest ftm.csv opde.csv
# dest ftm.csv brlcad.csv
# dest ftm.csv opentibia.csv
# dest ftm.csv plee-the-bear.csv
# dest ftm.csv xcsoar.csv
# dest ftm.csv vapor.csv
# dest ftm.csv reaper-ecad.csv
# dest ftm.csv jmri.csv
# dest ftm.csv igarden.csv
# dest ftm.csv mb-unit.csv
# dest ftm.csv kaffeine.csv
# dest ftm.csv ossim.csv
# dest ftm.csv jlinalg.csv
# dest ftm.csv megasquirtavr.csv
# dest ftm.csv psycle.csv
# dest ftm.csv beast-mcmc.csv
# dest ftm.csv ikvm.csv
# dest ftm.csv bscwweasel.csv
# dest ftm.csv zact.csv
# dest ftm.csv zscreen.csv
# dest ftm.csv sarasvati.csv
# dest ftm.csv flylegacy.csv
# dest ftm.csv nullc.csv
# dest ftm.csv dvt.csv
# dest ftm.csv retromenu.csv
# dest ftm.csv jatlas.csv
# dest ftm.csv liferea.csv
# dest ftm.csv array4j.csv
# dest ftm.csv go.csv
# dest ftm.csv zealos.csv
# dest ftm.csv ns-3.csv
# dest ftm.csv nug.csv
# dest ftm.csv critterding.csv
# dest ftm.csv gotjava.csv
# dest ftm.csv optalgtoolkit.csv
# dest ftm.csv kwave.csv
# dest ftm.csv superwaba.csv
# dest ftm.csv ltp.csv
# dest ftm.csv pdfedit.csv
# dest ftm.csv blogentis.csv
# dest ftm.csv mclient-mume.csv
# dest ftm.csv firebird.csv
# 2
# ftm.csv
# dest ftm.csv inkscape.csv
# dest ftm.csv wxcrp.csv
# dest ftm.csv m-m-m.csv
# dest ftm.csv bacula.csv
# dest ftm.csv extprosys.csv
# dest ftm.csv lsb.csv
# dest ftm.csv fritzing.csv
# dest ftm.csv robocode.csv
# dest ftm.csv capcode.csv
# dest ftm.csv openefm.csv
# dest ftm.csv etics.csv
# dest ftm.csv novembre.csv
# dest ftm.csv lmms.csv
# dest ftm.csv codeblocks.csv
# dest ftm.csv ontomorphtab.csv
# dest ftm.csv x-ray-mule.csv
# dest ftm.csv openintents.csv
# dest ftm.csv atomsite.csv
# dest ftm.csv bloodycore.csv
# dest ftm.csv checker-framework.csv
# dest ftm.csv arianne.csv
# dest ftm.csv dsworkbench.csv
# dest ftm.csv gogoego.csv
# dest ftm.csv electric-core.csv
# dest ftm.csv atlc.csv
# dest ftm.csv rosegarden.csv
# dest ftm.csv linuxsh.csv
# dest ftm.csv theresa.csv
# dest ftm.csv jcae.csv
# dest ftm.csv dxengine.csv
# dest ftm.csv uwom-server.csv
# dest ftm.csv ivatamasks.csv
# dest ftm.csv playerstage.csv
# dest ftm.csv taverna.csv
# dest ftm.csv rtb-team.csv
# dest ftm.csv projectts.csv
# dest ftm.csv autofac.csv
# dest ftm.csv nsis.csv
# dest ftm.csv knowledge.csv
# dest ftm.csv esmf.csv
# dest ftm.csv abbot.csv
# dest ftm.csv konversation.csv
# dest ftm.csv arsenal-1.csv
# dest ftm.csv utgb.csv
# dest ftm.csv taokgame.csv
# dest ftm.csv openmeetings.csv
# dest ftm.csv nosleepsoftware.csv
# dest ftm.csv jsidplay2.csv
# dest ftm.csv chipster.csv
# dest ftm.csv badtrinitycore.csv
# dest ftm.csv redshell.csv
# dest ftm.csv zengine.csv
# dest ftm.csv javagroups.csv
# dest ftm.csv hazelcast.csv
# dest ftm.csv xuggle.csv
# dest ftm.csv moviesandbox.csv
# dest ftm.csv jrefactory.csv
# dest ftm.csv alembik.csv
# dest ftm.csv mule.csv
# dest ftm.csv aubit4gl.csv
# dest ftm.csv sepgsql.csv
# dest ftm.csv sblim.csv
# dest ftm.csv pentahoanalysistool.csv
# dest ftm.csv rezilla.csv
# dest ftm.csv pcgen.csv
# dest ftm.csv dvd-create.csv
# dest ftm.csv freenet.csv
# dest ftm.csv ivef-sdk.csv
# dest ftm.csv adonthell.csv
# dest ftm.csv algebsql.csv
# 3
# ftm.csv
# dest ftm.csv qgis.csv
# dest ftm.csv migen.csv
# dest ftm.csv jsecurity.csv
# dest ftm.csv jnode.csv
# dest ftm.csv jhotdraw.csv
# dest ftm.csv sidekar.csv
# dest ftm.csv emeraldemu.csv
# dest ftm.csv emisview.csv
# dest ftm.csv autoopencas.csv
# dest ftm.csv mcmc-jags.csv
# dest ftm.csv cataclysmos.csv
# dest ftm.csv fontforge.csv
# dest ftm.csv badtrinity-zero.csv
# dest ftm.csv cleartk.csv
# dest ftm.csv delphilhlplib.csv
# dest ftm.csv mcore3d.csv
# dest ftm.csv applet2app.csv
# dest ftm.csv upp-mirror.csv
# dest ftm.csv magicwars.csv
# dest ftm.csv xbplayer.csv
# dest ftm.csv zildo.csv
# dest ftm.csv jython.csv
# dest ftm.csv ildjit.csv
# dest ftm.csv gbif-providertoolkit.csv
# dest ftm.csv jfreereport.csv
# dest ftm.csv opennms.csv
# dest ftm.csv yield.csv
# dest ftm.csv trackit.csv
# dest ftm.csv scen-connect.csv
# dest ftm.csv freelords.csv
# dest ftm.csv piccolo2d.csv
# dest ftm.csv bochs.csv
# dest ftm.csv intact.csv
# dest ftm.csv htmlunit.csv
# dest ftm.csv open-beos.csv
# dest ftm.csv libopenmetaverse.csv
# dest ftm.csv popeye-chess.csv
# dest ftm.csv jbpm.csv
# dest ftm.csv cities3d.csv
# dest ftm.csv springside.csv
# dest ftm.csv k3d.csv
# dest ftm.csv kvs.csv
# dest ftm.csv firebreath.csv
# dest ftm.csv fltk.csv
# dest ftm.csv bullet.csv
# dest ftm.csv mobicents.csv
# dest ftm.csv maya-work-in-progress.csv
# dest ftm.csv betoffice.csv
# dest ftm.csv scite-ru.csv
# dest ftm.csv ifmo-game-1.csv
# dest ftm.csv qcad2.csv
# dest ftm.csv xmemcached.csv
# dest ftm.csv ldview.csv
# dest ftm.csv rohxel.csv
# dest ftm.csv jpaul.csv
# dest ftm.csv pfaedit.csv
# dest ftm.csv gbif-indexingtoolkit.csv
# dest ftm.csv levent.csv
# dest ftm.csv neodatis-odb.csv
# dest ftm.csv pidgin.csv
# dest ftm.csv swtfox.csv
# dest ftm.csv aime.csv
# dest ftm.csv mvdsv.csv
# dest ftm.csv japano.csv
# dest ftm.csv jitterbit.csv
# dest ftm.csv encog-cs.csv
# dest ftm.csv red5.csv
# dest ftm.csv co-ode-owl-plugins.csv
# dest ftm.csv exordium.csv
# dest ftm.csv cornerstone.csv
# 4
# ftm.csv
# dest ftm.csv bl-toolkit.csv
# dest ftm.csv opengs.csv
# dest ftm.csv patterntesting.csv
# dest ftm.csv log4net.csv
# dest ftm.csv gzigzag.csv
# dest ftm.csv fw4spl.csv
# dest ftm.csv phet.csv
# dest ftm.csv gnukeda.csv
# dest ftm.csv jaxen.csv
# dest ftm.csv unimrcp.csv
# dest ftm.csv enlightenment.csv
# dest ftm.csv tokratan.csv
# dest ftm.csv opensim4opencog.csv
# dest ftm.csv rsyslog.csv
# dest ftm.csv qlc.csv
# dest ftm.csv lockss.csv
# dest ftm.csv nicepress.csv
# dest ftm.csv scenemonitor.csv
# dest ftm.csv wxlua.csv
# dest ftm.csv blue-c.csv
# dest ftm.csv tcl.csv
# dest ftm.csv etherboot.csv
# dest ftm.csv pustefix.csv
# dest ftm.csv haggle.csv
# dest ftm.csv jmonkeyengine.csv
# dest ftm.csv officefloor.csv
# dest ftm.csv fluidium.csv
# dest ftm.csv aufs.csv
# dest ftm.csv cuberok.csv
# dest ftm.csv vienna-add-in.csv
# dest ftm.csv ivataopenportal.csv
# dest ftm.csv decidr.csv
# dest ftm.csv mptvseries.csv
# dest ftm.csv planeshift.csv
# dest ftm.csv phonon-vlc-mplayer.csv
# dest ftm.csv jgnash.csv
# dest ftm.csv nassp.csv
# dest ftm.csv toped.csv
# dest ftm.csv mediate.csv
# dest ftm.csv arcallians.csv
# dest ftm.csv emulemorph.csv
# dest ftm.csv webdriver.csv
# dest ftm.csv jsr308-langtools.csv
# dest ftm.csv boost-sandbox.csv
# dest ftm.csv mvnforum.csv
# dest ftm.csv plato.csv
# dest ftm.csv tolven.csv
# dest ftm.csv grafx2.csv
# dest ftm.csv voms.csv
# dest ftm.csv onotoa.csv
# dest ftm.csv jguard.csv
# dest ftm.csv yale.csv
# dest ftm.csv jmol.csv
# dest ftm.csv mscore.csv
# dest ftm.csv hydrogen.csv
# dest ftm.csv qtwin.csv
# dest ftm.csv sbml.csv
# dest ftm.csv thrust.csv
# dest ftm.csv yaprm.csv
# dest ftm.csv continuum-ide.csv
# dest ftm.csv gpac.csv
# dest ftm.csv e-bio-flow.csv
# dest ftm.csv jbasic.csv
# dest ftm.csv aztec.csv
# dest ftm.csv sylpheed-claws.csv
# dest ftm.csv stuproa-cims.csv
# dest ftm.csv apertium.csv
# dest ftm.csv fm-classic.csv
# dest ftm.csv smarttag.csv
# dest ftm.csv pamguard.csv
# 5
# ftm.csv
# dest ftm.csv qtractor.csv
# dest ftm.csv oppna-program-hsatools.csv
# dest ftm.csv acegisecurity.csv
# dest ftm.csv customsagetv.csv
# dest ftm.csv openxava.csv
# dest ftm.csv botsnscouts.csv
# dest ftm.csv google-caja.csv
# dest ftm.csv freebios.csv
# dest ftm.csv tktoolkit.csv
# dest ftm.csv mbse.csv
# dest ftm.csv gebr.csv
# dest ftm.csv flexpay.csv
# dest ftm.csv bnetd.csv
# dest ftm.csv gabel.csv
# dest ftm.csv mpgravity.csv
# dest ftm.csv vars-redux.csv
# dest ftm.csv jam-daq.csv
# dest ftm.csv haphazard.csv
# dest ftm.csv httpcontentparser.csv
# dest ftm.csv mia.csv
# dest ftm.csv vrjuggler.csv
# dest ftm.csv myfaces.csv
# dest ftm.csv massiv.csv
# dest ftm.csv wow-qrsk.csv
# dest ftm.csv bacnet.csv
# dest ftm.csv gretl.csv
# dest ftm.csv empserver.csv
# dest ftm.csv plplot.csv
# dest ftm.csv mycila.csv
# dest ftm.csv ogrehg.csv
# dest ftm.csv alleg.csv
# dest ftm.csv k3b.csv
# dest ftm.csv jaxlib.csv
# dest ftm.csv chaperon.csv
# dest ftm.csv unbvision.csv
# dest ftm.csv genecys.csv
# dest ftm.csv openmalaria.csv
# dest ftm.csv wishmaster.csv
# dest ftm.csv bibedt.csv
# dest ftm.csv yarp0.csv
# dest ftm.csv tmva.csv
# dest ftm.csv azureus.csv
# dest ftm.csv bulmages.csv
# dest ftm.csv ctrlr.csv
# dest ftm.csv rodin-b-sharp.csv
# dest ftm.csv kowari.csv
# dest ftm.csv ppcboot.csv
# dest ftm.csv clamav.csv
# dest ftm.csv motu.csv
# dest ftm.csv gnupdate.csv
# dest ftm.csv customwars.csv
# dest ftm.csv libtorrent.csv
# dest ftm.csv fceugc.csv
# dest ftm.csv minig.csv
# dest ftm.csv calcubetimer.csv
# dest ftm.csv iaml.csv
# dest ftm.csv jppf-project.csv
# dest ftm.csv anaxagora.csv
# dest ftm.csv ipfire-wall.csv
# dest ftm.csv sumatrapdf.csv
# dest ftm.csv gwanted.csv
# dest ftm.csv cubefs.csv
# dest ftm.csv moving-pictures.csv
# dest ftm.csv alsa.csv
# dest ftm.csv nodal.csv
# dest ftm.csv monetdb.csv
# dest ftm.csv xemeiah.csv
# dest ftm.csv riff-evolve.csv
# dest ftm.csv owlapi.csv
# dest ftm.csv ogre.csv
# 6
# ftm.csv
# dest ftm.csv exist.csv
# dest ftm.csv proftp.csv
# dest ftm.csv rtrt-on-gpu.csv
# dest ftm.csv matrex.csv
# dest ftm.csv amateur-scrolls.csv
# dest ftm.csv ossbuild.csv
# dest ftm.csv st-filteredstatistics.csv
# dest ftm.csv pokenetonline.csv
# dest ftm.csv java-gnome.csv
# dest ftm.csv unflobtactical.csv
# dest ftm.csv archive-crawler.csv
# dest ftm.csv freedom-erp.csv
# dest ftm.csv miranda-icq.csv
# dest ftm.csv silvertree.csv
# dest ftm.csv projectfactory.csv
# dest ftm.csv autat.csv
# dest ftm.csv quarkplusplus.csv
# dest ftm.csv stemkit.csv
# dest ftm.csv foursquared.csv
# dest ftm.csv jasperreports.csv
# dest ftm.csv m-a-d-n-e-s-s.csv
# dest ftm.csv roolo.csv
# dest ftm.csv frogatto.csv
# dest ftm.csv mimosa.csv
# dest ftm.csv amygdala.csv
# dest ftm.csv irrlicht.csv
# dest ftm.csv lcfizvtop.csv
# dest ftm.csv grisbi.csv
# dest ftm.csv elynx.csv
# dest ftm.csv alpine.csv
# dest ftm.csv mumble.csv
# dest ftm.csv t-2.csv
# dest ftm.csv jaolt.csv
# dest ftm.csv libmesh.csv
# dest ftm.csv all-plasm.csv
# dest ftm.csv acdk.csv
# dest ftm.csv bwapi.csv
# dest ftm.csv modellus.csv
# dest ftm.csv micomt.csv
# dest ftm.csv mp-rechnungs-und-kundenverwaltung.csv
# dest ftm.csv tcvp.csv
# dest ftm.csv xstore.csv
# dest ftm.csv bdbbasic.csv
# dest ftm.csv tart.csv
# dest ftm.csv echongl.csv
# dest ftm.csv snakeyaml.csv
# dest ftm.csv wheat.csv
# dest ftm.csv dspace-gsoc.csv
# dest ftm.csv yarp.csv
# dest ftm.csv boost.csv
# dest ftm.csv qse.csv
# dest ftm.csv quarkplayer.csv
# dest ftm.csv open-data-kit.csv
# dest ftm.csv yafdotnet.csv
# dest ftm.csv impala.csv
# dest ftm.csv avisynth2.csv
# dest ftm.csv xreal.csv
# dest ftm.csv tycho.csv
# dest ftm.csv nabu-library.csv
# dest ftm.csv freewrl.csv
# dest ftm.csv roller.csv
# dest ftm.csv zabbix.csv
# dest ftm.csv turbotrader-bos.csv
# dest ftm.csv xpontus.csv
# dest ftm.csv cascading.csv
# dest ftm.csv omseek.csv
# dest ftm.csv kindb.csv
# dest ftm.csv panda3d.csv
# dest ftm.csv gusanos.csv
# dest ftm.csv truevision.csv
# 7
# ftm.csv
# dest ftm.csv kml.csv
# dest ftm.csv unicase.csv
# dest ftm.csv zoolib.csv
# dest ftm.csv ontopia.csv
# dest ftm.csv repositorium.csv
# dest ftm.csv pgui.csv
# dest ftm.csv ultimairis.csv
# dest ftm.csv galaxium.csv
# dest ftm.csv sigil.csv
# dest ftm.csv ardour.csv
# dest ftm.csv aten.csv
# dest ftm.csv irplus.csv
# dest ftm.csv xfce.csv
# dest ftm.csv projecteqemu.csv
# dest ftm.csv personalaccess.csv
# dest ftm.csv pcsx2.csv
# dest ftm.csv multitude.csv
# dest ftm.csv virtuoso.csv
# dest ftm.csv jrdf.csv
# dest ftm.csv runuomondains.csv
# dest ftm.csv jgossipforum.csv
# dest ftm.csv ingex.csv
# dest ftm.csv papertoolkit.csv
# dest ftm.csv modplug.csv
# dest ftm.csv xcmetadataservicestoolkit.csv
# dest ftm.csv bionote.csv
# dest ftm.csv openfrag.csv
# dest ftm.csv super-tux.csv
# dest ftm.csv uclmda.csv
# dest ftm.csv glas.csv
# dest ftm.csv itext.csv
# dest ftm.csv pydev.csv
# dest ftm.csv octet.csv
# dest ftm.csv powerfolder.csv
# dest ftm.csv auber.csv
# dest ftm.csv rebecca-aiml.csv
# dest ftm.csv dataobjectsdotnet.csv
# dest ftm.csv jparsec.csv
# dest ftm.csv twostep.csv
# dest ftm.csv xbg.csv
# dest ftm.csv joustsim.csv
# dest ftm.csv ofbiz.csv
# dest ftm.csv kftpgrabber.csv
# dest ftm.csv smartgwt.csv
# dest ftm.csv img-browse-sort.csv
# dest ftm.csv adobe-source.csv
# dest ftm.csv ibatisdb.csv
# dest ftm.csv fido.csv
# dest ftm.csv gdis.csv
# dest ftm.csv madman.csv
# dest ftm.csv soar.csv
# dest ftm.csv lufa-lib.csv
# dest ftm.csv somap.csv
# dest ftm.csv netatalk.csv
# dest ftm.csv google-web-toolkit.csv
# dest ftm.csv megameknet.csv
# dest ftm.csv power-architect.csv
# dest ftm.csv enzo.csv
# dest ftm.csv lite.csv
# dest ftm.csv hannosset.csv
# dest ftm.csv lportal.csv
# dest ftm.csv geotools.csv
# dest ftm.csv xined.csv
# dest ftm.csv reaper3d.csv
# dest ftm.csv openmsx.csv
# dest ftm.csv loki-lib.csv
# dest ftm.csv lphant.csv
# dest ftm.csv ns-3-dev-def-routing.csv
# dest ftm.csv wxcode.csv
# 8
# ftm.csv
# dest ftm.csv jchassis.csv
# dest ftm.csv doomlegacy.csv
# dest ftm.csv bzbyte.csv
# dest ftm.csv fmri-dmt.csv
# dest ftm.csv v8.csv
# dest ftm.csv servicestack.csv
# dest ftm.csv carabiner.csv
# dest ftm.csv gephex.csv
# dest ftm.csv mediaportal.csv
# dest ftm.csv gnome-jabber.csv
# dest ftm.csv fityk.csv
# dest ftm.csv mecat.csv
# dest ftm.csv ngl.csv
# dest ftm.csv codepurge.csv
# dest ftm.csv jcl.csv
# dest ftm.csv bigdata.csv
# dest ftm.csv salasaga.csv
# dest ftm.csv ondex.csv
# dest ftm.csv jas.csv
# dest ftm.csv qdvdauthor.csv
# dest ftm.csv gmerlin.csv
# dest ftm.csv wsmt.csv
# dest ftm.csv xqilla.csv
# dest ftm.csv jstock.csv
# dest ftm.csv poormans.csv
# dest ftm.csv kolmafia.csv
# dest ftm.csv synergyspace.csv
# dest ftm.csv nebuladevice.csv
# dest ftm.csv findbugs.csv
# dest ftm.csv qmmp.csv
# dest ftm.csv wxstudio.csv
# dest ftm.csv free-evolution.csv
# dest ftm.csv xapian.csv
# dest ftm.csv quark.csv
# dest ftm.csv les-indemodables.csv
# dest ftm.csv mesa3d.csv
# dest ftm.csv simplewebservices.csv
# dest ftm.csv illumination.csv
# dest ftm.csv wxjs.csv
# dest ftm.csv ambulant.csv
# dest ftm.csv kmess.csv
# dest ftm.csv fleet-simulator.csv
# dest ftm.csv tradelink.csv
# dest ftm.csv opendvr.csv
# dest ftm.csv pi-qmc.csv
# dest ftm.csv google-gears.csv
# dest ftm.csv bibletime.csv
# dest ftm.csv ipfilter.csv
# dest ftm.csv glelite.csv
# dest ftm.csv hibernate.csv
# dest ftm.csv keyczar.csv
# dest ftm.csv oscarmcmaster.csv
# dest ftm.csv passwordsafe.csv
# dest ftm.csv primefaces.csv
# dest ftm.csv xtreemfs.csv
# dest ftm.csv pixel-commandos.csv
# dest ftm.csv open-ms.csv
# dest ftm.csv pnotepad.csv
# dest ftm.csv qedo.csv
# dest ftm.csv tigermud.csv
# dest ftm.csv mevenide.csv
# dest ftm.csv xcf.csv
# dest ftm.csv ninject.csv
# dest ftm.csv xinity.csv
# dest ftm.csv xmoto.csv
# dest ftm.csv coot.csv
# dest ftm.csv emite.csv
# dest ftm.csv gss.csv
# dest ftm.csv icescrum.csv
# 9
# mecat.csv
# dest mecat.csv moast.csv
# dest mecat.csv chrysalis.csv
# dest mecat.csv cortex-vfx.csv
# dest mecat.csv l2j.csv
# dest mecat.csv geogebra.csv
# dest mecat.csv ffigo.csv
# dest mecat.csv autowikibrowser.csv
# dest mecat.csv duplicati.csv
# dest mecat.csv gstreamer.csv
# dest mecat.csv quantlib.csv
# dest mecat.csv skia.csv
# dest mecat.csv jruby.csv
# dest mecat.csv chaosrts.csv
# dest mecat.csv mplayer-ce.csv
# dest mecat.csv biopax.csv
# dest mecat.csv linux-ntfs.csv
# dest mecat.csv growl-for-windows.csv
# dest mecat.csv synecdoche.csv
# dest mecat.csv rcp-company-uibindings.csv
# dest mecat.csv tweetsharp.csv
# dest mecat.csv elateportal.csv
# dest mecat.csv sandiaportals.csv
# dest mecat.csv biodwh.csv
# dest mecat.csv trinitycore.csv
# dest mecat.csv zemljanka.csv
# dest mecat.csv tango-cs.csv
# dest mecat.csv buddata-ebxml-registry.csv
# dest mecat.csv javaprofiler.csv
# dest mecat.csv fluent-nhibernate.csv
# dest mecat.csv olex2.csv
# dest mecat.csv nunit.csv
# dest mecat.csv tencompetence.csv
# dest mecat.csv exl.csv
# dest mecat.csv nativeclient.csv
# dest mecat.csv codesmith.csv
# dest mecat.csv stajistics.csv
# dest mecat.csv oorexx.csv
# dest mecat.csv crux-framework.csv
# dest mecat.csv ta3d.csv
# dest mecat.csv web-cat.csv
# dest mecat.csv ftm.csv
# dest mecat.csv factor.csv
# dest mecat.csv hydrate.csv
# dest mecat.csv jfreechart.csv
# dest mecat.csv elvishrayrenderer.csv
# dest mecat.csv xamj.csv
# dest mecat.csv uwom.csv
# dest mecat.csv rocrail.csv
# dest mecat.csv columba.csv
# dest mecat.csv metacosm.csv
# dest mecat.csv quickfast.csv
# dest mecat.csv geochat.csv
# dest mecat.csv natpad.csv
# dest mecat.csv libarchive.csv
# dest mecat.csv jcache.csv
# dest mecat.csv zxing.csv
# dest mecat.csv arm-webradio.csv
# dest mecat.csv genoviz.csv
# dest mecat.csv fulguro.csv
# dest mecat.csv wikipediardware.csv
# dest mecat.csv rockbox.csv
# dest mecat.csv ng4j.csv
# dest mecat.csv uface.csv
# dest mecat.csv gisgraphy.csv
# dest mecat.csv emono.csv
# dest mecat.csv thedata.csv
# dest mecat.csv miranda.csv
# dest mecat.csv cme.csv
# dest mecat.csv jmule.csv
# 10
# ftm.csv
# dest ftm.csv guineu.csv
# dest ftm.csv campsoft.csv
# dest ftm.csv gtad.csv
# dest ftm.csv rhex.csv
# dest ftm.csv owlib.csv
# dest ftm.csv ktc.csv
# dest ftm.csv jedit.csv
# dest ftm.csv net-snmp.csv
# dest ftm.csv encog-java.csv
# dest ftm.csv umber.csv
# dest ftm.csv jahshakafx.csv
# dest ftm.csv jahshaka.csv
# dest ftm.csv selenium.csv
# dest ftm.csv paintown.csv
# dest ftm.csv h2database.csv
# dest ftm.csv x4x.csv
# dest ftm.csv elmo.csv
# dest ftm.csv jmoney.csv
# dest ftm.csv google-collections.csv
# dest ftm.csv baadengine.csv
# dest ftm.csv raven-monitoring.csv
# dest ftm.csv smbopensoft.csv
# dest ftm.csv xharbour.csv
# dest ftm.csv flylinkdc.csv
# dest ftm.csv reactos-mirror.csv
# dest ftm.csv qpe.csv
# dest ftm.csv xbrlapi.csv
# dest ftm.csv prelude.csv
# dest ftm.csv neoengine.csv
# dest ftm.csv atunes.csv
# dest ftm.csv avifile.csv
# dest ftm.csv lamp.csv
# dest ftm.csv logicmail.csv
# dest ftm.csv wgs-assembler.csv
# dest ftm.csv plearn.csv
# dest ftm.csv werx.csv
# dest ftm.csv plog4u.csv
# dest ftm.csv openwbem.csv
# dest ftm.csv qgo.csv
# dest ftm.csv jaql.csv
# dest ftm.csv kmatplot.csv
# dest ftm.csv pclasses.csv
# dest ftm.csv agilitybook.csv
# dest ftm.csv triplea.csv
# dest ftm.csv raygina.csv
# dest ftm.csv wpdev.csv
# dest ftm.csv owfs.csv
# dest ftm.csv olap-navigator.csv
# dest ftm.csv pokeglobal.csv
# dest ftm.csv nova.csv
# dest ftm.csv sauerbraten.csv
# dest ftm.csv graphmak.csv
# dest ftm.csv jgameai.csv
# dest ftm.csv gpsmid.csv
# dest ftm.csv empyrean.csv
# dest ftm.csv awemud.csv
# dest ftm.csv crisscross.csv
# dest ftm.csv re2c.csv
# dest ftm.csv tzod.csv
# dest ftm.csv octave.csv
# dest ftm.csv adaptagrams.csv
# dest ftm.csv open-media-library.csv
# dest ftm.csv vdsf.csv
# dest ftm.csv orc.csv
# dest ftm.csv lazarus-ccr.csv
# dest ftm.csv n2cms.csv
# dest ftm.csv forester-atv.csv
# dest ftm.csv mob-sen-plat.csv
# dest ftm.csv nh3d.csv
# dest ftm.csv amanda.csv
# 11
# ftm.csv
# dest ftm.csv rectracker.csv
# dest ftm.csv dynalloy.csv
# dest ftm.csv mpqc.csv
# dest ftm.csv thout.csv
# dest ftm.csv benojt.csv
# dest ftm.csv sabbu.csv
# dest ftm.csv unladen-swallow.csv
# dest ftm.csv powerfolder-.csv
# dest ftm.csv barracudamvc.csv
# dest ftm.csv nutz.csv
# dest ftm.csv apolloplayer.csv
# dest ftm.csv vxl.csv
# dest ftm.csv fbmanager.csv
# dest ftm.csv olsrd.csv
# dest ftm.csv jajuk.csv
# dest ftm.csv sqlpower-library.csv
# dest ftm.csv heekscad.csv
# dest ftm.csv zorannt.csv
# dest ftm.csv emftriple.csv
# dest ftm.csv gamestone.csv
# dest ftm.csv jicarilla.csv
# dest ftm.csv sevenupdate.csv
# dest ftm.csv nuttx.csv
# dest ftm.csv psrchive.csv
# dest ftm.csv jvcl.csv
# dest ftm.csv kdenlive.csv
# dest ftm.csv hatari.csv
# dest ftm.csv maidsafe-dht.csv
# dest ftm.csv opde.csv
# dest ftm.csv brlcad.csv
# dest ftm.csv opentibia.csv
# dest ftm.csv plee-the-bear.csv
# dest ftm.csv xcsoar.csv
# dest ftm.csv vapor.csv
# dest ftm.csv reaper-ecad.csv
# dest ftm.csv jmri.csv
# dest ftm.csv igarden.csv
# dest ftm.csv mb-unit.csv
# dest ftm.csv kaffeine.csv
# dest ftm.csv ossim.csv
# dest ftm.csv jlinalg.csv
# dest ftm.csv megasquirtavr.csv
# dest ftm.csv psycle.csv
# dest ftm.csv beast-mcmc.csv
# dest ftm.csv ikvm.csv
# dest ftm.csv bscwweasel.csv
# dest ftm.csv zact.csv
# dest ftm.csv zscreen.csv
# dest ftm.csv sarasvati.csv
# dest ftm.csv flylegacy.csv
# dest ftm.csv nullc.csv
# dest ftm.csv dvt.csv
# dest ftm.csv retromenu.csv
# dest ftm.csv jatlas.csv
# dest ftm.csv liferea.csv
# dest ftm.csv array4j.csv
# dest ftm.csv go.csv
# dest ftm.csv zealos.csv
# dest ftm.csv ns-3.csv
# dest ftm.csv nug.csv
# dest ftm.csv critterding.csv
# dest ftm.csv gotjava.csv
# dest ftm.csv optalgtoolkit.csv
# dest ftm.csv kwave.csv
# dest ftm.csv superwaba.csv
# dest ftm.csv ltp.csv
# dest ftm.csv pdfedit.csv
# dest ftm.csv blogentis.csv
# dest ftm.csv mclient-mume.csv
# dest ftm.csv firebird.csv
# 12
# ftm.csv
# dest ftm.csv inkscape.csv
# dest ftm.csv wxcrp.csv
# dest ftm.csv m-m-m.csv
# dest ftm.csv bacula.csv
# dest ftm.csv extprosys.csv
# dest ftm.csv lsb.csv
# dest ftm.csv fritzing.csv
# dest ftm.csv robocode.csv
# dest ftm.csv capcode.csv
# dest ftm.csv openefm.csv
# dest ftm.csv etics.csv
# dest ftm.csv novembre.csv
# dest ftm.csv lmms.csv
# dest ftm.csv codeblocks.csv
# dest ftm.csv ontomorphtab.csv
# dest ftm.csv x-ray-mule.csv
# dest ftm.csv openintents.csv
# dest ftm.csv atomsite.csv
# dest ftm.csv bloodycore.csv
# dest ftm.csv checker-framework.csv
# dest ftm.csv arianne.csv
# dest ftm.csv dsworkbench.csv
# dest ftm.csv gogoego.csv
# dest ftm.csv electric-core.csv
# dest ftm.csv atlc.csv
# dest ftm.csv rosegarden.csv
# dest ftm.csv linuxsh.csv
# dest ftm.csv theresa.csv
# dest ftm.csv jcae.csv
# dest ftm.csv dxengine.csv
# dest ftm.csv uwom-server.csv
# dest ftm.csv ivatamasks.csv
# dest ftm.csv playerstage.csv
# dest ftm.csv taverna.csv
# dest ftm.csv rtb-team.csv
# dest ftm.csv projectts.csv
# dest ftm.csv autofac.csv
# dest ftm.csv nsis.csv
# dest ftm.csv knowledge.csv
# dest ftm.csv esmf.csv
# dest ftm.csv abbot.csv
# dest ftm.csv konversation.csv
# dest ftm.csv arsenal-1.csv
# dest ftm.csv utgb.csv
# dest ftm.csv taokgame.csv
# dest ftm.csv openmeetings.csv
# dest ftm.csv nosleepsoftware.csv
# dest ftm.csv jsidplay2.csv
# dest ftm.csv chipster.csv
# dest ftm.csv badtrinitycore.csv
# dest ftm.csv redshell.csv
# dest ftm.csv zengine.csv
# dest ftm.csv javagroups.csv
# dest ftm.csv hazelcast.csv
# dest ftm.csv xuggle.csv
# dest ftm.csv moviesandbox.csv
# dest ftm.csv jrefactory.csv
# dest ftm.csv alembik.csv
# dest ftm.csv mule.csv
# dest ftm.csv aubit4gl.csv
# dest ftm.csv sepgsql.csv
# dest ftm.csv sblim.csv
# dest ftm.csv pentahoanalysistool.csv
# dest ftm.csv rezilla.csv
# dest ftm.csv pcgen.csv
# dest ftm.csv dvd-create.csv
# dest ftm.csv freenet.csv
# dest ftm.csv ivef-sdk.csv
# dest ftm.csv adonthell.csv
# dest ftm.csv algebsql.csv
# 13
# ftm.csv
# dest ftm.csv qgis.csv
# dest ftm.csv migen.csv
# dest ftm.csv jsecurity.csv
# dest ftm.csv jnode.csv
# dest ftm.csv jhotdraw.csv
# dest ftm.csv sidekar.csv
# dest ftm.csv emeraldemu.csv
# dest ftm.csv emisview.csv
# dest ftm.csv autoopencas.csv
# dest ftm.csv mcmc-jags.csv
# dest ftm.csv cataclysmos.csv
# dest ftm.csv fontforge.csv
# dest ftm.csv badtrinity-zero.csv
# dest ftm.csv cleartk.csv
# dest ftm.csv delphilhlplib.csv
# dest ftm.csv mcore3d.csv
# dest ftm.csv applet2app.csv
# dest ftm.csv upp-mirror.csv
# dest ftm.csv magicwars.csv
# dest ftm.csv xbplayer.csv
# dest ftm.csv zildo.csv
# dest ftm.csv jython.csv
# dest ftm.csv ildjit.csv
# dest ftm.csv gbif-providertoolkit.csv
# dest ftm.csv jfreereport.csv
# dest ftm.csv opennms.csv
# dest ftm.csv yield.csv
# dest ftm.csv trackit.csv
# dest ftm.csv scen-connect.csv
# dest ftm.csv freelords.csv
# dest ftm.csv piccolo2d.csv
# dest ftm.csv bochs.csv
# dest ftm.csv intact.csv
# dest ftm.csv htmlunit.csv
# dest ftm.csv open-beos.csv
# dest ftm.csv libopenmetaverse.csv
# dest ftm.csv popeye-chess.csv
# dest ftm.csv jbpm.csv
# dest ftm.csv cities3d.csv
# dest ftm.csv springside.csv
# dest ftm.csv k3d.csv
# dest ftm.csv kvs.csv
# dest ftm.csv firebreath.csv
# dest ftm.csv fltk.csv
# dest ftm.csv bullet.csv
# dest ftm.csv mobicents.csv
# dest ftm.csv maya-work-in-progress.csv
# dest ftm.csv betoffice.csv
# dest ftm.csv scite-ru.csv
# dest ftm.csv ifmo-game-1.csv
# dest ftm.csv qcad2.csv
# dest ftm.csv xmemcached.csv
# dest ftm.csv ldview.csv
# dest ftm.csv rohxel.csv
# dest ftm.csv jpaul.csv
# dest ftm.csv pfaedit.csv
# dest ftm.csv gbif-indexingtoolkit.csv
# dest ftm.csv levent.csv
# dest ftm.csv neodatis-odb.csv
# dest ftm.csv pidgin.csv
# dest ftm.csv swtfox.csv
# dest ftm.csv aime.csv
# dest ftm.csv mvdsv.csv
# dest ftm.csv japano.csv
# dest ftm.csv jitterbit.csv
# dest ftm.csv encog-cs.csv
# dest ftm.csv red5.csv
# dest ftm.csv co-ode-owl-plugins.csv
# dest ftm.csv exordium.csv
# dest ftm.csv cornerstone.csv
# 14
# ftm.csv
# dest ftm.csv bl-toolkit.csv
# dest ftm.csv opengs.csv
# dest ftm.csv patterntesting.csv
# dest ftm.csv log4net.csv
# dest ftm.csv gzigzag.csv
# dest ftm.csv fw4spl.csv
# dest ftm.csv phet.csv
# dest ftm.csv gnukeda.csv
# dest ftm.csv jaxen.csv
# dest ftm.csv unimrcp.csv
# dest ftm.csv enlightenment.csv
# dest ftm.csv tokratan.csv
# dest ftm.csv opensim4opencog.csv
# dest ftm.csv rsyslog.csv
# dest ftm.csv qlc.csv
# dest ftm.csv lockss.csv
# dest ftm.csv nicepress.csv
# dest ftm.csv scenemonitor.csv
# dest ftm.csv wxlua.csv
# dest ftm.csv blue-c.csv
# dest ftm.csv tcl.csv
# dest ftm.csv etherboot.csv
# dest ftm.csv pustefix.csv
# dest ftm.csv haggle.csv
# dest ftm.csv jmonkeyengine.csv
# dest ftm.csv officefloor.csv
# dest ftm.csv fluidium.csv
# dest ftm.csv aufs.csv
# dest ftm.csv cuberok.csv
# dest ftm.csv vienna-add-in.csv
# dest ftm.csv ivataopenportal.csv
# dest ftm.csv decidr.csv
# dest ftm.csv mptvseries.csv
# dest ftm.csv planeshift.csv
# dest ftm.csv phonon-vlc-mplayer.csv
# dest ftm.csv jgnash.csv
# dest ftm.csv nassp.csv
# dest ftm.csv toped.csv
# dest ftm.csv mediate.csv
# dest ftm.csv arcallians.csv
# dest ftm.csv emulemorph.csv
# dest ftm.csv webdriver.csv
# dest ftm.csv jsr308-langtools.csv
# dest ftm.csv boost-sandbox.csv
# dest ftm.csv mvnforum.csv
# dest ftm.csv plato.csv
# dest ftm.csv tolven.csv
# dest ftm.csv grafx2.csv
# dest ftm.csv voms.csv
# dest ftm.csv onotoa.csv
# dest ftm.csv jguard.csv
# dest ftm.csv yale.csv
# dest ftm.csv jmol.csv
# dest ftm.csv mscore.csv
# dest ftm.csv hydrogen.csv
# dest ftm.csv qtwin.csv
# dest ftm.csv sbml.csv
# dest ftm.csv thrust.csv
# dest ftm.csv yaprm.csv
# dest ftm.csv continuum-ide.csv
# dest ftm.csv gpac.csv
# dest ftm.csv e-bio-flow.csv
# dest ftm.csv jbasic.csv
# dest ftm.csv aztec.csv
# dest ftm.csv sylpheed-claws.csv
# dest ftm.csv stuproa-cims.csv
# dest ftm.csv apertium.csv
# dest ftm.csv fm-classic.csv
# dest ftm.csv smarttag.csv
# dest ftm.csv pamguard.csv
# 15
# ftm.csv
# dest ftm.csv qtractor.csv
# dest ftm.csv oppna-program-hsatools.csv
# dest ftm.csv acegisecurity.csv
# dest ftm.csv customsagetv.csv
# dest ftm.csv openxava.csv
# dest ftm.csv botsnscouts.csv
# dest ftm.csv google-caja.csv
# dest ftm.csv freebios.csv
# dest ftm.csv tktoolkit.csv
# dest ftm.csv mbse.csv
# dest ftm.csv gebr.csv
# dest ftm.csv flexpay.csv
# dest ftm.csv bnetd.csv
# dest ftm.csv gabel.csv
# dest ftm.csv mpgravity.csv
# dest ftm.csv vars-redux.csv
# dest ftm.csv jam-daq.csv
# dest ftm.csv haphazard.csv
# dest ftm.csv httpcontentparser.csv
# dest ftm.csv mia.csv
# dest ftm.csv vrjuggler.csv
# dest ftm.csv myfaces.csv
# dest ftm.csv massiv.csv
# dest ftm.csv wow-qrsk.csv
# dest ftm.csv bacnet.csv
# dest ftm.csv gretl.csv
# dest ftm.csv empserver.csv
# dest ftm.csv plplot.csv
# dest ftm.csv mycila.csv
# dest ftm.csv ogrehg.csv
# dest ftm.csv alleg.csv
# dest ftm.csv k3b.csv
# dest ftm.csv jaxlib.csv
# dest ftm.csv chaperon.csv
# dest ftm.csv unbvision.csv
# dest ftm.csv genecys.csv
# dest ftm.csv openmalaria.csv
# dest ftm.csv wishmaster.csv
# dest ftm.csv bibedt.csv
# dest ftm.csv yarp0.csv
# dest ftm.csv tmva.csv
# dest ftm.csv azureus.csv
# dest ftm.csv bulmages.csv
# dest ftm.csv ctrlr.csv
# dest ftm.csv rodin-b-sharp.csv
# dest ftm.csv kowari.csv
# dest ftm.csv ppcboot.csv
# dest ftm.csv clamav.csv
# dest ftm.csv motu.csv
# dest ftm.csv gnupdate.csv
# dest ftm.csv customwars.csv
# dest ftm.csv libtorrent.csv
# dest ftm.csv fceugc.csv
# dest ftm.csv minig.csv
# dest ftm.csv calcubetimer.csv
# dest ftm.csv iaml.csv
# dest ftm.csv jppf-project.csv
# dest ftm.csv anaxagora.csv
# dest ftm.csv ipfire-wall.csv
# dest ftm.csv sumatrapdf.csv
# dest ftm.csv gwanted.csv
# dest ftm.csv cubefs.csv
# dest ftm.csv moving-pictures.csv
# dest ftm.csv alsa.csv
# dest ftm.csv nodal.csv
# dest ftm.csv monetdb.csv
# dest ftm.csv xemeiah.csv
# dest ftm.csv riff-evolve.csv
# dest ftm.csv owlapi.csv
# dest ftm.csv ogre.csv
# 16
# ftm.csv
# dest ftm.csv exist.csv
# dest ftm.csv proftp.csv
# dest ftm.csv rtrt-on-gpu.csv
# dest ftm.csv matrex.csv
# dest ftm.csv amateur-scrolls.csv
# dest ftm.csv ossbuild.csv
# dest ftm.csv st-filteredstatistics.csv
# dest ftm.csv pokenetonline.csv
# dest ftm.csv java-gnome.csv
# dest ftm.csv unflobtactical.csv
# dest ftm.csv archive-crawler.csv
# dest ftm.csv freedom-erp.csv
# dest ftm.csv miranda-icq.csv
# dest ftm.csv silvertree.csv
# dest ftm.csv projectfactory.csv
# dest ftm.csv autat.csv
# dest ftm.csv quarkplusplus.csv
# dest ftm.csv stemkit.csv
# dest ftm.csv foursquared.csv
# dest ftm.csv jasperreports.csv
# dest ftm.csv m-a-d-n-e-s-s.csv
# dest ftm.csv roolo.csv
# dest ftm.csv frogatto.csv
# dest ftm.csv mimosa.csv
# dest ftm.csv amygdala.csv
# dest ftm.csv irrlicht.csv
# dest ftm.csv lcfizvtop.csv
# dest ftm.csv grisbi.csv
# dest ftm.csv elynx.csv
# dest ftm.csv alpine.csv
# dest ftm.csv mumble.csv
# dest ftm.csv t-2.csv
# dest ftm.csv jaolt.csv
# dest ftm.csv libmesh.csv
# dest ftm.csv all-plasm.csv
# dest ftm.csv acdk.csv
# dest ftm.csv bwapi.csv
# dest ftm.csv modellus.csv
# dest ftm.csv micomt.csv
# dest ftm.csv mp-rechnungs-und-kundenverwaltung.csv
# dest ftm.csv tcvp.csv
# dest ftm.csv xstore.csv
# dest ftm.csv bdbbasic.csv
# dest ftm.csv tart.csv
# dest ftm.csv echongl.csv
# dest ftm.csv snakeyaml.csv
# dest ftm.csv wheat.csv
# dest ftm.csv dspace-gsoc.csv
# dest ftm.csv yarp.csv
# dest ftm.csv boost.csv
# dest ftm.csv qse.csv
# dest ftm.csv quarkplayer.csv
# dest ftm.csv open-data-kit.csv
# dest ftm.csv yafdotnet.csv
# dest ftm.csv impala.csv
# dest ftm.csv avisynth2.csv
# dest ftm.csv xreal.csv
# dest ftm.csv tycho.csv
# dest ftm.csv nabu-library.csv
# dest ftm.csv freewrl.csv
# dest ftm.csv roller.csv
# dest ftm.csv zabbix.csv
# dest ftm.csv turbotrader-bos.csv
# dest ftm.csv xpontus.csv
# dest ftm.csv cascading.csv
# dest ftm.csv omseek.csv
# dest ftm.csv kindb.csv
# dest ftm.csv panda3d.csv
# dest ftm.csv gusanos.csv
# dest ftm.csv truevision.csv
# 17
# ftm.csv
# dest ftm.csv kml.csv
# dest ftm.csv unicase.csv
# dest ftm.csv zoolib.csv
# dest ftm.csv ontopia.csv
# dest ftm.csv repositorium.csv
# dest ftm.csv pgui.csv
# dest ftm.csv ultimairis.csv
# dest ftm.csv galaxium.csv
# dest ftm.csv sigil.csv
# dest ftm.csv ardour.csv
# dest ftm.csv aten.csv
# dest ftm.csv irplus.csv
# dest ftm.csv xfce.csv
# dest ftm.csv projecteqemu.csv
# dest ftm.csv personalaccess.csv
# dest ftm.csv pcsx2.csv
# dest ftm.csv multitude.csv
# dest ftm.csv virtuoso.csv
# dest ftm.csv jrdf.csv
# dest ftm.csv runuomondains.csv
# dest ftm.csv jgossipforum.csv
# dest ftm.csv ingex.csv
# dest ftm.csv papertoolkit.csv
# dest ftm.csv modplug.csv
# dest ftm.csv xcmetadataservicestoolkit.csv
# dest ftm.csv bionote.csv
# dest ftm.csv openfrag.csv
# dest ftm.csv super-tux.csv
# dest ftm.csv uclmda.csv
# dest ftm.csv glas.csv
# dest ftm.csv itext.csv
# dest ftm.csv pydev.csv
# dest ftm.csv octet.csv
# dest ftm.csv powerfolder.csv
# dest ftm.csv auber.csv
# dest ftm.csv rebecca-aiml.csv
# dest ftm.csv dataobjectsdotnet.csv
# dest ftm.csv jparsec.csv
# dest ftm.csv twostep.csv
# dest ftm.csv xbg.csv
# dest ftm.csv joustsim.csv
# dest ftm.csv ofbiz.csv
# dest ftm.csv kftpgrabber.csv
# dest ftm.csv smartgwt.csv
# dest ftm.csv img-browse-sort.csv
# dest ftm.csv adobe-source.csv
# dest ftm.csv ibatisdb.csv
# dest ftm.csv fido.csv
# dest ftm.csv gdis.csv
# dest ftm.csv madman.csv
# dest ftm.csv soar.csv
# dest ftm.csv lufa-lib.csv
# dest ftm.csv somap.csv
# dest ftm.csv netatalk.csv
# dest ftm.csv google-web-toolkit.csv
# dest ftm.csv megameknet.csv
# dest ftm.csv power-architect.csv
# dest ftm.csv enzo.csv
# dest ftm.csv lite.csv
# dest ftm.csv hannosset.csv
# dest ftm.csv lportal.csv
# dest ftm.csv geotools.csv
# dest ftm.csv xined.csv
# dest ftm.csv reaper3d.csv
# dest ftm.csv openmsx.csv
# dest ftm.csv loki-lib.csv
# dest ftm.csv lphant.csv
# dest ftm.csv ns-3-dev-def-routing.csv
# dest ftm.csv wxcode.csv
# 18
# ftm.csv
# dest ftm.csv jchassis.csv
# dest ftm.csv doomlegacy.csv
# dest ftm.csv bzbyte.csv
# dest ftm.csv fmri-dmt.csv
# dest ftm.csv v8.csv
# dest ftm.csv servicestack.csv
# dest ftm.csv carabiner.csv
# dest ftm.csv gephex.csv
# dest ftm.csv mediaportal.csv
# dest ftm.csv gnome-jabber.csv
# dest ftm.csv fityk.csv
# dest ftm.csv mecat.csv
# dest ftm.csv ngl.csv
# dest ftm.csv codepurge.csv
# dest ftm.csv jcl.csv
# dest ftm.csv bigdata.csv
# dest ftm.csv salasaga.csv
# dest ftm.csv ondex.csv
# dest ftm.csv jas.csv
# dest ftm.csv qdvdauthor.csv
# dest ftm.csv gmerlin.csv
# dest ftm.csv wsmt.csv
# dest ftm.csv xqilla.csv
# dest ftm.csv jstock.csv
# dest ftm.csv poormans.csv
# dest ftm.csv kolmafia.csv
# dest ftm.csv synergyspace.csv
# dest ftm.csv nebuladevice.csv
# dest ftm.csv findbugs.csv
# dest ftm.csv qmmp.csv
# dest ftm.csv wxstudio.csv
# dest ftm.csv free-evolution.csv
# dest ftm.csv xapian.csv
# dest ftm.csv quark.csv
# dest ftm.csv les-indemodables.csv
# dest ftm.csv mesa3d.csv
# dest ftm.csv simplewebservices.csv
# dest ftm.csv illumination.csv
# dest ftm.csv wxjs.csv
# dest ftm.csv ambulant.csv
# dest ftm.csv kmess.csv
# dest ftm.csv fleet-simulator.csv
# dest ftm.csv tradelink.csv
# dest ftm.csv opendvr.csv
# dest ftm.csv pi-qmc.csv
# dest ftm.csv google-gears.csv
# dest ftm.csv bibletime.csv
# dest ftm.csv ipfilter.csv
# dest ftm.csv glelite.csv
# dest ftm.csv hibernate.csv
# dest ftm.csv keyczar.csv
# dest ftm.csv oscarmcmaster.csv
# dest ftm.csv passwordsafe.csv
# dest ftm.csv primefaces.csv
# dest ftm.csv xtreemfs.csv
# dest ftm.csv pixel-commandos.csv
# dest ftm.csv open-ms.csv
# dest ftm.csv pnotepad.csv
# dest ftm.csv qedo.csv
# dest ftm.csv tigermud.csv
# dest ftm.csv mevenide.csv
# dest ftm.csv xcf.csv
# dest ftm.csv ninject.csv
# dest ftm.csv xinity.csv
# dest ftm.csv xmoto.csv
# dest ftm.csv coot.csv
# dest ftm.csv emite.csv
# dest ftm.csv gss.csv
# dest ftm.csv icescrum.csv
# 19
# mecat.csv
# dest mecat.csv moast.csv
# dest mecat.csv chrysalis.csv
# dest mecat.csv cortex-vfx.csv
# dest mecat.csv l2j.csv
# dest mecat.csv geogebra.csv
# dest mecat.csv ffigo.csv
# dest mecat.csv autowikibrowser.csv
# dest mecat.csv duplicati.csv
# dest mecat.csv gstreamer.csv
# dest mecat.csv quantlib.csv
# dest mecat.csv skia.csv
# dest mecat.csv jruby.csv
# dest mecat.csv chaosrts.csv
# dest mecat.csv mplayer-ce.csv
# dest mecat.csv biopax.csv
# dest mecat.csv linux-ntfs.csv
# dest mecat.csv growl-for-windows.csv
# dest mecat.csv synecdoche.csv
# dest mecat.csv rcp-company-uibindings.csv
# dest mecat.csv tweetsharp.csv
# dest mecat.csv elateportal.csv
# dest mecat.csv sandiaportals.csv
# dest mecat.csv biodwh.csv
# dest mecat.csv trinitycore.csv
# dest mecat.csv zemljanka.csv
# dest mecat.csv tango-cs.csv
# dest mecat.csv buddata-ebxml-registry.csv
# dest mecat.csv javaprofiler.csv
# dest mecat.csv fluent-nhibernate.csv
# dest mecat.csv olex2.csv
# dest mecat.csv nunit.csv
# dest mecat.csv tencompetence.csv
# dest mecat.csv exl.csv
# dest mecat.csv nativeclient.csv
# dest mecat.csv codesmith.csv
# dest mecat.csv stajistics.csv
# dest mecat.csv oorexx.csv
# dest mecat.csv crux-framework.csv
# dest mecat.csv ta3d.csv
# dest mecat.csv web-cat.csv
# dest mecat.csv ftm.csv
# dest mecat.csv factor.csv
# dest mecat.csv hydrate.csv
# dest mecat.csv jfreechart.csv
# dest mecat.csv elvishrayrenderer.csv
# dest mecat.csv xamj.csv
# dest mecat.csv uwom.csv
# dest mecat.csv rocrail.csv
# dest mecat.csv columba.csv
# dest mecat.csv metacosm.csv
# dest mecat.csv quickfast.csv
# dest mecat.csv geochat.csv
# dest mecat.csv natpad.csv
# dest mecat.csv libarchive.csv
# dest mecat.csv jcache.csv
# dest mecat.csv zxing.csv
# dest mecat.csv arm-webradio.csv
# dest mecat.csv genoviz.csv
# dest mecat.csv fulguro.csv
# dest mecat.csv wikipediardware.csv
# dest mecat.csv rockbox.csv
# dest mecat.csv ng4j.csv
# dest mecat.csv uface.csv
# dest mecat.csv gisgraphy.csv
# dest mecat.csv emono.csv
# dest mecat.csv thedata.csv
# dest mecat.csv miranda.csv
# dest mecat.csv cme.csv
# dest mecat.csv jmule.csv
