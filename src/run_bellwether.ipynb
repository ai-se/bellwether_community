# %%
import bellwether_v2
import pandas as pd
import numpy as np

# %%
bell = bellwether_v2.bellwether('/Users/suvodeepmajumder/Documents/AI4SE/git_miner/data/',
                                '/Users/suvodeepmajumder/Documents/AI4SE/bellwether_comminity/data/commit_guru/',1)

# %%
bell.run_bellwether()
# Out:
# druid
# newbestscore {'f1': 0.6275313586899599}:
# bestconf {'penalty': 'l1', 'multi_class': 'multinomial', 'C': 196.962, 'dual': False, 'fit_intercept': False, 'intercept_scaling': 79.3, 'class_weight': 'balanced', 'solver': 'saga', 'warm_start': True, 'max_iter': 398} :
# TUNING DONE ! {'penalty': 'l1', 'multi_class': 'multinomial', 'C': 196.962, 'dual': False, 'fit_intercept': False, 'intercept_scaling': 79.3, 'class_weight': 'balanced', 'solver': 'saga', 'warm_start': True, 'max_iter': 398} {'f1': 0.6275313586899599}
# newbestscore {'f1': 0.4886157154217628}:
# bestconf {'penalty': 'l2', 'multi_class': 'ovr', 'C': 16.546, 'dual': True, 'fit_intercept': True, 'intercept_scaling': 29.27, 'class_weight': None, 'solver': 'liblinear', 'warm_start': True, 'max_iter': 210} :
# newbestscore {'f1': 0.5036703264870296}:
# ...

# %%
df = pd.read_pickle('data/bellwether.pkl')

# %%
X = 0
for key in df['thanos']:
    if np.median(df['thanos'][key]) >= 0.6:
        X += 1
        print(np.median(df['thanos'][key]))
print(X)

# %%
np.median(df.iloc[0,0])
